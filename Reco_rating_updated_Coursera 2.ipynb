# %% [markdown]
# **Time Converter

# %%
import pandas as pd
#load excel
df = pd.read_csv("C:\\Users\\taslim.siddiqui\\Downloads\\production_recoRatingDataRecords (12).csv")
#df=pd.read_excel("//Users//romitbenkar//Desktop//Office//07-11-2024//other_output.xlsx")

# Replace 'apple' with 'orange' and 'banana' with 'grape' in column 'B'
df['duration_medium__c'] = df['duration_medium__c'].replace({'Day': 'Days', 'Month': 'Months','Year':'Years'})

# Define conversion factors to seconds for each mode
conversion_factors = {
    'years': 365 * 24 * 60 * 60,        # approximate (ignores leap years)
    'months': 30.44 * 24 * 60 * 60,     # average month
    'weeks': 7 * 24 * 60 * 60,
    'days': 24 * 60 * 60,
    'hours': 60 * 60,
    'minutes': 60
}

df['duration_medium__c']=df['duration_medium__c'].astype(str)


# Function to convert duration based on the mode
def convert_to_seconds(row):
    duration = row['course_duration__c']
    mode = row['duration_medium__c'].strip().lower()  # normalize to lowercase
    return duration * conversion_factors.get(mode, 1)  # Default to 1 if mode is not found

# Apply the conversion function to each row
df['Duration_in_seconds'] = df.apply(convert_to_seconds, axis=1)

# Add a column that checks if the duration in seconds is less than or equal to a week
df['Is_within_a_week'] = df['Duration_in_seconds'] <= 7 * 24 * 60 * 60

# Save the result back to Excel
#df.to_excel('//Users//romitbenkar//Desktop//Office//19-11-24//timeconvertoutput.xlsx', index=False)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2 #load excel
# ----> 3 df = pd.read_csv("C:\\Users\\taslim.siddiqui\\Downloads\\production_recoRatingDataRecords (12).csv")
#       4 #df=pd.read_excel("//Users//romitbenkar//Desktop//Office//07-11-2024//other_output.xlsx")
#       5
#       6 # Replace 'apple' with 'orange' and 'banana' with 'grape' in column 'B'
#       7 df['duration_medium__c'] = df['duration_medium__c'].replace({'Day': 'Days', 'Month': 'Months','Year':'Years'})
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Python311\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\taslim.siddiqui\\Downloads\\production_recoRatingDataRecords (12).csv'

# %% [markdown]
# Integration

# %%
values_to_check = ['Henry Harvin Education','Henry Harvin','Guvi Geeks','Edujournal','Sharpener','Business Toys Skills School']

# Check if any values in the DataFrame are in the list
df['Integration'] = df['course_provider_platform_name__c'].isin(values_to_check)
df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      01t8n000000GrJPAA0        4641  17890             Amity Future Academy
# 1      01t8n000000GrJQAA0        4642  16262             Amity Future Academy
# 2      01t8n000000GrJRAA0        4643  16885             Amity Future Academy
# 3      01t8n000000GrJSAA0        4644  17637             Amity Future Academy
# 4      01t8n000000GrJTAA0        4645  15978             Amity Future Academy
# ...                   ...         ...    ...                              ...
# 20952          przzd0g0p1       28069  26535                            Udemy
# 20953          przzj4igrr       14130  14308                         Coursera
# 20954          przzltt2yl       34946  35729                              GVC
# 20955          przzvn6z59       14710  11674                         Coursera
# 20956          przzxluxi8       20241  12028                         Coursera
#
#                                             product_name  course_level  \
# 0      PG Program in Digital Marketing Strategies (PG...      Advanced
# 1              PG Program in Product Management (PGP-PM)      Advanced
# 2                    Post Graduate Diploma in Management      Advanced
# 3                    Post Graduate Diploma in Management      Advanced
# 4      Post Graduate Program in Big Data Architecture...      Advanced
# ...                                                  ...           ...
# 20952  Email Marketing: Subscriber List Growth With C...      Beginner
# 20953                      Resourcing a Project Schedule      Beginner
# 20954                      Programming Languages, Part B  Intermediate
# 20955  Exam Prep CKA: Certified Kubernetes Administrator  Intermediate
# 20956                               Generative AI Primer      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 0                 Months               12.00       NaN        170000.0
# 1                 Months               12.00       NaN        215000.0
# 2                 Months                6.00       NaN        120000.0
# 3                 Months                6.00       NaN        120000.0
# 4                 Months                6.00       NaN        100000.0
# ...                  ...                 ...       ...             ...
# 20952            Minutes              215.00   23850.0         23850.0
# 20953              Hours                0.30       1.0             0.0
# 20954              Hours               18.00       NaN             1.0
# 20955              Hours               18.93       1.0             0.0
# 20956              Hours                1.48       1.0             0.0
#
#        inr_amount__c  skill_id  \
# 0           170000.0       119
# 1           215000.0       125
# 2           120000.0        98
# 3           120000.0        37
# 4           100000.0        63
# ...              ...       ...
# 20952        23850.0       107
# 20953            0.0        37
# 20954            1.0       164
# 20955            0.0       107
# 20956            0.0       317
#
#                                              concepts  Duration_in_seconds  \
# 0      4539 , 4573 , 4617 , 4637 , 5648 , 6168 , 6963           31560192.0
# 1                                         4899 , 5037           31560192.0
# 2                                                4550           15780096.0
# 3                                                4590           15780096.0
# 4                                                5652           15780096.0
# ...                                               ...                  ...
# 20952                                            6615              12900.0
# 20953                                            4590               1080.0
# 20954                                            6893              64800.0
# 20955                                             NaN              68148.0
# 20956                                             NaN               5328.0
#
#        Is_within_a_week  Integration
# 0                 False        False
# 1                 False        False
# 2                 False        False
# 3                 False        False
# 4                 False        False
# ...                 ...          ...
# 20952              True        False
# 20953              True        False
# 20954              True        False
# 20955              True        False
# 20956              True        False
#
# [20957 rows x 16 columns]

# %% [markdown]
# Concept Count

# %%
def count_commas(val):
    if pd.isna(val):
        return 0
    elif ',' in val:
        return val.count(',') + 1
    else:
        return 1
df['concept_count']=df['concepts'].apply(count_commas)
df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      01t8n000000GrJPAA0        4641  17890             Amity Future Academy
# 1      01t8n000000GrJQAA0        4642  16262             Amity Future Academy
# 2      01t8n000000GrJRAA0        4643  16885             Amity Future Academy
# 3      01t8n000000GrJSAA0        4644  17637             Amity Future Academy
# 4      01t8n000000GrJTAA0        4645  15978             Amity Future Academy
# ...                   ...         ...    ...                              ...
# 20952          przzd0g0p1       28069  26535                            Udemy
# 20953          przzj4igrr       14130  14308                         Coursera
# 20954          przzltt2yl       34946  35729                              GVC
# 20955          przzvn6z59       14710  11674                         Coursera
# 20956          przzxluxi8       20241  12028                         Coursera
#
#                                             product_name  course_level  \
# 0      PG Program in Digital Marketing Strategies (PG...      Advanced
# 1              PG Program in Product Management (PGP-PM)      Advanced
# 2                    Post Graduate Diploma in Management      Advanced
# 3                    Post Graduate Diploma in Management      Advanced
# 4      Post Graduate Program in Big Data Architecture...      Advanced
# ...                                                  ...           ...
# 20952  Email Marketing: Subscriber List Growth With C...      Beginner
# 20953                      Resourcing a Project Schedule      Beginner
# 20954                      Programming Languages, Part B  Intermediate
# 20955  Exam Prep CKA: Certified Kubernetes Administrator  Intermediate
# 20956                               Generative AI Primer      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 0                 Months               12.00       NaN        170000.0
# 1                 Months               12.00       NaN        215000.0
# 2                 Months                6.00       NaN        120000.0
# 3                 Months                6.00       NaN        120000.0
# 4                 Months                6.00       NaN        100000.0
# ...                  ...                 ...       ...             ...
# 20952            Minutes              215.00   23850.0         23850.0
# 20953              Hours                0.30       1.0             0.0
# 20954              Hours               18.00       NaN             1.0
# 20955              Hours               18.93       1.0             0.0
# 20956              Hours                1.48       1.0             0.0
#
#        inr_amount__c  skill_id  \
# 0           170000.0       119
# 1           215000.0       125
# 2           120000.0        98
# 3           120000.0        37
# 4           100000.0        63
# ...              ...       ...
# 20952        23850.0       107
# 20953            0.0        37
# 20954            1.0       164
# 20955            0.0       107
# 20956            0.0       317
#
#                                              concepts  Duration_in_seconds  \
# 0      4539 , 4573 , 4617 , 4637 , 5648 , 6168 , 6963           31560192.0
# 1                                         4899 , 5037           31560192.0
# 2                                                4550           15780096.0
# 3                                                4590           15780096.0
# 4                                                5652           15780096.0
# ...                                               ...                  ...
# 20952                                            6615              12900.0
# 20953                                            4590               1080.0
# 20954                                            6893              64800.0
# 20955                                             NaN              68148.0
# 20956                                             NaN               5328.0
#
#        Is_within_a_week  Integration  concept_count
# 0                 False        False              7
# 1                 False        False              2
# 2                 False        False              1
# 3                 False        False              1
# 4                 False        False              1
# ...                 ...          ...            ...
# 20952              True        False              1
# 20953              True        False              1
# 20954              True        False              1
# 20955              True        False              0
# 20956              True        False              0
#
# [20957 rows x 17 columns]

# %%
deficit_0 =(df['concept_count']== 0 ).sum()
deficit_0
# Out:
# np.int64(2574)

# %% [markdown]
# No concept column

# %%
df['no_concept'] = df['concepts'].isna()

# %% [markdown]
# Only Udemy data

# %%
# Sample DataFrame
df# data is the file which will only have CPP names

# List of values to check
values_to_check_udemy = ['Udemy']

# Check if any values in the DataFrame are in the list
df['Udemy'] = df['course_provider_platform_name__c'].isin(values_to_check_udemy)
udemy_df = df.query("Udemy == True and no_concept == False")
udemy_df
#df.to_excel("//Users//romitbenkar//Desktop//Office//19-11-2024//Udemy_output.xlsx")
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 1405      0AbIh9To       24901  23122                            Udemy
# 1406      0AbXa8Ut       24645  22866                            Udemy
# 1407      0AnKw5Rl       24128  22349                            Udemy
# 1408      0ArCd7Lv       27407  25631                            Udemy
# 1409      0ArKm5Sb       24969  23190                            Udemy
# ...            ...         ...    ...                              ...
# 20932   przy1fgag3       28644  27110                            Udemy
# 20937   przyc3rjqv       31300  29856                            Udemy
# 20938   przyhu62lv       29152  27615                            Udemy
# 20948   przyxra2de       29045  27508                            Udemy
# 20952   przzd0g0p1       28069  26535                            Udemy
#
#                                             product_name  course_level  \
# 1405   (Jetpack, Architecture  and  More)Advanced And...      Beginner
# 1406           Object-oriented Programming in JavaScript  Intermediate
# 1407   Vue - The Complete Guide (incl. Router  and  C...      Beginner
# 1408   Bootstrap 5 From Scratch | Build 5 Modern Webs...      Beginner
# 1409   Complete Deep Learning In R With Keras  and  O...      Beginner
# ...                                                  ...           ...
# 20932  Microsoft Teams: Teams Essentials for the work...      Beginner
# 20937  Master Certified Fraud Examiner (CFE) Essentia...      Beginner
# 20938           Negotiating Your Salary and Compensation      Beginner
# 20948                     Advanced Cryptography Concepts      Beginner
# 20952  Email Marketing: Subscriber List Growth With C...      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 1405             Minutes              2250.0   23850.0         23850.0
# 1406             Minutes               234.0   23850.0         23850.0
# 1407             Minutes              1912.0   23850.0         23850.0
# 1408             Minutes               798.0   23850.0         23850.0
# 1409             Minutes               475.0   23850.0         23850.0
# ...                  ...                 ...       ...             ...
# 20932            Minutes               135.0   23850.0         23850.0
# 20937            Minutes               121.0       0.0         23850.0
# 20938            Minutes               133.0   23850.0         23850.0
# 20948            Minutes               260.0   23850.0         23850.0
# 20952            Minutes               215.0   23850.0         23850.0
#
#        inr_amount__c  skill_id  \
# 1405         23850.0       293
# 1406         23850.0       103
# 1407         23850.0       103
# 1408         23850.0       103
# 1409         23850.0       293
# ...              ...       ...
# 20932        23850.0        44
# 20937        23850.0       256
# 20938        23850.0       255
# 20948        23850.0       291
# 20952        23850.0       107
#
#                                                 concepts  Duration_in_seconds  \
# 1405                                                6876             135000.0
# 1406                                                6849              14040.0
# 1407                                                6849             114720.0
# 1408                                         6817 , 6849              47880.0
# 1409                                                6778              28500.0
# ...                                                  ...                  ...
# 20932                                               4561               8100.0
# 20937  5400 , 5503 , 5593 , 5645 , 5760 , 6177 , 6344...               7260.0
# 20938                                               5041               7980.0
# 20948                                               4648              15600.0
# 20952                                               6615              12900.0
#
#        Is_within_a_week  Integration  concept_count  no_concept  Udemy
# 1405               True        False              1       False   True
# 1406               True        False              1       False   True
# 1407               True        False              1       False   True
# 1408               True        False              2       False   True
# 1409               True        False              1       False   True
# ...                 ...          ...            ...         ...    ...
# 20932              True        False              1       False   True
# 20937              True        False              8       False   True
# 20938              True        False              1       False   True
# 20948              True        False              1       False   True
# 20952              True        False              1       False   True
#
# [5262 rows x 19 columns]

# %%
# Check if any values in the DataFrame are in the list
df['Udemy'] = df['course_provider_platform_name__c'].isin(values_to_check_udemy)
udemy_0_df = df.query("Udemy == True and no_concept == True")
udemy_0_df
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 1727      1FkNf0Wo       22871  21092                            Udemy
# 1915      1YjTw3Oy       23767  21988                            Udemy
# 1979      2FeBo7Oj       25745  23967                            Udemy
# 2863      5TgAx9Cg       22983  21204                            Udemy
# 2916      5YrGr8Hy       22895  21116                            Udemy
# 3212      7BpKm9Gj       23448  21669                            Udemy
# 3593      8ObDt0Ty       23451  21672                            Udemy
# 4026    pr04rriz87       29480  27943                            Udemy
# 5530    pr3a8wqtda       29919  28382                            Udemy
# 5757    pr3vmyyxgg       30260  28723                            Udemy
# 6042    pr4gzf4zqb       27977  26443                            Udemy
# 8300    pr982673yy       27946  26412                            Udemy
# 8373    pr9d9b50m9       28381  26847                            Udemy
# 8379    pr9dhr23kk       29614  28077                            Udemy
# 9052    prau0sb5p5       29406  27869                            Udemy
# 9880    prckjmlvhq       29660  28123                            Udemy
# 10482   prdv4gup74       28335  26801                            Udemy
# 10733   preelbycur       29646  28109                            Udemy
# 11631   prgh28omad       30150  28613                            Udemy
# 14048   prllet9osu       30939  29495                            Udemy
# 17962   prtq3w17ir       29930  28393                            Udemy
# 19154   prw95gpdwy       28285  26751                            Udemy
# 19309   prwkzmf60z       30271  28734                            Udemy
# 19687   prxd7fln6n       29050  27513                            Udemy
# 19810   prxn9li6ss       31017  29573                            Udemy
# 19822   prxnxpgnvw       28120  26586                            Udemy
#
#                                             product_name  course_level  \
# 1727   ACCA MA (F2) A Complete Course on Management A...      Beginner
# 1915   Web Performance In Practice: Master Core Web V...      Beginner
# 1979   AWS Technical Essentials  - Hands-On Training ...      Beginner
# 2863   Certified Key Performance Indicators Professio...      Beginner
# 2916   Automated Cryptocurrency Portfolio Investing w...      Beginner
# 3212   Master PMP Cost Management: Plan, Budget, Esti...      Beginner
# 3593   Master SWOT Analysis  and  Business Strategy f...      Beginner
# 4026                                Effective Leadership      Beginner
# 5530   Business English Essentials for Leadership and...  Intermediate
# 5757          Chaos Engineering using Azure Chaos Studio      Beginner
# 6042   Quality Management for Business Excellence (Ac...      Beginner
# 8300         How to Manage & Influence Your Virtual Team      Beginner
# 8373   Informed Risk Taking : Risk Management Process...      Beginner
# 8379         Developing Your Executive Leadership Skills  Intermediate
# 9052                   Leadership Become a better leader      Beginner
# 9880              Managing a Global Team with Confidence      Beginner
# 10482  Leadership: Growth Mindset for Leadership and ...      Beginner
# 10733  Leadership - Rise of a Leader (Lead people wit...      Beginner
# 11631  Web Performance In Practice: Master Core Web V...      Beginner
# 14048  Manage Change Through Collaboration and Team Work      Beginner
# 17962  Product Owner II for Agile Intermediate: Certi...      Beginner
# 19154  Mastering Collaboration: Work together for the...      Beginner
# 19309  Leadership Style: Discover & Maximize Your Lea...      Beginner
# 19687                             Smart Tips: Leadership      Beginner
# 19810          Collaboration with Emotional Intelligence  Intermediate
# 19822  Management & Leadership Skills: When To Manage...      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 1727             Minutes              2014.0   23850.0         23850.0
# 1915             Minutes               204.0   23850.0         23850.0
# 1979             Minutes               866.0   23850.0         23850.0
# 2863             Minutes               448.0   23850.0         23850.0
# 2916             Minutes              1931.0   23850.0         23850.0
# 3212             Minutes               224.0   23850.0         23850.0
# 3593             Minutes               185.0   23850.0         23850.0
# 4026             Minutes                49.0   23850.0         23850.0
# 5530             Minutes               319.0   23850.0         23850.0
# 5757             Minutes                74.0   23850.0         23850.0
# 6042             Minutes               240.0   23850.0         23850.0
# 8300             Minutes               192.0   23850.0         23850.0
# 8373             Minutes               532.0   23850.0         23850.0
# 8379             Minutes                52.0   23850.0         23850.0
# 9052             Minutes               133.0   23850.0         23850.0
# 9880             Minutes                35.0   23850.0         23850.0
# 10482            Minutes               228.0   23850.0         23850.0
# 10733            Minutes                91.0   23850.0         23850.0
# 11631            Minutes               204.0   23850.0         23850.0
# 14048            Minutes               102.0       0.0         23850.0
# 17962            Minutes               379.0   23850.0         23850.0
# 19154            Minutes                48.0   23850.0         23850.0
# 19309            Minutes               100.0   23850.0         23850.0
# 19687            Minutes               172.0   23850.0         23850.0
# 19810            Minutes               184.0       0.0         23850.0
# 19822            Minutes               346.0   23850.0         23850.0
#
#        inr_amount__c  skill_id concepts  Duration_in_seconds  \
# 1727         23850.0        49      NaN             120840.0
# 1915         23850.0       261      NaN              12240.0
# 1979         23850.0        44      NaN              51960.0
# 2863         23850.0       261      NaN              26880.0
# 2916         23850.0        49      NaN             115860.0
# 3212         23850.0       261      NaN              13440.0
# 3593         23850.0        49      NaN              11100.0
# 4026         23850.0       255      NaN               2940.0
# 5530         23850.0       255      NaN              19140.0
# 5757         23850.0       261      NaN               4440.0
# 6042         23850.0       263      NaN              14400.0
# 8300         23850.0       262      NaN              11520.0
# 8373         23850.0       406      NaN              31920.0
# 8379         23850.0       255      NaN               3120.0
# 9052         23850.0       255      NaN               7980.0
# 9880         23850.0       255      NaN               2100.0
# 10482        23850.0       255      NaN              13680.0
# 10733        23850.0       255      NaN               5460.0
# 11631        23850.0       106      NaN              12240.0
# 14048        23850.0       262      NaN               6120.0
# 17962        23850.0        36      NaN              22740.0
# 19154        23850.0       262      NaN               2880.0
# 19309        23850.0       255      NaN               6000.0
# 19687        23850.0       255      NaN              10320.0
# 19810        23850.0       262      NaN              11040.0
# 19822        23850.0       255      NaN              20760.0
#
#        Is_within_a_week  Integration  concept_count  no_concept  Udemy
# 1727               True        False              0        True   True
# 1915               True        False              0        True   True
# 1979               True        False              0        True   True
# 2863               True        False              0        True   True
# 2916               True        False              0        True   True
# 3212               True        False              0        True   True
# 3593               True        False              0        True   True
# 4026               True        False              0        True   True
# 5530               True        False              0        True   True
# 5757               True        False              0        True   True
# 6042               True        False              0        True   True
# 8300               True        False              0        True   True
# 8373               True        False              0        True   True
# 8379               True        False              0        True   True
# 9052               True        False              0        True   True
# 9880               True        False              0        True   True
# 10482              True        False              0        True   True
# 10733              True        False              0        True   True
# 11631              True        False              0        True   True
# 14048              True        False              0        True   True
# 17962              True        False              0        True   True
# 19154              True        False              0        True   True
# 19309              True        False              0        True   True
# 19687              True        False              0        True   True
# 19810              True        False              0        True   True
# 19822              True        False              0        True   True

# %% [markdown]
# Only ABC data

# %%
values_to_check_abc_coursera = ['Coursera']

# Check if values in 'course_provider_platform_name__c' column are in the list, and create a boolean column 'ABC'
df['ABC_coursera'] = df['course_provider_platform_name__c'].isin(values_to_check_abc_coursera)

abc_coursera_df = df.query("ABC_coursera == True and no_concept == False")
abc_coursera_df
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 3975    pr00ll9a88       14368  15208                         Coursera
# 3976    pr00nc2nuj       19718  12119                         Coursera
# 3987    pr01mrgb8a       16779  13115                         Coursera
# 3990    pr01x7z7az       16372  15180                         Coursera
# 3993    pr029rjxo5       22667  20755                         Coursera
# ...            ...         ...    ...                              ...
# 20945   przyv633ju       15093  14071                         Coursera
# 20947   przyx8v5ue       14285  10322                         Coursera
# 20949   przz7qgy8j       20005  14847                         Coursera
# 20950   przz9s4oct       16916  10069                         Coursera
# 20953   przzj4igrr       14130  14308                         Coursera
#
#                                             product_name  course_level  \
# 3975   Use SurveyMonkey to Create a Survey and Analyz...      Beginner
# 3976                 Getting Started with Facebook Pixel      Beginner
# 3987                       LangChain Chat with Your Data      Beginner
# 3990   Use C++ to build a Crypto Trading Platform: Fi...  Intermediate
# 3993                     TensorFlow: Data and Deployment      Beginner
# ...                                                  ...           ...
# 20945                            Programming Languages Ⅱ  Intermediate
# 20947  Cluster Analysis, Association Mining, and Mode...  Intermediate
# 20949                Technical Managerial Written Skills      Beginner
# 20950          Building Your Freelancing Career Capstone  Intermediate
# 20953                      Resourcing a Project Schedule      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 3975               Hours                0.40       1.0             0.0
# 3976               Hours                 NaN       1.0             0.0
# 3987               Hours                1.50       1.0             0.0
# 3990               Hours                7.30       1.0             0.0
# 3993               Hours                 NaN       1.0             0.0
# ...                  ...                 ...       ...             ...
# 20945              Hours               10.55       1.0             0.0
# 20947              Hours                3.95       1.0             0.0
# 20949              Hours               18.87       1.0             0.0
# 20950              Hours               11.93       1.0             0.0
# 20953              Hours                0.30       1.0             0.0
#
#        inr_amount__c  skill_id     concepts  Duration_in_seconds  \
# 3975             0.0       123         5497               1440.0
# 3976             0.0       117         5274                  NaN
# 3987             0.0       102         5888               5400.0
# 3990             0.0       290         4648              26280.0
# 3993             1.0        62         6669                  NaN
# ...              ...       ...          ...                  ...
# 20945            0.0       164         6893              37980.0
# 20947            0.0        65  4928 , 5224              14220.0
# 20949            0.0       130         6061              67932.0
# 20950            0.0       129         5334              42948.0
# 20953            0.0        37         4590               1080.0
#
#        Is_within_a_week  Integration  concept_count  no_concept  Udemy  \
# 3975               True        False              1       False  False
# 3976              False        False              1       False  False
# 3987               True        False              1       False  False
# 3990               True        False              1       False  False
# 3993              False        False              1       False  False
# ...                 ...          ...            ...         ...    ...
# 20945              True        False              1       False  False
# 20947              True        False              2       False  False
# 20949              True        False              1       False  False
# 20950              True        False              1       False  False
# 20953              True        False              1       False  False
#
#        ABC_coursera
# 3975           True
# 3976           True
# 3987           True
# 3990           True
# 3993           True
# ...             ...
# 20945          True
# 20947          True
# 20949          True
# 20950          True
# 20953          True
#
# [5454 rows x 20 columns]

# %%
# Check if values in 'course_provider_platform_name__c' column are in the list, and create a boolean column 'ABC'
df['ABC_coursera'] = df['course_provider_platform_name__c'].isin(values_to_check_abc_coursera)

abc_coursera_0_df = df.query("ABC_coursera == True and no_concept == True")
abc_coursera_0_df
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 3974    pr0072y7ai       17054  13847                         Coursera
# 4031    pr05es3nvi       18844  12909                         Coursera
# 4045    pr06dj3org       16102  13823                         Coursera
# 4046    pr06e8hqrz       14035  14086                         Coursera
# 4060    pr07ffp1wt       14715  14357                         Coursera
# ...            ...         ...    ...                              ...
# 20911   przwql4s97       19202  13317                         Coursera
# 20930   przxwst6s4       16924  13794                         Coursera
# 20933   przy2ytv16       21460  19450                         Coursera
# 20955   przzvn6z59       14710  11674                         Coursera
# 20956   przzxluxi8       20241  12028                         Coursera
#
#                                             product_name  course_level  \
# 3974   Personal Productivity, Time Management and Pri...      Beginner
# 4031                     Introduction to NoSQL Databases      Beginner
# 4045                        Payroll and Tax Fundamentals      Beginner
# 4046   Project Management: Control using the Earned V...      Beginner
# 4060   Running a Node.js Container on Google Kubernet...      Beginner
# ...                                                  ...           ...
# 20911  Machine Learning Operations (MLOps) with Verte...  Intermediate
# 20930  Our Share: Employee Ownership as a Wealth Shar...      Beginner
# 20933  Database Design and Operational Business Intel...      Beginner
# 20955  Exam Prep CKA: Certified Kubernetes Administrator  Intermediate
# 20956                               Generative AI Primer      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 3974               Hours                6.32       1.0             0.0
# 4031               Hours                 NaN       1.0             0.0
# 4045               Hours                5.58       1.0             0.0
# 4046               Hours                1.87       1.0             0.0
# 4060               Hours                0.67       1.0             0.0
# ...                  ...                 ...       ...             ...
# 20911              Hours                 NaN       1.0             0.0
# 20930              Hours               15.08       1.0             0.0
# 20933              Hours                 NaN       1.0             0.0
# 20955              Hours               18.93       1.0             0.0
# 20956              Hours                1.48       1.0             0.0
#
#        inr_amount__c  skill_id concepts  Duration_in_seconds  \
# 3974             0.0        40      NaN              22752.0
# 4031             0.0        57      NaN                  NaN
# 4045             0.0       126      NaN              20088.0
# 4046             0.0       213      NaN               6732.0
# 4060             0.0       108      NaN               2412.0
# ...              ...       ...      ...                  ...
# 20911            0.0       319      NaN                  NaN
# 20930            0.0       267      NaN              54288.0
# 20933            1.0        66      NaN                  NaN
# 20955            0.0       107      NaN              68148.0
# 20956            0.0       317      NaN               5328.0
#
#        Is_within_a_week  Integration  concept_count  no_concept  Udemy  \
# 3974               True        False              0        True  False
# 4031              False        False              0        True  False
# 4045               True        False              0        True  False
# 4046               True        False              0        True  False
# 4060               True        False              0        True  False
# ...                 ...          ...            ...         ...    ...
# 20911             False        False              0        True  False
# 20930              True        False              0        True  False
# 20933             False        False              0        True  False
# 20955              True        False              0        True  False
# 20956              True        False              0        True  False
#
#        ABC_coursera
# 3974           True
# 4031           True
# 4045           True
# 4046           True
# 4060           True
# ...             ...
# 20911          True
# 20930          True
# 20933          True
# 20955          True
# 20956          True
#
# [1052 rows x 20 columns]

# %%
# List of values to check
values_to_check_abc = ['GVC','Gyanodaya Virtual Campus','CIEL']

# Check if values in 'course_provider_platform_name__c' column are in the list, and create a boolean column 'ABC'
df['ABC'] = df['course_provider_platform_name__c'].isin(values_to_check_abc)

# Save the updated DataFrame to a new Excel file
#df.to_excel("//Users//romitbenkar//Desktop//Office//07-11-2024//ABCoutput.xlsx", index=False)
abc_df = df.query("ABC == True and no_concept == False")
abc_df
#df.to_excel("//Users//romitbenkar//Desktop//Office//19-11-2024//Udemy_output.xlsx")
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 3973    pr000be54a       22145  20095                              GVC
# 3981    pr015bytb9       12844   8295                              GVC
# 3983    pr01iiouag       34882  35609                              GVC
# 3984    pr01kkxugj       12964   8414                              GVC
# 3985    pr01kw4oyr       22165  20115                              GVC
# ...            ...         ...    ...                              ...
# 20912   przwty7x3c       13212   8662                              GVC
# 20936   przy8u5muw       12681   8132                              GVC
# 20943   przyr0egej       13596   9046                              GVC
# 20944   przyu0in9m       22779  20873                              GVC
# 20954   przzltt2yl       34946  35729                              GVC
#
#                                             product_name  course_level  \
# 3973   Advanced Visualizations & Dashboards: Visualiz...  Intermediate
# 3981   CompTIA A+ Core 1: Wireless Networking & Services  Intermediate
# 3983                 Cryptography and Information Theory  Intermediate
# 3984   Integrate Power Apps portals with web-based te...      Beginner
# 3985   CompTIA A+ Core 1: Mobile Device Accessories &...      Beginner
# ...                                                  ...           ...
# 20912  Webex Meetings Web: Organizing & Hosting Meetings      Beginner
# 20936  PMBOK® Guide Sixth Edition: Project Management...  Intermediate
# 20943  Applying Research Methods for Trend & Impact A...      Advanced
# 20944            Microsoft Azure Services and Lifecycles      Beginner
# 20954                      Programming Languages, Part B  Intermediate
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 3973               Hours                0.34       1.0             0.0  ...
# 3981               Hours                2.25       1.0             0.0  ...
# 3983               Hours                4.60       NaN             1.0  ...
# 3984               Hours                0.19       1.0             0.0  ...
# 3985               Hours                1.22       1.0             0.0  ...
# ...                  ...                 ...       ...             ...  ...
# 20912              Hours                1.07       1.0             0.0  ...
# 20936              Hours                0.45       1.0             0.0  ...
# 20943              Hours                0.35       1.0             0.0  ...
# 20944              Hours                 NaN       1.0             0.0  ...
# 20954              Hours               18.00       NaN             1.0  ...
#
#        skill_id  concepts Duration_in_seconds  Is_within_a_week  Integration  \
# 3973        336      4641              1224.0              True        False
# 3981        106      6575              8100.0              True        False
# 3983        291      4648             16560.0              True        False
# 3984        336      5207               684.0              True        False
# 3985        106      6229              4392.0              True        False
# ...         ...       ...                 ...               ...          ...
# 20912       288      6226              3852.0              True        False
# 20936        37      4590              1620.0              True        False
# 20943       126      5263              1260.0              True        False
# 20944       288      5947                 NaN             False        False
# 20954       164      6893             64800.0              True        False
#
#        concept_count  no_concept  Udemy  ABC_coursera   ABC
# 3973               1       False  False         False  True
# 3981               1       False  False         False  True
# 3983               1       False  False         False  True
# 3984               1       False  False         False  True
# 3985               1       False  False         False  True
# ...              ...         ...    ...           ...   ...
# 20912              1       False  False         False  True
# 20936              1       False  False         False  True
# 20943              1       False  False         False  True
# 20944              1       False  False         False  True
# 20954              1       False  False         False  True
#
# [2491 rows x 21 columns]

# %%
# Save the updated DataFrame to a new Excel file
#df.to_excel("//Users//romitbenkar//Desktop//Office//07-11-2024//ABCoutput.xlsx", index=False)
abc_0_df = df.query("ABC == True and no_concept == True")
abc_0_df
#df.to_excel("//Users//romitbenkar//Desktop//Office//19-11-2024//Udemy_output.xlsx")
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 4496    pr14vi9jve       13408   8858                              GVC
# 4573    pr1avov4dr       22840  20934                              GVC
# 4806    pr1tp2vzx8       12759   8210                              GVC
# 4968    pr250j7vms       12781   8232                              GVC
# 5227    pr2o2gu7to       22776  20870                              GVC
# ...            ...         ...    ...                              ...
# 19936   prxw8lype3       20908  18816                              GVC
# 19954   prxxilay2h       21520  19565                              GVC
# 20296   prylmq950l       12719   8170                              GVC
# 20658   przdn85o2g       21964  19914                              GVC
# 20809   przp8o0vrj       20929  18837                              GVC
#
#                                             product_name  course_level  \
# 4496       Implement hybrid identity with Windows Server      Beginner
# 4573             Advanced Styling with Responsive Design      Beginner
# 4806   Windows 8.1: Installing & Using Windows Univer...  Intermediate
# 4968   Perform Automatic Remediation by Using an AWS ...      Beginner
# 5227   Data Engineering with MS Azure Synapse Apache ...      Beginner
# ...                                                  ...           ...
# 19936  Optimize Your Operations for Today - and Tomorrow      Beginner
# 19954   Project Scheduling:  Estimate Activity Durations      Beginner
# 20296      Amazon Web Services 2018: Networking Services  Intermediate
# 20658  Talent Development and Transformation Leadercamps      Beginner
# 20809       Scrum Foundation: Scrum Development Concepts      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 4496               Hours                1.82       1.0             0.0  ...
# 4573               Hours                 NaN       1.0             0.0  ...
# 4806               Hours                1.28       1.0             0.0  ...
# 4968               Hours                0.75       1.0             0.0  ...
# 5227               Hours                 NaN       1.0             0.0  ...
# ...                  ...                 ...       ...             ...  ...
# 19936              Hours                0.58       1.0             0.0  ...
# 19954              Hours                 NaN       1.0             0.0  ...
# 20296              Hours                0.80       1.0             0.0  ...
# 20658              Hours                 NaN       1.0             0.0  ...
# 20809              Hours                1.10       1.0             0.0  ...
#
#        skill_id  concepts Duration_in_seconds  Is_within_a_week  Integration  \
# 4496        213       NaN              6552.0              True        False
# 4573        103       NaN                 NaN             False        False
# 4806        262       NaN              4608.0              True        False
# 4968        213       NaN              2700.0              True        False
# 5227        164       NaN                 NaN             False        False
# ...         ...       ...                 ...               ...          ...
# 19936        42       NaN              2088.0              True        False
# 19954        37       NaN                 NaN             False        False
# 20296       213       NaN              2880.0              True        False
# 20658       130       NaN                 NaN             False        False
# 20809       284       NaN              3960.0              True        False
#
#        concept_count  no_concept  Udemy  ABC_coursera   ABC
# 4496               0        True  False         False  True
# 4573               0        True  False         False  True
# 4806               0        True  False         False  True
# 4968               0        True  False         False  True
# 5227               0        True  False         False  True
# ...              ...         ...    ...           ...   ...
# 19936              0        True  False         False  True
# 19954              0        True  False         False  True
# 20296              0        True  False         False  True
# 20658              0        True  False         False  True
# 20809              0        True  False         False  True
#
# [88 rows x 21 columns]

# %% [markdown]
# non_corporate_df(No ABC and Udemy)

# %%
non_corporate_df = df.query("ABC == False and ABC_coursera == False and Udemy == False and no_concept == False").sort_values(by='Duration_in_seconds')
non_corporate_df
# Out:
#             product_sfid  product_id   mpid course_provider_platform_name__c  \
# 1301  01t8n000000JE6yAAG       10009  15708                      Skill Smith
# 1306  01t8n000000JE73AAG       10014  15544                      Skill Smith
# 1300  01t8n000000JE6wAAG       10007  15551                      Skill Smith
# 1298  01t8n000000JE6uAAG       10005  15553                      Skill Smith
# 4489          pr140tds7q       21046  18972                          Eduonix
# ...                  ...         ...    ...                              ...
# 1000  01t8n000000GwvPAAS        9054  16448   Lovely Professional University
# 981   01t8n000000GwuLAAS        8988  16687   Lovely Professional University
# 463   01t8n000000GrsuAAC        6842  15579                    Masters Union
# 530   01t8n000000GrxEAAS        7140  17371                           upGrad
# 84    01t8n000000GrYbAAK        5575  16657                        Edudelphi
#
#                                            product_name  course_level  \
# 1301                     Angular Master Program Offline      Advanced
# 1306                 Master React Native Program Online      Advanced
# 1300                       Java Booster Program Offline      Advanced
# 1298  Full Stack Program (React JS and Node JS) Offline      Advanced
# 4489                   Business Analytics for Beginners      Beginner
# ...                                                 ...           ...
# 1000                                 BBA, LL.B. (Hons.)  Intermediate
# 981                                  B.A., LL.B.(Hons.)  Intermediate
# 463                             Undergraduate Programme      Beginner
# 530                 MBA Leading Business Transformation      Advanced
# 84             Certified Fraud Examiner Course in India      Advanced
#
#      duration_medium__c  course_duration__c   price__c  loan_amount__c  ...  \
# 1301            Minutes                 3.0        5.0       118000.00  ...
# 1306            Minutes                 3.0        9.0          777.29  ...
# 1300            Minutes                 3.0       15.0       118000.00  ...
# 1298            Minutes                 6.0       15.0         1295.48  ...
# 4489            Minutes                15.0    22488.0        22488.00  ...
# ...                 ...                 ...        ...             ...  ...
# 1000              Years                 5.0  1200000.0      1200000.00  ...
# 981               Years                 5.0  1200000.0      1200000.00  ...
# 463               Years                 6.0        NaN      2925000.00  ...
# 530              Months               585.0   365000.0      1344753.00  ...
# 84                  nan                 NaN        NaN          439.32  ...
#
#       skill_id     concepts Duration_in_seconds  Is_within_a_week  \
# 1301       111         5747        1.800000e+02              True
# 1306       111         5747        1.800000e+02              True
# 1300       213         6107        1.800000e+02              True
# 1298       213         6107        3.600000e+02              True
# 4489        66         4980        9.000000e+02              True
# ...        ...          ...                 ...               ...
# 1000       288  7743 , 7748        1.576800e+08             False
# 981        185         5547        1.576800e+08             False
# 463         35         6032        1.892160e+08             False
# 530        130         6213        1.538559e+09             False
# 84          18         5503                 NaN             False
#
#       Integration  concept_count  no_concept  Udemy  ABC_coursera    ABC
# 1301        False              1       False  False         False  False
# 1306        False              1       False  False         False  False
# 1300        False              1       False  False         False  False
# 1298        False              1       False  False         False  False
# 4489        False              1       False  False         False  False
# ...           ...            ...         ...    ...           ...    ...
# 1000        False              2       False  False         False  False
# 981         False              1       False  False         False  False
# 463         False              1       False  False         False  False
# 530         False              1       False  False         False  False
# 84          False              1       False  False         False  False
#
# [5176 rows x 21 columns]

# %%
non_corporate_0_df = df.query("ABC == False and Udemy == False and ABC_coursera == False and no_concept == True").sort_values(by='Duration_in_seconds')
non_corporate_0_df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 1305   01t8n000000JE72AAG       10013  16508                      Skill Smith
# 1299   01t8n000000JE6vAAG       10006  15552                      Skill Smith
# 17939          prtp1hfygz       34141  34051                         Certybox
# 14107          prlphxlqt8       31380  29980                     EBC Learning
# 6261           pr4vvkrab4       31390  29946                     EBC Learning
# ...                   ...         ...    ...                              ...
# 991    01t8n000000GwuqAAC        9019   2928   Lovely Professional University
# 462    01t8n000000GrstAAC        6841  16928                    Masters Union
# 545    01t8n000000GrxbAAC        7163  15767                           upGrad
# 11377          prfwoo5mcq       27775  25999                        IMI Delhi
# 149    01t8n000000GreMAAS        5940  14641              Fireblaze AI School
#
#                                             product_name  course_level  \
# 1305                 Master React Native Program Offline      Advanced
# 1299    Full Stack Program (React JS and Node JS) Online      Advanced
# 17939                                 Profile Assessment      Beginner
# 14107                       Introduction to Forms of IPR      Beginner
# 6261   Private Equity and Venture Capital: Mastering ...      Advanced
# ...                                                  ...           ...
# 991    B.Tech. (Computer Science Engineering - AI and...  Intermediate
# 462         UG Programme in Tech and Business Management  Intermediate
# 545    Post Graduate Diploma in Management (BIMTECH)\r\n      Advanced
# 11377       Post Graduate Diploma in Management (Online)      Advanced
# 149                                 SQL for Data Science      Advanced
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 1305             Minutes                 3.0       9.0          777.29  ...
# 1299             Minutes                 6.0      15.0         1295.48  ...
# 17939            Minutes                30.0       NaN        10618.00  ...
# 14107            Minutes                35.0    2950.0         2950.00  ...
# 6261             Minutes                42.0    5900.0         5900.00  ...
# ...                  ...                 ...       ...             ...  ...
# 991                Years                 4.0  760000.0       760000.00  ...
# 462                Years                 4.0       NaN      4368000.00  ...
# 545               Months                48.0       NaN       275000.00  ...
# 11377              Years                24.0  295000.0       295000.00  ...
# 149                  nan                 NaN       NaN         2499.00  ...
#
#        skill_id  concepts Duration_in_seconds  Is_within_a_week  Integration  \
# 1305        110       NaN               180.0              True        False
# 1299        106       NaN               360.0              True        False
# 17939        92       NaN              1800.0              True        False
# 14107       184       NaN              2100.0              True        False
# 6261         29       NaN              2520.0              True        False
# ...         ...       ...                 ...               ...          ...
# 991         164       NaN         126144000.0             False        False
# 462          37       NaN         126144000.0             False        False
# 545          42       NaN         126240768.0             False        False
# 11377        92       NaN         756864000.0             False        False
# 149         315       NaN                 NaN             False        False
#
#        concept_count  no_concept  Udemy  ABC_coursera    ABC
# 1305               0        True  False         False  False
# 1299               0        True  False         False  False
# 17939              0        True  False         False  False
# 14107              0        True  False         False  False
# 6261               0        True  False         False  False
# ...              ...         ...    ...           ...    ...
# 991                0        True  False         False  False
# 462                0        True  False         False  False
# 545                0        True  False         False  False
# 11377              0        True  False         False  False
# 149                0        True  False         False  False
#
# [1408 rows x 21 columns]

# %% [markdown]
# Ranking non_corporate

# %%
non_corporate_df = non_corporate_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
non_corporate_df['Rank'] = 600 - (non_corporate_df.index * 0.01)
non_corporate_df
# Out:
#             product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0     01t8n000000JE73AAG       10014  15544                      Skill Smith
# 1     01t8n000000JE6yAAG       10009  15708                      Skill Smith
# 2     01t8n000000JE6wAAG       10007  15551                      Skill Smith
# 3     01t8n000000JE6uAAG       10005  15553                      Skill Smith
# 4             pr140tds7q       21046  18972                          Eduonix
# ...                  ...         ...    ...                              ...
# 5171  01t8n000000GwvPAAS        9054  16448   Lovely Professional University
# 5172  01t8n000000GwuLAAS        8988  16687   Lovely Professional University
# 5173  01t8n000000GrsuAAC        6842  15579                    Masters Union
# 5174  01t8n000000GrxEAAS        7140  17371                           upGrad
# 5175  01t8n000000GrYbAAK        5575  16657                        Edudelphi
#
#                                            product_name  course_level  \
# 0                    Master React Native Program Online      Advanced
# 1                        Angular Master Program Offline      Advanced
# 2                          Java Booster Program Offline      Advanced
# 3     Full Stack Program (React JS and Node JS) Offline      Advanced
# 4                      Business Analytics for Beginners      Beginner
# ...                                                 ...           ...
# 5171                                 BBA, LL.B. (Hons.)  Intermediate
# 5172                                 B.A., LL.B.(Hons.)  Intermediate
# 5173                            Undergraduate Programme      Beginner
# 5174                MBA Leading Business Transformation      Advanced
# 5175           Certified Fraud Examiner Course in India      Advanced
#
#      duration_medium__c  course_duration__c   price__c  loan_amount__c  ...  \
# 0               Minutes                 3.0        9.0          777.29  ...
# 1               Minutes                 3.0        5.0       118000.00  ...
# 2               Minutes                 3.0       15.0       118000.00  ...
# 3               Minutes                 6.0       15.0         1295.48  ...
# 4               Minutes                15.0    22488.0        22488.00  ...
# ...                 ...                 ...        ...             ...  ...
# 5171              Years                 5.0  1200000.0      1200000.00  ...
# 5172              Years                 5.0  1200000.0      1200000.00  ...
# 5173              Years                 6.0        NaN      2925000.00  ...
# 5174             Months               585.0   365000.0      1344753.00  ...
# 5175                nan                 NaN        NaN          439.32  ...
#
#          concepts  Duration_in_seconds Is_within_a_week  Integration  \
# 0            5747         1.800000e+02             True        False
# 1            5747         1.800000e+02             True        False
# 2            6107         1.800000e+02             True        False
# 3            6107         3.600000e+02             True        False
# 4            4980         9.000000e+02             True        False
# ...           ...                  ...              ...          ...
# 5171  7743 , 7748         1.576800e+08            False        False
# 5172         5547         1.576800e+08            False        False
# 5173         6032         1.892160e+08            False        False
# 5174         6213         1.538559e+09            False        False
# 5175         5503                  NaN            False        False
#
#       concept_count  no_concept  Udemy  ABC_coursera    ABC    Rank
# 0                 1       False  False         False  False  600.00
# 1                 1       False  False         False  False  599.99
# 2                 1       False  False         False  False  599.98
# 3                 1       False  False         False  False  599.97
# 4                 1       False  False         False  False  599.96
# ...             ...         ...    ...           ...    ...     ...
# 5171              2       False  False         False  False  548.29
# 5172              1       False  False         False  False  548.28
# 5173              1       False  False         False  False  548.27
# 5174              1       False  False         False  False  548.26
# 5175              1       False  False         False  False  548.25
#
# [5176 rows x 22 columns]

# %%
non_corporate_0_df = non_corporate_0_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
non_corporate_0_df['Rank'] = 550 - (non_corporate_0_df.index * 0.01)
non_corporate_0_df
# Out:
#             product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0     01t8n000000JE72AAG       10013  16508                      Skill Smith
# 1     01t8n000000JE6vAAG       10006  15552                      Skill Smith
# 2             prtp1hfygz       34141  34051                         Certybox
# 3             prlphxlqt8       31380  29980                     EBC Learning
# 4             pr4vvkrab4       31390  29946                     EBC Learning
# ...                  ...         ...    ...                              ...
# 1403  01tTZ000000gwEnYAI       10496   5887      The Design Village Easebuzz
# 1404  01t8n000000GrstAAC        6841  16928                    Masters Union
# 1405  01t8n000000GrxbAAC        7163  15767                           upGrad
# 1406          prfwoo5mcq       27775  25999                        IMI Delhi
# 1407  01t8n000000GreMAAS        5940  14641              Fireblaze AI School
#
#                                            product_name  course_level  \
# 0                   Master React Native Program Offline      Advanced
# 1      Full Stack Program (React JS and Node JS) Online      Advanced
# 2                                    Profile Assessment      Beginner
# 3                          Introduction to Forms of IPR      Beginner
# 4     Private Equity and Venture Capital: Mastering ...      Advanced
# ...                                                 ...           ...
# 1403                           Graphics & Communication      Beginner
# 1404       UG Programme in Tech and Business Management  Intermediate
# 1405  Post Graduate Diploma in Management (BIMTECH)\r\n      Advanced
# 1406       Post Graduate Diploma in Management (Online)      Advanced
# 1407                               SQL for Data Science      Advanced
#
#      duration_medium__c  course_duration__c   price__c  loan_amount__c  ...  \
# 0               Minutes                 3.0        9.0          777.29  ...
# 1               Minutes                 6.0       15.0         1295.48  ...
# 2               Minutes                30.0        NaN        10618.00  ...
# 3               Minutes                35.0     2950.0         2950.00  ...
# 4               Minutes                42.0     5900.0         5900.00  ...
# ...                 ...                 ...        ...             ...  ...
# 1403              Years                 4.0  2200000.0      2200000.00  ...
# 1404              Years                 4.0        NaN      4368000.00  ...
# 1405             Months                48.0        NaN       275000.00  ...
# 1406              Years                24.0   295000.0       295000.00  ...
# 1407                nan                 NaN        NaN         2499.00  ...
#
#       concepts  Duration_in_seconds Is_within_a_week  Integration  \
# 0          NaN                180.0             True        False
# 1          NaN                360.0             True        False
# 2          NaN               1800.0             True        False
# 3          NaN               2100.0             True        False
# 4          NaN               2520.0             True        False
# ...        ...                  ...              ...          ...
# 1403       NaN          126144000.0            False        False
# 1404       NaN          126144000.0            False        False
# 1405       NaN          126240768.0            False        False
# 1406       NaN          756864000.0            False        False
# 1407       NaN                  NaN            False        False
#
#       concept_count  no_concept  Udemy  ABC_coursera    ABC    Rank
# 0                 0        True  False         False  False  550.00
# 1                 0        True  False         False  False  549.99
# 2                 0        True  False         False  False  549.98
# 3                 0        True  False         False  False  549.97
# 4                 0        True  False         False  False  549.96
# ...             ...         ...    ...           ...    ...     ...
# 1403              0        True  False         False  False  535.97
# 1404              0        True  False         False  False  535.96
# 1405              0        True  False         False  False  535.95
# 1406              0        True  False         False  False  535.94
# 1407              0        True  False         False  False  535.93
#
# [1408 rows x 22 columns]

# %% [markdown]
# Ranking ABC

# %%
abc_coursera_0_df = abc_coursera_0_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
abc_coursera_0_df['Rank'] = 510 - (abc_coursera_0_df.index * 0.01)
abc_coursera_0_df
# Out:
#      product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      prai5zubue       14804  14664                         Coursera
# 1      prj50a1zil       16862  11768                         Coursera
# 2      prpp90zk8u       18219  14252                         Coursera
# 3      prrtje596c       15301  14737                         Coursera
# 4      przvd8bx2g       19471  10883                         Coursera
# ...           ...         ...    ...                              ...
# 1047   pruyymchl0       22643  20728                         Coursera
# 1048   prw7ivef80       15593  20515                         Coursera
# 1049   prwbrwx3rr       22534  20612                         Coursera
# 1050   prx3ri6kt5       17517  20952                         Coursera
# 1051   przy2ytv16       21460  19450                         Coursera
#
#                                            product_name  course_level  \
# 0     Static Website Hosting and Cross-Region Replic...      Beginner
# 1                          Fast Typer Game using Pygame      Beginner
# 2     Recreate the First Ever Easter Egg from Advent...      Beginner
# 3                                 Style Images with CSS  Intermediate
# 4                    Creating Custom Callbacks in Keras  Intermediate
# ...                                                 ...           ...
# 1047                  Transforming the Fashion Business      Beginner
# 1048  Hotel Digital Marketing and Social Media Strategy      Beginner
# 1049                     Google Advanced Data Analytics      Beginner
# 1050                                    jQuery Tutorial      Beginner
# 1051  Database Design and Operational Business Intel...      Beginner
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0                 Hours                 0.1       1.0             0.0  ...
# 1                 Hours                 0.1       1.0             0.0  ...
# 2                 Hours                 0.1       1.0             0.0  ...
# 3                 Hours                 0.1       1.0             0.0  ...
# 4                 Hours                 0.1       1.0             0.0  ...
# ...                 ...                 ...       ...             ...  ...
# 1047              Hours                 NaN       1.0             0.0  ...
# 1048              Hours                 NaN       1.0             0.0  ...
# 1049              Hours                 NaN       1.0             0.0  ...
# 1050              Hours                 NaN       1.0             0.0  ...
# 1051              Hours                 NaN       1.0             0.0  ...
#
#       skill_id  concepts Duration_in_seconds  Is_within_a_week  Integration  \
# 0           55       NaN               360.0              True        False
# 1          213       NaN               360.0              True        False
# 2          313       NaN               360.0              True        False
# 3          111       NaN               360.0              True        False
# 4           69       NaN               360.0              True        False
# ...        ...       ...                 ...               ...          ...
# 1047       262       NaN                 NaN             False        False
# 1048       107       NaN                 NaN             False        False
# 1049       213       NaN                 NaN             False        False
# 1050       107       NaN                 NaN             False        False
# 1051        66       NaN                 NaN             False        False
#
#       concept_count  no_concept  Udemy  ABC_coursera    Rank
# 0                 0        True  False          True  510.00
# 1                 0        True  False          True  509.99
# 2                 0        True  False          True  509.98
# 3                 0        True  False          True  509.97
# 4                 0        True  False          True  509.96
# ...             ...         ...    ...           ...     ...
# 1047              0        True  False          True  499.53
# 1048              0        True  False          True  499.52
# 1049              0        True  False          True  499.51
# 1050              0        True  False          True  499.50
# 1051              0        True  False          True  499.49
#
# [1052 rows x 21 columns]

# %%
abc_coursera_df = abc_coursera_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
abc_coursera_df['Rank'] = 525 - (abc_coursera_df.index * 0.01)
abc_coursera_df
# Out:
#      product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      pr191gx295       19528   9449                         Coursera
# 1      pr1mfracxt       20031  12536                         Coursera
# 2      prabvbpkbt       15387  11282                         Coursera
# 3      priofhwu49       14375  10553                         Coursera
# 4      prmlysrlzl       19486  13933                         Coursera
# ...           ...         ...    ...                              ...
# 5449   prze8tlgz8       22603  20686                         Coursera
# 5450   przhd3q074       22533  20611                         Coursera
# 5451   przixvhfo5       22618  20702                         Coursera
# 5452   przqenabsa       22672  20761                         Coursera
# 5453   pro59osu24       22748  20841                         Coursera
#
#                                            product_name  course_level  \
# 0                    Analyze Text Data with Yellowbrick  Intermediate
# 1                Improving Math Engagement with Prodigy      Beginner
# 2     Design and Develop an Obstacles Game using Pyg...  Intermediate
# 3     Create a Boggle Word Solver using recursion in...  Intermediate
# 4     Predict Gas Guzzlers using a Neural Net Model ...  Intermediate
# ...                                                 ...           ...
# 5449            Digital Marketing Strategy and Planning      Beginner
# 5450               Learn Mandarin Chinese: Intermediate      Beginner
# 5451                        Privacy and Standardisation      Beginner
# 5452                Teach English: Intermediate Grammar      Beginner
# 5453                          Academic English: Writing      Beginner
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0                 Hours                 0.1       1.0             0.0  ...
# 1                 Hours                 0.1       1.0             0.0  ...
# 2                 Hours                 0.1       1.0             0.0  ...
# 3                 Hours                 0.1       1.0             0.0  ...
# 4                 Hours                 0.1       1.0             0.0  ...
# ...                 ...                 ...       ...             ...  ...
# 5449              Hours                 NaN       1.0             0.0  ...
# 5450              Hours                 NaN       1.0             0.0  ...
# 5451              Hours                 NaN       1.0             0.0  ...
# 5452              Hours                 NaN       1.0             0.0  ...
# 5453              Hours                 NaN       1.0             0.0  ...
#
#       skill_id            concepts Duration_in_seconds  Is_within_a_week  \
# 0           66                4887               360.0              True
# 1          130                6061               360.0              True
# 2          299                6801               360.0              True
# 3          299                6800               360.0              True
# 4           62  4607 , 4905 , 6669               360.0              True
# ...        ...                 ...                 ...               ...
# 5449       129                4540                 NaN             False
# 5450       130         6061 , 6213                 NaN             False
# 5451        64                4934                 NaN             False
# 5452       130                6213                 NaN             False
# 5453       130                6213                 NaN             False
#
#       Integration  concept_count  no_concept  Udemy  ABC_coursera    Rank
# 0           False              1       False  False          True  525.00
# 1           False              1       False  False          True  524.99
# 2           False              1       False  False          True  524.98
# 3           False              1       False  False          True  524.97
# 4           False              3       False  False          True  524.96
# ...           ...            ...         ...    ...           ...     ...
# 5449        False              1       False  False          True  470.51
# 5450        False              2       False  False          True  470.50
# 5451        False              1       False  False          True  470.49
# 5452        False              1       False  False          True  470.48
# 5453        False              1       False  False          True  470.47
#
# [5454 rows x 21 columns]

# %%
abc_df = abc_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
abc_df['Rank'] = 425 - (abc_df.index * 0.01)
abc_df
# Out:
#      product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      pr6ggb6crn       13720   9169                              GVC
# 1      prz439vl3r       12700   8151                              GVC
# 2      prwjj6sgg7       13783  19765                              GVC
# 3      pr0ramdk0c       13667   9117                              GVC
# 4      prnl3tqozi       13112   8562                              GVC
# ...           ...         ...    ...                              ...
# 2486   przpiipjwv       22448  20398                              GVC
# 2487   przsnkj6o1       22075  20025                              GVC
# 2488   przurvq0im       22264  20214                              GVC
# 2489   przvahytsh       22157  20107                              GVC
# 2490   przyu0in9m       22779  20873                              GVC
#
#                                            product_name  course_level  \
# 0               Sharing Multiple Screens Simultaneously      Beginner
# 1                     Scheduling a Meeting with Outlook      Beginner
# 2     Recognizing and Addressing Micro-behaviors in ...      Beginner
# 3                                     Closed Captioning      Beginner
# 4                                   Sharing Your Screen      Beginner
# ...                                                 ...           ...
# 2486  Outlook on the Web: Using & Managing the Calendar      Beginner
# 2487  Configure Windows Defender on a Windows System...      Beginner
# 2488                 CompTIA Linux+: SELinux & AppArmor  Intermediate
# 2489      Outlook 2016 (Mac): Sending & Receiving Email      Beginner
# 2490            Microsoft Azure Services and Lifecycles      Beginner
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0                 Hours                0.01       1.0             0.0  ...
# 1                 Hours                0.01       1.0             0.0  ...
# 2                 Hours                0.01       1.0             0.0  ...
# 3                 Hours                0.02       1.0             0.0  ...
# 4                 Hours                0.02       1.0             0.0  ...
# ...                 ...                 ...       ...             ...  ...
# 2486              Hours                 NaN       1.0             0.0  ...
# 2487              Hours                 NaN       1.0             0.0  ...
# 2488              Hours                 NaN       1.0             0.0  ...
# 2489              Hours                 NaN       1.0             0.0  ...
# 2490              Hours                 NaN       1.0             0.0  ...
#
#       concepts  Duration_in_seconds Is_within_a_week  Integration  \
# 0         5002                 36.0             True        False
# 1         5002                 36.0             True        False
# 2         4888                 36.0             True        False
# 3         5002                 72.0             True        False
# 4         5002                 72.0             True        False
# ...        ...                  ...              ...          ...
# 2486      5002                  NaN            False        False
# 2487      6492                  NaN            False        False
# 2488      6301                  NaN            False        False
# 2489      5002                  NaN            False        False
# 2490      5947                  NaN            False        False
#
#       concept_count  no_concept  Udemy  ABC_coursera   ABC    Rank
# 0                 1       False  False         False  True  425.00
# 1                 1       False  False         False  True  424.99
# 2                 1       False  False         False  True  424.98
# 3                 1       False  False         False  True  424.97
# 4                 1       False  False         False  True  424.96
# ...             ...         ...    ...           ...   ...     ...
# 2486              1       False  False         False  True  400.14
# 2487              1       False  False         False  True  400.13
# 2488              1       False  False         False  True  400.12
# 2489              1       False  False         False  True  400.11
# 2490              1       False  False         False  True  400.10
#
# [2491 rows x 22 columns]

# %%
abc_0_df = abc_0_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
abc_0_df['Rank'] = 350 - (abc_0_df.index * 0.01)
abc_0_df
# Out:
#    product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0    prkbticw4m       13061   8511                              GVC
# 1    prb7wcf1w1       21985  19935                              GVC
# 2    pr8l3huhxx       13084   8534                              GVC
# 3    prk4u6jgyu       12654   8105                              GVC
# 4    prrkijqjx1       12775   8226                              GVC
# ..          ...         ...    ...                              ...
# 83   prnkuvtsec       22777  20871                              GVC
# 84   prp279k851       21916  19866                              GVC
# 85   prxblezp5c       22763  20857                              GVC
# 86   prxxilay2h       21520  19565                              GVC
# 87   przdn85o2g       21964  19914                              GVC
#
#                                          product_name course_level  \
# 0                       Is Your Internet FAST Enough?     Beginner
# 1                Creating a Coaching at Scale Program     Beginner
# 2                 Prospecting: Panning for Sales Gold     Beginner
# 3                Introduction to Power Virtual Agents     Beginner
# 4                       The facts about Fact checking     Beginner
# ..                                                ...          ...
# 83  Azure Data Lake Storage Gen2 and Data Streamin...     Beginner
# 84                                      Collaboration     Beginner
# 85  Data Manipulation at Scale: Systems and Algori...     Beginner
# 86   Project Scheduling:  Estimate Activity Durations     Beginner
# 87  Talent Development and Transformation Leadercamps     Beginner
#
#    duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0               Hours                0.11       1.0             0.0  ...
# 1               Hours                0.15       1.0             0.0  ...
# 2               Hours                0.20       1.0             0.0  ...
# 3               Hours                0.22       1.0             0.0  ...
# 4               Hours                0.23       1.0             0.0  ...
# ..                ...                 ...       ...             ...  ...
# 83              Hours                 NaN       1.0             0.0  ...
# 84              Hours                 NaN       1.0             0.0  ...
# 85              Hours                 NaN       1.0             0.0  ...
# 86              Hours                 NaN       1.0             0.0  ...
# 87              Hours                 NaN       1.0             0.0  ...
#
#     concepts  Duration_in_seconds Is_within_a_week  Integration  \
# 0        NaN                396.0             True        False
# 1        NaN                540.0             True        False
# 2        NaN                720.0             True        False
# 3        NaN                792.0             True        False
# 4        NaN                828.0             True        False
# ..       ...                  ...              ...          ...
# 83       NaN                  NaN            False        False
# 84       NaN                  NaN            False        False
# 85       NaN                  NaN            False        False
# 86       NaN                  NaN            False        False
# 87       NaN                  NaN            False        False
#
#     concept_count  no_concept  Udemy  ABC_coursera   ABC    Rank
# 0               0        True  False         False  True  350.00
# 1               0        True  False         False  True  349.99
# 2               0        True  False         False  True  349.98
# 3               0        True  False         False  True  349.97
# 4               0        True  False         False  True  349.96
# ..            ...         ...    ...           ...   ...     ...
# 83              0        True  False         False  True  349.17
# 84              0        True  False         False  True  349.16
# 85              0        True  False         False  True  349.15
# 86              0        True  False         False  True  349.14
# 87              0        True  False         False  True  349.13
#
# [88 rows x 22 columns]

# %% [markdown]
# Ranking Udemy_courses

# %%
udemy_df = udemy_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
udemy_df['Rank'] = 300 - (udemy_df.index * 0.01)
udemy_df
# Out:
#      product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      pr0y1ipl5c       31002  29558                            Udemy
# 1      pr3362upkq       31204  29760                            Udemy
# 2      prcdxzvedk       31166  29722                            Udemy
# 3      prgw6evcc9       31137  29693                            Udemy
# 4      prhzt6h99t       31340  29896                            Udemy
# ...           ...         ...    ...                              ...
# 5257     5OqCv2Pw       25043  23264                            Udemy
# 5258     3TgEl5Xn       27077  25300                            Udemy
# 5259   prbgu9bqhd       33590  33488                            Udemy
# 5260   prpnv1ebe6       33589  33487                            Udemy
# 5261   prz666dzq4       29616  28785                            Udemy
#
#                                            product_name  course_level  \
# 0     Project Management Certified Associate: CAPM P...  Intermediate
# 1     SAFE 6.0 Scrum Master - Certified SAFE 6 Scrum...      Beginner
# 2     ISO 22301Business Continuity Management (BCM &...      Beginner
# 3     Project Management - Theory of Constraints way...      Beginner
# 4        Life Insurance & Annuity Ultimate Buyers Guide      Beginner
# ...                                                 ...           ...
# 5257  Selenium Java : Beginner to Advanced [Live Pro...      Beginner
# 5258  SAP ABAP, OOPS, CROSSAPP, WEBDYNPRO, WORKFLOW,...      Beginner
# 5259  KPI and metrics for Management Consultants & M...      Advanced
# 5260  Critical Thinker Academy: Learn to Think Like ...  Intermediate
# 5261  ISC2 Certified in Cybersecurity (CC) Full Prac...      Beginner
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 0                 Hours                 0.1       0.0         23850.0
# 1                 Hours                 0.1       0.0         23850.0
# 2                 Hours                 0.1       0.0         23850.0
# 3                 Hours                 0.1       0.0         23850.0
# 4                 Hours                 0.1       0.0         23850.0
# ...                 ...                 ...       ...             ...
# 5257            Minutes             11327.0   23850.0         23850.0
# 5258            Minutes             11547.0   23850.0         23850.0
# 5259              Hours               334.0   22842.0         23850.0
# 5260              Hours              1173.0   22842.0         23850.0
# 5261            Minutes                 NaN   23850.0         23850.0
#
#       inr_amount__c  skill_id  \
# 0           23850.0        37
# 1           23850.0       263
# 2           23850.0        40
# 3           23850.0        37
# 4           23850.0        45
# ...             ...       ...
# 5257        23850.0       103
# 5258        23850.0       316
# 5259        23850.0        63
# 5260        23850.0       314
# 5261        23850.0       130
#
#                                                concepts  Duration_in_seconds  \
# 0                                                  4590                360.0
# 1                                                  5724                360.0
# 2                                           4586 , 5436                360.0
# 3                                                  4590                360.0
# 4                                                  4568                360.0
# ...                                                 ...                  ...
# 5257                                        6817 , 6849             679620.0
# 5258                                               6938             692820.0
# 5259                                               5506            1202400.0
# 5260  5025 , 7005 , 7006 , 7007 , 7008 , 7009 , 7010...            4222800.0
# 5261                                               6063                  NaN
#
#       Is_within_a_week  Integration  concept_count  no_concept  Udemy    Rank
# 0                 True        False              1       False   True  300.00
# 1                 True        False              1       False   True  299.99
# 2                 True        False              2       False   True  299.98
# 3                 True        False              1       False   True  299.97
# 4                 True        False              1       False   True  299.96
# ...                ...          ...            ...         ...    ...     ...
# 5257             False        False              2       False   True  247.43
# 5258             False        False              1       False   True  247.42
# 5259             False        False              1       False   True  247.41
# 5260             False        False             10       False   True  247.40
# 5261             False        False              1       False   True  247.39
#
# [5262 rows x 20 columns]

# %%
udemy_0_df = udemy_0_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
udemy_0_df['Rank'] = 200 - (udemy_0_df.index * 0.01)
udemy_0_df
# Out:
#    product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0    prckjmlvhq       29660  28123                            Udemy
# 1    prw95gpdwy       28285  26751                            Udemy
# 2    pr04rriz87       29480  27943                            Udemy
# 3    pr9dhr23kk       29614  28077                            Udemy
# 4    pr3vmyyxgg       30260  28723                            Udemy
# 5    preelbycur       29646  28109                            Udemy
# 6    prwkzmf60z       30271  28734                            Udemy
# 7    prllet9osu       30939  29495                            Udemy
# 8    prau0sb5p5       29406  27869                            Udemy
# 9    prxd7fln6n       29050  27513                            Udemy
# 10   prxn9li6ss       31017  29573                            Udemy
# 11     8ObDt0Ty       23451  21672                            Udemy
# 12   pr982673yy       27946  26412                            Udemy
# 13     1YjTw3Oy       23767  21988                            Udemy
# 14   prgh28omad       30150  28613                            Udemy
# 15     7BpKm9Gj       23448  21669                            Udemy
# 16   prdv4gup74       28335  26801                            Udemy
# 17   pr4gzf4zqb       27977  26443                            Udemy
# 18   pr3a8wqtda       29919  28382                            Udemy
# 19   prxnxpgnvw       28120  26586                            Udemy
# 20   prtq3w17ir       29930  28393                            Udemy
# 21     5TgAx9Cg       22983  21204                            Udemy
# 22   pr9d9b50m9       28381  26847                            Udemy
# 23     2FeBo7Oj       25745  23967                            Udemy
# 24     5YrGr8Hy       22895  21116                            Udemy
# 25     1FkNf0Wo       22871  21092                            Udemy
#
#                                          product_name  course_level  \
# 0              Managing a Global Team with Confidence      Beginner
# 1   Mastering Collaboration: Work together for the...      Beginner
# 2                                Effective Leadership      Beginner
# 3         Developing Your Executive Leadership Skills  Intermediate
# 4          Chaos Engineering using Azure Chaos Studio      Beginner
# 5   Leadership - Rise of a Leader (Lead people wit...      Beginner
# 6   Leadership Style: Discover & Maximize Your Lea...      Beginner
# 7   Manage Change Through Collaboration and Team Work      Beginner
# 8                   Leadership Become a better leader      Beginner
# 9                              Smart Tips: Leadership      Beginner
# 10          Collaboration with Emotional Intelligence  Intermediate
# 11  Master SWOT Analysis  and  Business Strategy f...      Beginner
# 12        How to Manage & Influence Your Virtual Team      Beginner
# 13  Web Performance In Practice: Master Core Web V...      Beginner
# 14  Web Performance In Practice: Master Core Web V...      Beginner
# 15  Master PMP Cost Management: Plan, Budget, Esti...      Beginner
# 16  Leadership: Growth Mindset for Leadership and ...      Beginner
# 17  Quality Management for Business Excellence (Ac...      Beginner
# 18  Business English Essentials for Leadership and...  Intermediate
# 19  Management & Leadership Skills: When To Manage...      Beginner
# 20  Product Owner II for Agile Intermediate: Certi...      Beginner
# 21  Certified Key Performance Indicators Professio...      Beginner
# 22  Informed Risk Taking : Risk Management Process...      Beginner
# 23  AWS Technical Essentials  - Hands-On Training ...      Beginner
# 24  Automated Cryptocurrency Portfolio Investing w...      Beginner
# 25  ACCA MA (F2) A Complete Course on Management A...      Beginner
#
#    duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 0             Minutes                35.0   23850.0         23850.0
# 1             Minutes                48.0   23850.0         23850.0
# 2             Minutes                49.0   23850.0         23850.0
# 3             Minutes                52.0   23850.0         23850.0
# 4             Minutes                74.0   23850.0         23850.0
# 5             Minutes                91.0   23850.0         23850.0
# 6             Minutes               100.0   23850.0         23850.0
# 7             Minutes               102.0       0.0         23850.0
# 8             Minutes               133.0   23850.0         23850.0
# 9             Minutes               172.0   23850.0         23850.0
# 10            Minutes               184.0       0.0         23850.0
# 11            Minutes               185.0   23850.0         23850.0
# 12            Minutes               192.0   23850.0         23850.0
# 13            Minutes               204.0   23850.0         23850.0
# 14            Minutes               204.0   23850.0         23850.0
# 15            Minutes               224.0   23850.0         23850.0
# 16            Minutes               228.0   23850.0         23850.0
# 17            Minutes               240.0   23850.0         23850.0
# 18            Minutes               319.0   23850.0         23850.0
# 19            Minutes               346.0   23850.0         23850.0
# 20            Minutes               379.0   23850.0         23850.0
# 21            Minutes               448.0   23850.0         23850.0
# 22            Minutes               532.0   23850.0         23850.0
# 23            Minutes               866.0   23850.0         23850.0
# 24            Minutes              1931.0   23850.0         23850.0
# 25            Minutes              2014.0   23850.0         23850.0
#
#     inr_amount__c  skill_id concepts  Duration_in_seconds  Is_within_a_week  \
# 0         23850.0       255      NaN               2100.0              True
# 1         23850.0       262      NaN               2880.0              True
# 2         23850.0       255      NaN               2940.0              True
# 3         23850.0       255      NaN               3120.0              True
# 4         23850.0       261      NaN               4440.0              True
# 5         23850.0       255      NaN               5460.0              True
# 6         23850.0       255      NaN               6000.0              True
# 7         23850.0       262      NaN               6120.0              True
# 8         23850.0       255      NaN               7980.0              True
# 9         23850.0       255      NaN              10320.0              True
# 10        23850.0       262      NaN              11040.0              True
# 11        23850.0        49      NaN              11100.0              True
# 12        23850.0       262      NaN              11520.0              True
# 13        23850.0       261      NaN              12240.0              True
# 14        23850.0       106      NaN              12240.0              True
# 15        23850.0       261      NaN              13440.0              True
# 16        23850.0       255      NaN              13680.0              True
# 17        23850.0       263      NaN              14400.0              True
# 18        23850.0       255      NaN              19140.0              True
# 19        23850.0       255      NaN              20760.0              True
# 20        23850.0        36      NaN              22740.0              True
# 21        23850.0       261      NaN              26880.0              True
# 22        23850.0       406      NaN              31920.0              True
# 23        23850.0        44      NaN              51960.0              True
# 24        23850.0        49      NaN             115860.0              True
# 25        23850.0        49      NaN             120840.0              True
#
#     Integration  concept_count  no_concept  Udemy    Rank
# 0         False              0        True   True  200.00
# 1         False              0        True   True  199.99
# 2         False              0        True   True  199.98
# 3         False              0        True   True  199.97
# 4         False              0        True   True  199.96
# 5         False              0        True   True  199.95
# 6         False              0        True   True  199.94
# 7         False              0        True   True  199.93
# 8         False              0        True   True  199.92
# 9         False              0        True   True  199.91
# 10        False              0        True   True  199.90
# 11        False              0        True   True  199.89
# 12        False              0        True   True  199.88
# 13        False              0        True   True  199.87
# 14        False              0        True   True  199.86
# 15        False              0        True   True  199.85
# 16        False              0        True   True  199.84
# 17        False              0        True   True  199.83
# 18        False              0        True   True  199.82
# 19        False              0        True   True  199.81
# 20        False              0        True   True  199.80
# 21        False              0        True   True  199.79
# 22        False              0        True   True  199.78
# 23        False              0        True   True  199.77
# 24        False              0        True   True  199.76
# 25        False              0        True   True  199.75

# %% [markdown]
# Concanating all the dataframe

# %%
pieces = {"x": non_corporate_df,"x1":non_corporate_0_df, "y":abc_coursera_df,"y1":abc_coursera_0_df,"y2": abc_df,"y3": abc_0_df, "z": udemy_df,"z1": udemy_0_df}
result = pd.concat(pieces)
result.to_excel("C:\\Users\\taslim.siddiqui\\Downloads\\Recorating_09-05-2025.xlsx")
print(result)
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# x  0   01t8n000000JE73AAG       10014  15544                      Skill Smith
#    1   01t8n000000JE6yAAG       10009  15708                      Skill Smith
#    2   01t8n000000JE6wAAG       10007  15551                      Skill Smith
#    3   01t8n000000JE6uAAG       10005  15553                      Skill Smith
#    4           pr140tds7q       21046  18972                          Eduonix
# ...                   ...         ...    ...                              ...
# z1 21            5TgAx9Cg       22983  21204                            Udemy
#    22          pr9d9b50m9       28381  26847                            Udemy
#    23            2FeBo7Oj       25745  23967                            Udemy
#    24            5YrGr8Hy       22895  21116                            Udemy
#    25            1FkNf0Wo       22871  21092                            Udemy
#
#                                             product_name course_level  \
# x  0                  Master React Native Program Online     Advanced
#    1                      Angular Master Program Offline     Advanced
#    2                        Java Booster Program Offline     Advanced
#    3   Full Stack Program (React JS and Node JS) Offline     Advanced
#    4                    Business Analytics for Beginners     Beginner
# ...                                                  ...          ...
# z1 21  Certified Key Performance Indicators Professio...     Beginner
#    22  Informed Risk Taking : Risk Management Process...     Beginner
#    23  AWS Technical Essentials  - Hands-On Training ...     Beginner
#    24  Automated Cryptocurrency Portfolio Investing w...     Beginner
#    25  ACCA MA (F2) A Complete Course on Management A...     Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# x  0             Minutes                 3.0       9.0          777.29  ...
#    1             Minutes                 3.0       5.0       118000.00  ...
#    2             Minutes                 3.0      15.0       118000.00  ...
#    3             Minutes                 6.0      15.0         1295.48  ...
#    4             Minutes                15.0   22488.0        22488.00  ...
# ...                  ...                 ...       ...             ...  ...
# z1 21            Minutes               448.0   23850.0        23850.00  ...
#    22            Minutes               532.0   23850.0        23850.00  ...
#    23            Minutes               866.0   23850.0        23850.00  ...
#    24            Minutes              1931.0   23850.0        23850.00  ...
#    25            Minutes              2014.0   23850.0        23850.00  ...
#
#        concepts  Duration_in_seconds Is_within_a_week  Integration  \
# x  0       5747                180.0             True        False
#    1       5747                180.0             True        False
#    2       6107                180.0             True        False
#    3       6107                360.0             True        False
#    4       4980                900.0             True        False
# ...         ...                  ...              ...          ...
# z1 21       NaN              26880.0             True        False
#    22       NaN              31920.0             True        False
#    23       NaN              51960.0             True        False
#    24       NaN             115860.0             True        False
#    25       NaN             120840.0             True        False
#
#        concept_count  no_concept  Udemy  ABC_coursera    ABC    Rank
# x  0               1       False  False         False  False  600.00
#    1               1       False  False         False  False  599.99
#    2               1       False  False         False  False  599.98
#    3               1       False  False         False  False  599.97
#    4               1       False  False         False  False  599.96
# ...              ...         ...    ...           ...    ...     ...
# z1 21              0        True   True           NaN    NaN  199.79
#    22              0        True   True           NaN    NaN  199.78
#    23              0        True   True           NaN    NaN  199.77
#    24              0        True   True           NaN    NaN  199.76
#    25              0        True   True           NaN    NaN  199.75
#
# [20957 rows x 22 columns]

# %% [markdown]
# testing

# %%
result_reset = result.reset_index()
result_reset['final_rank'] = 600 - (result_reset.index * 0.01)
#result_reset.to_excel("/Users/romitbenkar/Downloads/Recorating_21-03-2025.xlsx")

# %%
import pandas as pd

# Define the dataset
data = {
    "duration_seconds": [2000, 5890, 5739, 6746, 2000, 2000, 5890, 2000, 67383, 784892, 6474, 5890],
    "Integration": [True, True, False, True, True, True, True, True, False, True, False, False],
    "Price": [5943843, 7744, 4744, 84433, 74484, 4438, 46746, 73782, 74383, 74873, 764673, 64473]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort by the three columns in the desired order: duration_seconds, Integration (descending), Price
df = df.sort_values(
    by=["duration_seconds", "Integration", "Price"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
df['Rank'] = 600 - (df.index * 0.01)

# Display the resulting DataFrame
print(df)
# Out:
#     duration_seconds  Integration    Price    Rank
# 0               2000         True     4438  600.00
# 1               2000         True    73782  599.99
# 2               2000         True    74484  599.98
# 3               2000         True  5943843  599.97
# 4               5739        False     4744  599.96
# 5               5890         True     7744  599.95
# 6               5890         True    46746  599.94
# 7               5890        False    64473  599.93
# 8               6474        False   764673  599.92
# 9               6746         True    84433  599.91
# 10             67383        False    74383  599.90
# 11            784892         True    74873  599.89

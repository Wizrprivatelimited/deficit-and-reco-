# %% [markdown]
# **Time Converter

# %%
import pandas as pd
#load excel
df = pd.read_csv("C:\\Users\\taslim.siddiqui\\Downloads\\production_recoRatingDataRecords (9).csv")
#df=pd.read_excel("//Users//romitbenkar//Desktop//Office//07-11-2024//other_output.xlsx")

# Replace 'apple' with 'orange' and 'banana' with 'grape' in column 'B'
df['duration_medium__c'] = df['duration_medium__c'].replace({'Day': 'Days', 'Month': 'Months','Year':'Years'})

# Define conversion factors to seconds for each mode
conversion_factors = {
    'years': 365 * 24 * 60 * 60,        # approximate (ignores leap years)
    'months': 30.44 * 24 * 60 * 60,     # average month
    'weeks': 7 * 24 * 60 * 60,
    'days': 24 * 60 * 60,
    'hours': 60 * 60,
    'minutes': 60
}

df['duration_medium__c']=df['duration_medium__c'].astype(str)


# Function to convert duration based on the mode
def convert_to_seconds(row):
    duration = row['course_duration__c']
    mode = row['duration_medium__c'].strip().lower()  # normalize to lowercase
    return duration * conversion_factors.get(mode, 1)  # Default to 1 if mode is not found

# Apply the conversion function to each row
df['Duration_in_seconds'] = df.apply(convert_to_seconds, axis=1)

# Add a column that checks if the duration in seconds is less than or equal to a week
df['Is_within_a_week'] = df['Duration_in_seconds'] <= 7 * 24 * 60 * 60

# Save the result back to Excel
#df.to_excel('//Users//romitbenkar//Desktop//Office//19-11-24//timeconvertoutput.xlsx', index=False)
df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      01t8n000000GrJPAA0        4641  17890             Amity Future Academy
# 1      01t8n000000GrJQAA0        4642  16262             Amity Future Academy
# 2      01t8n000000GrJRAA0        4643  16885             Amity Future Academy
# 3      01t8n000000GrJSAA0        4644  17637             Amity Future Academy
# 4      01t8n000000GrJTAA0        4645  15978             Amity Future Academy
# ...                   ...         ...    ...                              ...
# 20940          przzd0g0p1       28069  26535                            Udemy
# 20941          przzj4igrr       14130  14308                         Coursera
# 20942          przzltt2yl       34946  35729                              GVC
# 20943          przzvn6z59       14710  11674                         Coursera
# 20944          przzxluxi8       20241  12028                         Coursera
#
#                                             product_name  course_level  \
# 0      PG Program in Digital Marketing Strategies (PG...      Advanced
# 1              PG Program in Product Management (PGP-PM)      Advanced
# 2                    Post Graduate Diploma in Management      Advanced
# 3                    Post Graduate Diploma in Management      Advanced
# 4      Post Graduate Program in Big Data Architecture...      Advanced
# ...                                                  ...           ...
# 20940  Email Marketing: Subscriber List Growth With C...      Beginner
# 20941                      Resourcing a Project Schedule      Beginner
# 20942                      Programming Languages, Part B  Intermediate
# 20943  Exam Prep CKA: Certified Kubernetes Administrator  Intermediate
# 20944                               Generative AI Primer      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 0                 Months               12.00       NaN        170000.0
# 1                 Months               12.00       NaN        215000.0
# 2                 Months                6.00       NaN        120000.0
# 3                 Months                6.00       NaN        120000.0
# 4                 Months                6.00       NaN        100000.0
# ...                  ...                 ...       ...             ...
# 20940            Minutes              215.00   23850.0         23850.0
# 20941              Hours                0.30       1.0             0.0
# 20942              Hours               18.00       NaN             1.0
# 20943              Hours               18.93       1.0             0.0
# 20944              Hours                1.48       1.0             0.0
#
#        inr_amount__c  skill_id concepts  Duration_in_seconds  Is_within_a_week
# 0           170000.0       120      NaN           31560192.0             False
# 1           215000.0        36     5336           31560192.0             False
# 2           120000.0        98     4550           15780096.0             False
# 3           120000.0        39      NaN           15780096.0             False
# 4           100000.0        63     5652           15780096.0             False
# ...              ...       ...      ...                  ...               ...
# 20940        23850.0       107     6615              12900.0              True
# 20941            0.0        39     6101               1080.0              True
# 20942            1.0       164     6893              64800.0              True
# 20943            0.0       107      NaN              68148.0              True
# 20944            0.0       317      NaN               5328.0              True
#
# [20945 rows x 15 columns]

# %% [markdown]
# Integration

# %%
values_to_check = ['Henry Harvin Education','Henry Harvin','Guvi Geeks','Edujournal','Sharpener','Business Toys Skills School']

# Check if any values in the DataFrame are in the list
df['Integration'] = df['course_provider_platform_name__c'].isin(values_to_check)
df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      01t8n000000GrJPAA0        4641  17890             Amity Future Academy
# 1      01t8n000000GrJQAA0        4642  16262             Amity Future Academy
# 2      01t8n000000GrJRAA0        4643  16885             Amity Future Academy
# 3      01t8n000000GrJSAA0        4644  17637             Amity Future Academy
# 4      01t8n000000GrJTAA0        4645  15978             Amity Future Academy
# ...                   ...         ...    ...                              ...
# 20940          przzd0g0p1       28069  26535                            Udemy
# 20941          przzj4igrr       14130  14308                         Coursera
# 20942          przzltt2yl       34946  35729                              GVC
# 20943          przzvn6z59       14710  11674                         Coursera
# 20944          przzxluxi8       20241  12028                         Coursera
#
#                                             product_name  course_level  \
# 0      PG Program in Digital Marketing Strategies (PG...      Advanced
# 1              PG Program in Product Management (PGP-PM)      Advanced
# 2                    Post Graduate Diploma in Management      Advanced
# 3                    Post Graduate Diploma in Management      Advanced
# 4      Post Graduate Program in Big Data Architecture...      Advanced
# ...                                                  ...           ...
# 20940  Email Marketing: Subscriber List Growth With C...      Beginner
# 20941                      Resourcing a Project Schedule      Beginner
# 20942                      Programming Languages, Part B  Intermediate
# 20943  Exam Prep CKA: Certified Kubernetes Administrator  Intermediate
# 20944                               Generative AI Primer      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 0                 Months               12.00       NaN        170000.0
# 1                 Months               12.00       NaN        215000.0
# 2                 Months                6.00       NaN        120000.0
# 3                 Months                6.00       NaN        120000.0
# 4                 Months                6.00       NaN        100000.0
# ...                  ...                 ...       ...             ...
# 20940            Minutes              215.00   23850.0         23850.0
# 20941              Hours                0.30       1.0             0.0
# 20942              Hours               18.00       NaN             1.0
# 20943              Hours               18.93       1.0             0.0
# 20944              Hours                1.48       1.0             0.0
#
#        inr_amount__c  skill_id concepts  Duration_in_seconds  \
# 0           170000.0       120      NaN           31560192.0
# 1           215000.0        36     5336           31560192.0
# 2           120000.0        98     4550           15780096.0
# 3           120000.0        39      NaN           15780096.0
# 4           100000.0        63     5652           15780096.0
# ...              ...       ...      ...                  ...
# 20940        23850.0       107     6615              12900.0
# 20941            0.0        39     6101               1080.0
# 20942            1.0       164     6893              64800.0
# 20943            0.0       107      NaN              68148.0
# 20944            0.0       317      NaN               5328.0
#
#        Is_within_a_week  Integration
# 0                 False        False
# 1                 False        False
# 2                 False        False
# 3                 False        False
# 4                 False        False
# ...                 ...          ...
# 20940              True        False
# 20941              True        False
# 20942              True        False
# 20943              True        False
# 20944              True        False
#
# [20945 rows x 16 columns]

# %% [markdown]
# Concept Count

# %%
def count_commas(val):
    if pd.isna(val):
        return 0
    elif ',' in val:
        return val.count(',') + 1
    else:
        return 1
df['concept_count']=df['concepts'].apply(count_commas)
df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      01t8n000000GrJPAA0        4641  17890             Amity Future Academy
# 1      01t8n000000GrJQAA0        4642  16262             Amity Future Academy
# 2      01t8n000000GrJRAA0        4643  16885             Amity Future Academy
# 3      01t8n000000GrJSAA0        4644  17637             Amity Future Academy
# 4      01t8n000000GrJTAA0        4645  15978             Amity Future Academy
# ...                   ...         ...    ...                              ...
# 20940          przzd0g0p1       28069  26535                            Udemy
# 20941          przzj4igrr       14130  14308                         Coursera
# 20942          przzltt2yl       34946  35729                              GVC
# 20943          przzvn6z59       14710  11674                         Coursera
# 20944          przzxluxi8       20241  12028                         Coursera
#
#                                             product_name  course_level  \
# 0      PG Program in Digital Marketing Strategies (PG...      Advanced
# 1              PG Program in Product Management (PGP-PM)      Advanced
# 2                    Post Graduate Diploma in Management      Advanced
# 3                    Post Graduate Diploma in Management      Advanced
# 4      Post Graduate Program in Big Data Architecture...      Advanced
# ...                                                  ...           ...
# 20940  Email Marketing: Subscriber List Growth With C...      Beginner
# 20941                      Resourcing a Project Schedule      Beginner
# 20942                      Programming Languages, Part B  Intermediate
# 20943  Exam Prep CKA: Certified Kubernetes Administrator  Intermediate
# 20944                               Generative AI Primer      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 0                 Months               12.00       NaN        170000.0
# 1                 Months               12.00       NaN        215000.0
# 2                 Months                6.00       NaN        120000.0
# 3                 Months                6.00       NaN        120000.0
# 4                 Months                6.00       NaN        100000.0
# ...                  ...                 ...       ...             ...
# 20940            Minutes              215.00   23850.0         23850.0
# 20941              Hours                0.30       1.0             0.0
# 20942              Hours               18.00       NaN             1.0
# 20943              Hours               18.93       1.0             0.0
# 20944              Hours                1.48       1.0             0.0
#
#        inr_amount__c  skill_id concepts  Duration_in_seconds  \
# 0           170000.0       120      NaN           31560192.0
# 1           215000.0        36     5336           31560192.0
# 2           120000.0        98     4550           15780096.0
# 3           120000.0        39      NaN           15780096.0
# 4           100000.0        63     5652           15780096.0
# ...              ...       ...      ...                  ...
# 20940        23850.0       107     6615              12900.0
# 20941            0.0        39     6101               1080.0
# 20942            1.0       164     6893              64800.0
# 20943            0.0       107      NaN              68148.0
# 20944            0.0       317      NaN               5328.0
#
#        Is_within_a_week  Integration  concept_count
# 0                 False        False              0
# 1                 False        False              1
# 2                 False        False              1
# 3                 False        False              0
# 4                 False        False              1
# ...                 ...          ...            ...
# 20940              True        False              1
# 20941              True        False              1
# 20942              True        False              1
# 20943              True        False              0
# 20944              True        False              0
#
# [20945 rows x 17 columns]

# %%
deficit_0 =(df['concept_count']== 0 ).sum()
deficit_0
# Out:
# 2576

# %% [markdown]
# No concept column

# %%
df['no_concept'] = df['concepts'].isna()

# %% [markdown]
# Only Udemy data

# %%
# Sample DataFrame
df# data is the file which will only have CPP names

# List of values to check
values_to_check = ['Udemy']

# Check if any values in the DataFrame are in the list
df['Udemy'] = df['course_provider_platform_name__c'].isin(values_to_check)
udemy_df = df.query("Udemy == True and no_concept == False")
udemy_df
#df.to_excel("//Users//romitbenkar//Desktop//Office//19-11-2024//Udemy_output.xlsx")
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 1404      0AbIh9To       24901  23122                            Udemy
# 1405      0AbXa8Ut       24645  22866                            Udemy
# 1406      0AnKw5Rl       24128  22349                            Udemy
# 1407      0ArCd7Lv       27407  25631                            Udemy
# 1408      0ArKm5Sb       24969  23190                            Udemy
# ...            ...         ...    ...                              ...
# 20920   przy1fgag3       28644  27110                            Udemy
# 20925   przyc3rjqv       31300  29856                            Udemy
# 20926   przyhu62lv       29152  27615                            Udemy
# 20936   przyxra2de       29045  27508                            Udemy
# 20940   przzd0g0p1       28069  26535                            Udemy
#
#                                             product_name  course_level  \
# 1404   (Jetpack, Architecture  and  More)Advanced And...      Beginner
# 1405           Object-oriented Programming in JavaScript  Intermediate
# 1406   Vue - The Complete Guide (incl. Router  and  C...      Beginner
# 1407   Bootstrap 5 From Scratch | Build 5 Modern Webs...      Beginner
# 1408   Complete Deep Learning In R With Keras  and  O...      Beginner
# ...                                                  ...           ...
# 20920  Microsoft Teams: Teams Essentials for the work...      Beginner
# 20925  Master Certified Fraud Examiner (CFE) Essentia...      Beginner
# 20926           Negotiating Your Salary and Compensation      Beginner
# 20936                     Advanced Cryptography Concepts      Beginner
# 20940  Email Marketing: Subscriber List Growth With C...      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 1404             Minutes              2250.0   23850.0         23850.0
# 1405             Minutes               234.0   23850.0         23850.0
# 1406             Minutes              1912.0   23850.0         23850.0
# 1407             Minutes               798.0   23850.0         23850.0
# 1408             Minutes               475.0   23850.0         23850.0
# ...                  ...                 ...       ...             ...
# 20920            Minutes               135.0   23850.0         23850.0
# 20925            Minutes               121.0       0.0         23850.0
# 20926            Minutes               133.0   23850.0         23850.0
# 20936            Minutes               260.0   23850.0         23850.0
# 20940            Minutes               215.0   23850.0         23850.0
#
#        inr_amount__c  skill_id     concepts  Duration_in_seconds  \
# 1404         23850.0       293         6876             135000.0
# 1405         23850.0       103         6849              14040.0
# 1406         23850.0       103         6849             114720.0
# 1407         23850.0       103  6817 , 6849              47880.0
# 1408         23850.0       293         6778              28500.0
# ...              ...       ...          ...                  ...
# 20920        23850.0        44         4561               8100.0
# 20925        23850.0        24         5635               7260.0
# 20926        23850.0       255         5041               7980.0
# 20936        23850.0       291         4648              15600.0
# 20940        23850.0       107         6615              12900.0
#
#        Is_within_a_week  Integration  concept_count  no_concept  Udemy
# 1404               True        False              1       False   True
# 1405               True        False              1       False   True
# 1406               True        False              1       False   True
# 1407               True        False              2       False   True
# 1408               True        False              1       False   True
# ...                 ...          ...            ...         ...    ...
# 20920              True        False              1       False   True
# 20925              True        False              1       False   True
# 20926              True        False              1       False   True
# 20936              True        False              1       False   True
# 20940              True        False              1       False   True
#
# [5260 rows x 19 columns]

# %%
# Sample DataFrame
df# data is the file which will only have CPP names

# List of values to check
values_to_check = ['Udemy']

# Check if any values in the DataFrame are in the list
df['Udemy'] = df['course_provider_platform_name__c'].isin(values_to_check)
udemy_0_df = df.query("Udemy == True and no_concept == True")
udemy_0_df
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 1726      1FkNf0Wo       22871  21092                            Udemy
# 1978      2FeBo7Oj       25745  23967                            Udemy
# 2862      5TgAx9Cg       22983  21204                            Udemy
# 2915      5YrGr8Hy       22895  21116                            Udemy
# 3211      7BpKm9Gj       23448  21669                            Udemy
# 3592      8ObDt0Ty       23451  21672                            Udemy
# 4025    pr04rriz87       29480  27943                            Udemy
# 5754    pr3vmyyxgg       30260  28723                            Udemy
# 5942    pr48w18bp0       28040  26506                            Udemy
# 6173    pr4rce05qb       30210  28673                            Udemy
# 7306    pr72kec05o       27984  26450                            Udemy
# 8367    pr9d9b50m9       28381  26847                            Udemy
# 8373    pr9dhr23kk       29614  28077                            Udemy
# 9304    prbg329x5m       28263  26729                            Udemy
# 9873    prckjmlvhq       29660  28123                            Udemy
# 10726   preelbycur       29646  28109                            Udemy
# 11622   prgh28omad       30150  28613                            Udemy
# 12469   pridfixh08       29375  27838                            Udemy
# 14037   prllet9osu       30939  29495                            Udemy
# 16712   prr7lx775u       29532  27995                            Udemy
# 16942   prrn4jj0va       28014  26480                            Udemy
# 17951   prtq3w17ir       29930  28393                            Udemy
# 18635   prv7lg5yyb       29127  27590                            Udemy
# 19298   prwkzmf60z       30271  28734                            Udemy
# 19666   prxcjr25z4       30054  28517                            Udemy
# 19676   prxd7fln6n       29050  27513                            Udemy
# 19799   prxn9li6ss       31017  29573                            Udemy
# 19829   prxp6bib17       28731  27197                            Udemy
#
#                                             product_name  course_level  \
# 1726   ACCA MA (F2) A Complete Course on Management A...      Beginner
# 1978   AWS Technical Essentials  - Hands-On Training ...      Beginner
# 2862   Certified Key Performance Indicators Professio...      Beginner
# 2915   Automated Cryptocurrency Portfolio Investing w...      Beginner
# 3211   Master PMP Cost Management: Plan, Budget, Esti...      Beginner
# 3592   Master SWOT Analysis  and  Business Strategy f...      Beginner
# 4025                                Effective Leadership      Beginner
# 5754          Chaos Engineering using Azure Chaos Studio      Beginner
# 5942             Leadership: Practical Leadership Skills      Beginner
# 6173   Ethical AI Decision Making, Insights for Leade...      Beginner
# 7306      Lean Six Sigma Green Belt Online Course (2023)      Beginner
# 8367   Informed Risk Taking : Risk Management Process...      Beginner
# 8373         Developing Your Executive Leadership Skills  Intermediate
# 9304   Leadership: How to Influence, Inspire and Impa...      Beginner
# 9873              Managing a Global Team with Confidence      Beginner
# 10726  Leadership - Rise of a Leader (Lead people wit...      Beginner
# 11622  Web Performance In Practice: Master Core Web V...      Beginner
# 12469                         Enterprise Risk Management      Advanced
# 14037  Manage Change Through Collaboration and Team Work      Beginner
# 16712            Leading & Managing People [Effectively]      Beginner
# 16942  Management - Leadership, Negotiating, Assertiv...      Beginner
# 17951  Product Owner II for Agile Intermediate: Certi...      Beginner
# 18635  Leadership & Management Skills: 2-in-1 Masterc...      Beginner
# 19298  Leadership Style: Discover & Maximize Your Lea...      Beginner
# 19666  Body Language & Nonverbal Communication in Bus...      Beginner
# 19676                             Smart Tips: Leadership      Beginner
# 19799          Collaboration with Emotional Intelligence  Intermediate
# 19829  Jira Crash Course | Jira Fundamentals for Agil...      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 1726             Minutes              2014.0   23850.0         23850.0
# 1978             Minutes               866.0   23850.0         23850.0
# 2862             Minutes               448.0   23850.0         23850.0
# 2915             Minutes              1931.0   23850.0         23850.0
# 3211             Minutes               224.0   23850.0         23850.0
# 3592             Minutes               185.0   23850.0         23850.0
# 4025             Minutes                49.0   23850.0         23850.0
# 5754             Minutes                74.0   23850.0         23850.0
# 5942             Minutes               200.0   23850.0         23850.0
# 6173             Minutes               126.0   23850.0         23850.0
# 7306             Minutes               967.0   23850.0         23850.0
# 8367             Minutes               532.0   23850.0         23850.0
# 8373             Minutes                52.0   23850.0         23850.0
# 9304             Minutes                91.0   23850.0         23850.0
# 9873             Minutes                35.0   23850.0         23850.0
# 10726            Minutes                91.0   23850.0         23850.0
# 11622            Minutes               204.0   23850.0         23850.0
# 12469            Minutes              1055.0   23850.0         23850.0
# 14037            Minutes               102.0       0.0             0.0
# 16712            Minutes               119.0   23850.0         23850.0
# 16942            Minutes               128.0   23850.0         23850.0
# 17951            Minutes               379.0   23850.0         23850.0
# 18635            Minutes              2655.0   23850.0         23850.0
# 19298            Minutes               100.0   23850.0         23850.0
# 19666            Minutes               125.0   23850.0         23850.0
# 19676            Minutes               172.0   23850.0         23850.0
# 19799            Minutes               184.0       0.0             0.0
# 19829            Minutes               138.0   23850.0         23850.0
#
#        inr_amount__c  skill_id concepts  Duration_in_seconds  \
# 1726         23850.0        49      NaN             120840.0
# 1978         23850.0        44      NaN              51960.0
# 2862         23850.0        49      NaN              26880.0
# 2915         23850.0       261      NaN             115860.0
# 3211         23850.0       261      NaN              13440.0
# 3592         23850.0        49      NaN              11100.0
# 4025         23850.0       255      NaN               2940.0
# 5754         23850.0       261      NaN               4440.0
# 5942         23850.0       255      NaN              12000.0
# 6173         23850.0       261      NaN               7560.0
# 7306         23850.0        39      NaN              58020.0
# 8367         23850.0       406      NaN              31920.0
# 8373         23850.0       255      NaN               3120.0
# 9304         23850.0       255      NaN               5460.0
# 9873         23850.0       255      NaN               2100.0
# 10726        23850.0       255      NaN               5460.0
# 11622        23850.0       106      NaN              12240.0
# 12469        23850.0        21      NaN              63300.0
# 14037            0.0       262      NaN               6120.0
# 16712        23850.0       255      NaN               7140.0
# 16942        23850.0       255      NaN               7680.0
# 17951        23850.0        36      NaN              22740.0
# 18635        23850.0       255      NaN             159300.0
# 19298        23850.0       255      NaN               6000.0
# 19666        23850.0        64      NaN               7500.0
# 19676        23850.0       255      NaN              10320.0
# 19799            0.0       262      NaN              11040.0
# 19829        23850.0        39      NaN               8280.0
#
#        Is_within_a_week  Integration  concept_count  no_concept  Udemy
# 1726               True        False              0        True   True
# 1978               True        False              0        True   True
# 2862               True        False              0        True   True
# 2915               True        False              0        True   True
# 3211               True        False              0        True   True
# 3592               True        False              0        True   True
# 4025               True        False              0        True   True
# 5754               True        False              0        True   True
# 5942               True        False              0        True   True
# 6173               True        False              0        True   True
# 7306               True        False              0        True   True
# 8367               True        False              0        True   True
# 8373               True        False              0        True   True
# 9304               True        False              0        True   True
# 9873               True        False              0        True   True
# 10726              True        False              0        True   True
# 11622              True        False              0        True   True
# 12469              True        False              0        True   True
# 14037              True        False              0        True   True
# 16712              True        False              0        True   True
# 16942              True        False              0        True   True
# 17951              True        False              0        True   True
# 18635              True        False              0        True   True
# 19298              True        False              0        True   True
# 19666              True        False              0        True   True
# 19676              True        False              0        True   True
# 19799              True        False              0        True   True
# 19829              True        False              0        True   True

# %% [markdown]
# Only ABC data

# %%
# List of values to check
values_to_check = ['Coursera','GVC','Gyanodaya Virtual Campus','CIEL']

# Check if values in 'course_provider_platform_name__c' column are in the list, and create a boolean column 'ABC'
df['ABC'] = df['course_provider_platform_name__c'].isin(values_to_check)

# Save the updated DataFrame to a new Excel file
#df.to_excel("//Users//romitbenkar//Desktop//Office//07-11-2024//ABCoutput.xlsx", index=False)
abc_df = df.query("ABC == True and no_concept == False")
abc_df
#df.to_excel("//Users//romitbenkar//Desktop//Office//19-11-2024//Udemy_output.xlsx")
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 3972    pr000be54a       22145  20095                              GVC
# 3974    pr00ll9a88       14368  15208                         Coursera
# 3975    pr00nc2nuj       19718  12119                         Coursera
# 3980    pr015bytb9       12844   8295                              GVC
# 3982    pr01iiouag       34882  35609                              GVC
# ...            ...         ...    ...                              ...
# 20935   przyx8v5ue       14285  10322                         Coursera
# 20937   przz7qgy8j       20005  14847                         Coursera
# 20938   przz9s4oct       16916  10069                         Coursera
# 20941   przzj4igrr       14130  14308                         Coursera
# 20942   przzltt2yl       34946  35729                              GVC
#
#                                             product_name  course_level  \
# 3972   Advanced Visualizations & Dashboards: Visualiz...  Intermediate
# 3974   Use SurveyMonkey to Create a Survey and Analyz...      Beginner
# 3975                 Getting Started with Facebook Pixel      Beginner
# 3980   CompTIA A+ Core 1: Wireless Networking & Services  Intermediate
# 3982                 Cryptography and Information Theory  Intermediate
# ...                                                  ...           ...
# 20935  Cluster Analysis, Association Mining, and Mode...  Intermediate
# 20937                Technical Managerial Written Skills      Beginner
# 20938          Building Your Freelancing Career Capstone  Intermediate
# 20941                      Resourcing a Project Schedule      Beginner
# 20942                      Programming Languages, Part B  Intermediate
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 3972               Hours                0.34       1.0             0.0
# 3974               Hours                0.40       1.0             0.0
# 3975               Hours                 NaN       1.0             0.0
# 3980               Hours                2.25       1.0             0.0
# 3982               Hours                4.60       NaN             1.0
# ...                  ...                 ...       ...             ...
# 20935              Hours                3.95       1.0             0.0
# 20937              Hours               18.87       1.0             0.0
# 20938              Hours               11.93       1.0             0.0
# 20941              Hours                0.30       1.0             0.0
# 20942              Hours               18.00       NaN             1.0
#
#        inr_amount__c  skill_id concepts  Duration_in_seconds  \
# 3972             1.0       336     4641               1224.0
# 3974             0.0       123     5497               1440.0
# 3975             0.0       117     5274                  NaN
# 3980             0.0       106     6575               8100.0
# 3982             1.0       290     4648              16560.0
# ...              ...       ...      ...                  ...
# 20935            0.0       123     5224              14220.0
# 20937            0.0       130     6061              67932.0
# 20938            0.0       129     5334              42948.0
# 20941            0.0        39     6101               1080.0
# 20942            1.0       164     6893              64800.0
#
#        Is_within_a_week  Integration  concept_count  no_concept  Udemy   ABC
# 3972               True        False              1       False  False  True
# 3974               True        False              1       False  False  True
# 3975              False        False              1       False  False  True
# 3980               True        False              1       False  False  True
# 3982               True        False              1       False  False  True
# ...                 ...          ...            ...         ...    ...   ...
# 20935              True        False              1       False  False  True
# 20937              True        False              1       False  False  True
# 20938              True        False              1       False  False  True
# 20941              True        False              1       False  False  True
# 20942              True        False              1       False  False  True
#
# [7985 rows x 20 columns]

# %%
# List of values to check
values_to_check = ['Coursera','GVC','Gyanodaya Virtual Campus','CIEL']

# Check if values in 'course_provider_platform_name__c' column are in the list, and create a boolean column 'ABC'
df['ABC'] = df['course_provider_platform_name__c'].isin(values_to_check)

# Save the updated DataFrame to a new Excel file
#df.to_excel("//Users//romitbenkar//Desktop//Office//07-11-2024//ABCoutput.xlsx", index=False)
abc_0_df = df.query("ABC == True and no_concept == True")
abc_0_df
#df.to_excel("//Users//romitbenkar//Desktop//Office//19-11-2024//Udemy_output.xlsx")
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 3973    pr0072y7ai       17054  13847                         Coursera
# 4045    pr06e8hqrz       14035  14086                         Coursera
# 4059    pr07ffp1wt       14715  14357                         Coursera
# 4080    pr08pu8d3g       19039  14138                         Coursera
# 4081    pr08qdarvu       17992  10918                         Coursera
# ...            ...         ...    ...                              ...
# 20899   przwql4s97       19202  13317                         Coursera
# 20918   przxwst6s4       16924  13794                         Coursera
# 20921   przy2ytv16       21460  19450                         Coursera
# 20943   przzvn6z59       14710  11674                         Coursera
# 20944   przzxluxi8       20241  12028                         Coursera
#
#                                             product_name  course_level  \
# 3973   Personal Productivity, Time Management and Pri...      Beginner
# 4045   Project Management: Control using the Earned V...      Beginner
# 4059   Running a Node.js Container on Google Kubernet...      Beginner
# 4080                  PyCaret: Anatomy of Classification  Intermediate
# 4081         Creativity Toolkit I: Changing Perspectives      Advanced
# ...                                                  ...           ...
# 20899  Machine Learning Operations (MLOps) with Verte...  Intermediate
# 20918  Our Share: Employee Ownership as a Wealth Shar...      Beginner
# 20921  Database Design and Operational Business Intel...      Beginner
# 20943  Exam Prep CKA: Certified Kubernetes Administrator  Intermediate
# 20944                               Generative AI Primer      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 3973               Hours                6.32       1.0             0.0
# 4045               Hours                1.87       1.0             0.0
# 4059               Hours                0.67       1.0             0.0
# 4080               Hours                0.20       1.0             0.0
# 4081               Hours               10.70       1.0             0.0
# ...                  ...                 ...       ...             ...
# 20899              Hours                 NaN       1.0             0.0
# 20918              Hours               15.08       1.0             0.0
# 20921              Hours                 NaN       1.0             0.0
# 20943              Hours               18.93       1.0             0.0
# 20944              Hours                1.48       1.0             0.0
#
#        inr_amount__c  skill_id concepts  Duration_in_seconds  \
# 3973             0.0       130      NaN              22752.0
# 4045             0.0        37      NaN               6732.0
# 4059             0.0       108      NaN               2412.0
# 4080             0.0        65      NaN                720.0
# 4081             0.0       262      NaN              38520.0
# ...              ...       ...      ...                  ...
# 20899            0.0       319      NaN                  NaN
# 20918            0.0       267      NaN              54288.0
# 20921            1.0        66      NaN                  NaN
# 20943            0.0       107      NaN              68148.0
# 20944            0.0       317      NaN               5328.0
#
#        Is_within_a_week  Integration  concept_count  no_concept  Udemy   ABC
# 3973               True        False              0        True  False  True
# 4045               True        False              0        True  False  True
# 4059               True        False              0        True  False  True
# 4080               True        False              0        True  False  True
# 4081               True        False              0        True  False  True
# ...                 ...          ...            ...         ...    ...   ...
# 20899             False        False              0        True  False  True
# 20918              True        False              0        True  False  True
# 20921             False        False              0        True  False  True
# 20943              True        False              0        True  False  True
# 20944              True        False              0        True  False  True
#
# [1101 rows x 20 columns]

# %% [markdown]
# non_corporate_df(No ABC and Udemy)

# %%
non_corporate_df = df.query("ABC == False and Udemy == False and no_concept == False").sort_values(by='Duration_in_seconds')
non_corporate_df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 1300   01t8n000000JE6wAAG       10007  15551                      Skill Smith
# 1301   01t8n000000JE6yAAG       10009  15708                      Skill Smith
# 1298   01t8n000000JE6uAAG       10005  15553                      Skill Smith
# 19202          prwea1wbu6       32056  30730                       Expertrons
# 15507          prom1ezo1m       32060  30734                       Expertrons
# ...                   ...         ...    ...                              ...
# 462    01t8n000000GrsuAAC        6842  15579                    Masters Union
# 11369          prfwoo5mcq       27775  25999                        IMI Delhi
# 529    01t8n000000GrxEAAS        7140  17371                           upGrad
# 85     01t8n000000GrYbAAK        5575  16657                        Edudelphi
# 150    01t8n000000GreMAAS        5940  14641              Fireblaze AI School
#
#                                             product_name course_level  \
# 1300                        Java Booster Program Offline     Advanced
# 1301                      Angular Master Program Offline     Advanced
# 1298   Full Stack Program (React JS and Node JS) Offline     Advanced
# 19202                      Business Analysis using Excel     Beginner
# 15507                                 Basics of LinkedIn     Beginner
# ...                                                  ...          ...
# 462                              Undergraduate Programme     Beginner
# 11369       Post Graduate Diploma in Management (Online)     Advanced
# 529                  MBA Leading Business Transformation     Advanced
# 85              Certified Fraud Examiner Course in India     Advanced
# 150                                 SQL for Data Science     Advanced
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 1300             Minutes                 3.0      15.0       118000.00
# 1301             Minutes                 3.0       5.0       118000.00
# 1298             Minutes                 6.0      15.0         1295.48
# 19202            Minutes                18.0   20000.0        20000.00
# 15507            Minutes                25.0   20000.0        20000.00
# ...                  ...                 ...       ...             ...
# 462                Years                 6.0       NaN      2925000.00
# 11369              Years                24.0  295000.0       295000.00
# 529               Months               585.0  365000.0      1344753.00
# 85                   nan                 NaN       NaN          439.32
# 150                  nan                 NaN       NaN         2499.00
#
#        inr_amount__c  skill_id  \
# 1300        118000.0       213
# 1301        118000.0       111
# 1298          1274.0       213
# 19202        20000.0       259
# 15507        20000.0       130
# ...              ...       ...
# 462        2925000.0        21
# 11369       295000.0        64
# 529        1344753.0       130
# 85           36990.0       256
# 150           2499.0       164
#
#                                                 concepts  Duration_in_seconds  \
# 1300                                                6107         1.800000e+02
# 1301                                                5747         1.800000e+02
# 1298                                                6107         3.600000e+02
# 19202                                               5002         1.080000e+03
# 15507                                               5812         1.500000e+03
# ...                                                  ...                  ...
# 462                                                 5051         1.892160e+08
# 11369                                               4928         7.568640e+08
# 529                                                 6213         1.538559e+09
# 85     5400 , 5503 , 5593 , 5611 , 5645 , 5740 , 5760...                  NaN
# 150                                                 4778                  NaN
#
#        Is_within_a_week  Integration  concept_count  no_concept  Udemy    ABC
# 1300               True        False              1       False  False  False
# 1301               True        False              1       False  False  False
# 1298               True        False              1       False  False  False
# 19202              True        False              1       False  False  False
# 15507              True        False              1       False  False  False
# ...                 ...          ...            ...         ...    ...    ...
# 462               False        False              1       False  False  False
# 11369             False        False              1       False  False  False
# 529               False        False              1       False  False  False
# 85                False        False             11       False  False  False
# 150               False        False              1       False  False  False
#
# [5124 rows x 20 columns]

# %%
non_corporate_0_df = df.query("ABC == False and Udemy == False and no_concept == True").sort_values(by='Duration_in_seconds')
non_corporate_0_df
# Out:
#             product_sfid  product_id   mpid course_provider_platform_name__c  \
# 1306  01t8n000000JE73AAG       10014  15544                      Skill Smith
# 1305  01t8n000000JE72AAG       10013  16508                      Skill Smith
# 1299  01t8n000000JE6vAAG       10006  15552                      Skill Smith
# 4488          pr140tds7q       21046  18972                          Eduonix
# 6256          pr4vvkrab4       31390  29946                     EBC Learning
# ...                  ...         ...    ...                              ...
# 1393  01tTZ000000gwEvYAI       10504   5894      The Design Village Easebuzz
# 1398  01tTZ000000gwFWYAY       10541   5922      The Design Village Easebuzz
# 5803          pr3yro2h81       11180  15999                   Physics Wallah
# 998   01t8n000000GwvOAAS        9053  16407   Lovely Professional University
# 1004  01t8n000000GwxiAAC        9197  16417   Lovely Professional University
#
#                                            product_name  course_level  \
# 1306                 Master React Native Program Online      Advanced
# 1305                Master React Native Program Offline      Advanced
# 1299   Full Stack Program (React JS and Node JS) Online      Advanced
# 4488                   Business Analytics for Beginners      Beginner
# 6256  Private Equity and Venture Capital: Mastering ...      Advanced
# ...                                                 ...           ...
# 1393                            Interaction & Ux Design      Beginner
# 1398                                     Product Design      Beginner
# 5803  UG Course in Computer Science & Artificial Int...      Advanced
# 998   BBA [2+2 with International Credit Transfer Op...  Intermediate
# 1004                               Integrated BBA - MBA      Advanced
#
#      duration_medium__c  course_duration__c   price__c  loan_amount__c  \
# 1306            Minutes                 3.0        9.0          777.29
# 1305            Minutes                 3.0        9.0          777.29
# 1299            Minutes                 6.0       15.0         1295.48
# 4488            Minutes                15.0    22488.0        22488.00
# 6256            Minutes                42.0     5900.0         5900.00
# ...                 ...                 ...        ...             ...
# 1393              Years                 4.0  2200000.0      2200000.00
# 1398              Years                 4.0  2200000.0      2200000.00
# 5803              Years                 4.0  1519000.0      1519000.00
# 998               Years                 4.0   640000.0       640000.00
# 1004              Years                 4.0   480000.0       480000.00
#
#       inr_amount__c  skill_id concepts  Duration_in_seconds  Is_within_a_week  \
# 1306          764.0       110      NaN                180.0              True
# 1305          764.0       110      NaN                180.0              True
# 1299         1274.0       104      NaN                360.0              True
# 4488        22488.0       125      NaN                900.0              True
# 6256         5900.0        29      NaN               2520.0              True
# ...             ...       ...      ...                  ...               ...
# 1393      2200000.0        73      NaN          126144000.0             False
# 1398      2200000.0        79      NaN          126144000.0             False
# 5803      1519000.0        62      NaN          126144000.0             False
# 998        640000.0        37      NaN          126144000.0             False
# 1004       480000.0        37      NaN          126144000.0             False
#
#       Integration  concept_count  no_concept  Udemy    ABC
# 1306        False              0        True  False  False
# 1305        False              0        True  False  False
# 1299        False              0        True  False  False
# 4488        False              0        True  False  False
# 6256        False              0        True  False  False
# ...           ...            ...         ...    ...    ...
# 1393        False              0        True  False  False
# 1398        False              0        True  False  False
# 5803        False              0        True  False  False
# 998         False              0        True  False  False
# 1004        False              0        True  False  False
#
# [1447 rows x 20 columns]

# %% [markdown]
# Ranking non_corporate

# %%
non_corporate_df = non_corporate_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
non_corporate_df['Rank'] = 600 - (non_corporate_df.index * 0.01)
non_corporate_df
# Out:
#             product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0     01t8n000000JE6wAAG       10007  15551                      Skill Smith
# 1     01t8n000000JE6yAAG       10009  15708                      Skill Smith
# 2     01t8n000000JE6uAAG       10005  15553                      Skill Smith
# 3             prwea1wbu6       32056  30730                       Expertrons
# 4             prom1ezo1m       32060  30734                       Expertrons
# ...                  ...         ...    ...                              ...
# 5119  01t8n000000GrsuAAC        6842  15579                    Masters Union
# 5120          prfwoo5mcq       27775  25999                        IMI Delhi
# 5121  01t8n000000GrxEAAS        7140  17371                           upGrad
# 5122  01t8n000000GreMAAS        5940  14641              Fireblaze AI School
# 5123  01t8n000000GrYbAAK        5575  16657                        Edudelphi
#
#                                            product_name course_level  \
# 0                          Java Booster Program Offline     Advanced
# 1                        Angular Master Program Offline     Advanced
# 2     Full Stack Program (React JS and Node JS) Offline     Advanced
# 3                         Business Analysis using Excel     Beginner
# 4                                    Basics of LinkedIn     Beginner
# ...                                                 ...          ...
# 5119                            Undergraduate Programme     Beginner
# 5120       Post Graduate Diploma in Management (Online)     Advanced
# 5121                MBA Leading Business Transformation     Advanced
# 5122                               SQL for Data Science     Advanced
# 5123           Certified Fraud Examiner Course in India     Advanced
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0               Minutes                 3.0      15.0       118000.00  ...
# 1               Minutes                 3.0       5.0       118000.00  ...
# 2               Minutes                 6.0      15.0         1295.48  ...
# 3               Minutes                18.0   20000.0        20000.00  ...
# 4               Minutes                25.0   20000.0        20000.00  ...
# ...                 ...                 ...       ...             ...  ...
# 5119              Years                 6.0       NaN      2925000.00  ...
# 5120              Years                24.0  295000.0       295000.00  ...
# 5121             Months               585.0  365000.0      1344753.00  ...
# 5122                nan                 NaN       NaN         2499.00  ...
# 5123                nan                 NaN       NaN          439.32  ...
#
#       skill_id                                           concepts  \
# 0          213                                               6107
# 1          111                                               5747
# 2          213                                               6107
# 3          259                                               5002
# 4          130                                               5812
# ...        ...                                                ...
# 5119        21                                               5051
# 5120        64                                               4928
# 5121       130                                               6213
# 5122       164                                               4778
# 5123       256  5400 , 5503 , 5593 , 5611 , 5645 , 5740 , 5760...
#
#      Duration_in_seconds  Is_within_a_week  Integration  concept_count  \
# 0           1.800000e+02              True        False              1
# 1           1.800000e+02              True        False              1
# 2           3.600000e+02              True        False              1
# 3           1.080000e+03              True        False              1
# 4           1.500000e+03              True        False              1
# ...                  ...               ...          ...            ...
# 5119        1.892160e+08             False        False              1
# 5120        7.568640e+08             False        False              1
# 5121        1.538559e+09             False        False              1
# 5122                 NaN             False        False              1
# 5123                 NaN             False        False             11
#
#       no_concept  Udemy    ABC    Rank
# 0          False  False  False  600.00
# 1          False  False  False  599.99
# 2          False  False  False  599.98
# 3          False  False  False  599.97
# 4          False  False  False  599.96
# ...          ...    ...    ...     ...
# 5119       False  False  False  548.81
# 5120       False  False  False  548.80
# 5121       False  False  False  548.79
# 5122       False  False  False  548.78
# 5123       False  False  False  548.77
#
# [5124 rows x 21 columns]

# %%
non_corporate_0_df = non_corporate_0_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
non_corporate_0_df['Rank'] = 550 - (non_corporate_0_df.index * 0.01)
non_corporate_0_df
# Out:
#             product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0     01t8n000000JE73AAG       10014  15544                      Skill Smith
# 1     01t8n000000JE72AAG       10013  16508                      Skill Smith
# 2     01t8n000000JE6vAAG       10006  15552                      Skill Smith
# 3             pr140tds7q       21046  18972                          Eduonix
# 4             pr4vvkrab4       31390  29946                     EBC Learning
# ...                  ...         ...    ...                              ...
# 1442          pr3yro2h81       11180  15999                   Physics Wallah
# 1443  01tTZ000000gwEnYAI       10496   5887      The Design Village Easebuzz
# 1444  01tTZ000000gwEvYAI       10504   5894      The Design Village Easebuzz
# 1445  01tTZ000000gwFWYAY       10541   5922      The Design Village Easebuzz
# 1446  01t8n000000GrstAAC        6841  16928                    Masters Union
#
#                                            product_name  course_level  \
# 0                    Master React Native Program Online      Advanced
# 1                   Master React Native Program Offline      Advanced
# 2      Full Stack Program (React JS and Node JS) Online      Advanced
# 3                      Business Analytics for Beginners      Beginner
# 4     Private Equity and Venture Capital: Mastering ...      Advanced
# ...                                                 ...           ...
# 1442  UG Course in Computer Science & Artificial Int...      Advanced
# 1443                           Graphics & Communication      Beginner
# 1444                            Interaction & Ux Design      Beginner
# 1445                                     Product Design      Beginner
# 1446       UG Programme in Tech and Business Management  Intermediate
#
#      duration_medium__c  course_duration__c   price__c  loan_amount__c  ...  \
# 0               Minutes                 3.0        9.0          777.29  ...
# 1               Minutes                 3.0        9.0          777.29  ...
# 2               Minutes                 6.0       15.0         1295.48  ...
# 3               Minutes                15.0    22488.0        22488.00  ...
# 4               Minutes                42.0     5900.0         5900.00  ...
# ...                 ...                 ...        ...             ...  ...
# 1442              Years                 4.0  1519000.0      1519000.00  ...
# 1443              Years                 4.0  2200000.0      2200000.00  ...
# 1444              Years                 4.0  2200000.0      2200000.00  ...
# 1445              Years                 4.0  2200000.0      2200000.00  ...
# 1446              Years                 4.0        NaN      4368000.00  ...
#
#       skill_id  concepts Duration_in_seconds  Is_within_a_week  Integration  \
# 0          110       NaN               180.0              True        False
# 1          110       NaN               180.0              True        False
# 2          104       NaN               360.0              True        False
# 3          125       NaN               900.0              True        False
# 4           29       NaN              2520.0              True        False
# ...        ...       ...                 ...               ...          ...
# 1442        62       NaN         126144000.0             False        False
# 1443        73       NaN         126144000.0             False        False
# 1444        73       NaN         126144000.0             False        False
# 1445        79       NaN         126144000.0             False        False
# 1446        37       NaN         126144000.0             False        False
#
#       concept_count  no_concept  Udemy    ABC    Rank
# 0                 0        True  False  False  550.00
# 1                 0        True  False  False  549.99
# 2                 0        True  False  False  549.98
# 3                 0        True  False  False  549.97
# 4                 0        True  False  False  549.96
# ...             ...         ...    ...    ...     ...
# 1442              0        True  False  False  535.58
# 1443              0        True  False  False  535.57
# 1444              0        True  False  False  535.56
# 1445              0        True  False  False  535.55
# 1446              0        True  False  False  535.54
#
# [1447 rows x 21 columns]

# %% [markdown]
# Ranking ABC

# %%
abc_df = abc_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
abc_df['Rank'] = 500 - (abc_df.index * 0.01)
abc_df
# Out:
#      product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      pr6ggb6crn       13720   9169                              GVC
# 1      prz439vl3r       12700   8151                              GVC
# 2      prwjj6sgg7       13783  19765                              GVC
# 3      pr0ramdk0c       13667   9117                              GVC
# 4      prnl3tqozi       13112   8562                              GVC
# ...           ...         ...    ...                              ...
# 7980   przurvq0im       22264  20214                              GVC
# 7981   przvahytsh       22157  20107                              GVC
# 7982   przyu0in9m       22779  20873                              GVC
# 7983   prqqlga689       17818  14709         Gyanodaya Virtual Campus
# 7984   pro59osu24       22748  20841                         Coursera
#
#                                            product_name  course_level  \
# 0               Sharing Multiple Screens Simultaneously      Beginner
# 1                     Scheduling a Meeting with Outlook      Beginner
# 2     Recognizing and Addressing Micro-behaviors in ...      Beginner
# 3                                     Closed Captioning      Beginner
# 4                                   Sharing Your Screen      Beginner
# ...                                                 ...           ...
# 7980                 CompTIA Linux+: SELinux & AppArmor  Intermediate
# 7981      Outlook 2016 (Mac): Sending & Receiving Email      Beginner
# 7982            Microsoft Azure Services and Lifecycles      Beginner
# 7983                                 Strategic Sourcing      Beginner
# 7984                          Academic English: Writing      Beginner
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0                 Hours                0.01       1.0             0.0  ...
# 1                 Hours                0.01       1.0             0.0  ...
# 2                 Hours                0.01       1.0             0.0  ...
# 3                 Hours                0.02       1.0             0.0  ...
# 4                 Hours                0.02       1.0             0.0  ...
# ...                 ...                 ...       ...             ...  ...
# 7980              Hours                 NaN       1.0             0.0  ...
# 7981              Hours                 NaN       1.0             0.0  ...
# 7982              Hours                 NaN       1.0             0.0  ...
# 7983              Hours                 NaN       1.0         23600.0  ...
# 7984              Hours                 NaN       1.0             0.0  ...
#
#       skill_id  concepts Duration_in_seconds  Is_within_a_week  Integration  \
# 0          259      5002                36.0              True        False
# 1          272      5002                36.0              True        False
# 2          255      4888                36.0              True        False
# 3          260      5002                72.0              True        False
# 4          285      5002                72.0              True        False
# ...        ...       ...                 ...               ...          ...
# 7980       108      6301                 NaN             False        False
# 7981       272      5002                 NaN             False        False
# 7982       288      5947                 NaN             False        False
# 7983       341      5119                 NaN             False        False
# 7984       130      6213                 NaN             False        False
#
#       concept_count  no_concept  Udemy   ABC    Rank
# 0                 1       False  False  True  500.00
# 1                 1       False  False  True  499.99
# 2                 1       False  False  True  499.98
# 3                 1       False  False  True  499.97
# 4                 1       False  False  True  499.96
# ...             ...         ...    ...   ...     ...
# 7980              1       False  False  True  420.20
# 7981              1       False  False  True  420.19
# 7982              1       False  False  True  420.18
# 7983              1       False  False  True  420.17
# 7984              1       False  False  True  420.16
#
# [7985 rows x 21 columns]

# %%
abc_0_df = abc_0_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
abc_0_df['Rank'] = 420 - (abc_0_df.index * 0.01)
abc_0_df
# Out:
#      product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      prai5zubue       14804  14664                         Coursera
# 1      priofhwu49       14375  10553                         Coursera
# 2      prj50a1zil       16862  11768                         Coursera
# 3      prpp90zk8u       18219  14252                         Coursera
# 4      prrtje596c       15301  14737                         Coursera
# ...           ...         ...    ...                              ...
# 1096   prvem1d31q       22626  20710                         Coursera
# 1097   prwbrwx3rr       22534  20612                         Coursera
# 1098   prxblezp5c       22763  20857                              GVC
# 1099   prxxilay2h       21520  19565                              GVC
# 1100   przy2ytv16       21460  19450                         Coursera
#
#                                            product_name  course_level  \
# 0     Static Website Hosting and Cross-Region Replic...      Beginner
# 1     Create a Boggle Word Solver using recursion in...  Intermediate
# 2                          Fast Typer Game using Pygame      Beginner
# 3     Recreate the First Ever Easter Egg from Advent...      Beginner
# 4                                 Style Images with CSS  Intermediate
# ...                                                 ...           ...
# 1096                                  Agile Development      Beginner
# 1097                     Google Advanced Data Analytics      Beginner
# 1098  Data Manipulation at Scale: Systems and Algori...      Beginner
# 1099   Project Scheduling:  Estimate Activity Durations      Beginner
# 1100  Database Design and Operational Business Intel...      Beginner
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0                 Hours                 0.1       1.0             0.0  ...
# 1                 Hours                 0.1       1.0             0.0  ...
# 2                 Hours                 0.1       1.0             0.0  ...
# 3                 Hours                 0.1       1.0             0.0  ...
# 4                 Hours                 0.1       1.0             0.0  ...
# ...                 ...                 ...       ...             ...  ...
# 1096              Hours                 NaN       1.0             0.0  ...
# 1097              Hours                 NaN       1.0             0.0  ...
# 1098              Hours                 NaN       1.0             0.0  ...
# 1099              Hours                 NaN       1.0             0.0  ...
# 1100              Hours                 NaN       1.0             0.0  ...
#
#       skill_id  concepts Duration_in_seconds  Is_within_a_week  Integration  \
# 0           55       NaN               360.0              True        False
# 1           67       NaN               360.0              True        False
# 2           53       NaN               360.0              True        False
# 3          313       NaN               360.0              True        False
# 4          111       NaN               360.0              True        False
# ...        ...       ...                 ...               ...          ...
# 1096       284       NaN                 NaN             False        False
# 1097       213       NaN                 NaN             False        False
# 1098        57       NaN                 NaN             False        False
# 1099        37       NaN                 NaN             False        False
# 1100        66       NaN                 NaN             False        False
#
#       concept_count  no_concept  Udemy   ABC    Rank
# 0                 0        True  False  True  420.00
# 1                 0        True  False  True  419.99
# 2                 0        True  False  True  419.98
# 3                 0        True  False  True  419.97
# 4                 0        True  False  True  419.96
# ...             ...         ...    ...   ...     ...
# 1096              0        True  False  True  409.04
# 1097              0        True  False  True  409.03
# 1098              0        True  False  True  409.02
# 1099              0        True  False  True  409.01
# 1100              0        True  False  True  409.00
#
# [1101 rows x 21 columns]

# %% [markdown]
# Ranking Udemy_courses

# %%
udemy_df = udemy_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
udemy_df['Rank'] = 400 - (udemy_df.index * 0.01)
udemy_df
# Out:
#      product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      pr0y1ipl5c       31002  29558                            Udemy
# 1      prcdxzvedk       31166  29722                            Udemy
# 2      prgw6evcc9       31137  29693                            Udemy
# 3      prhzt6h99t       31340  29896                            Udemy
# 4      prr0pknjsi       31322  29878                            Udemy
# ...           ...         ...    ...                              ...
# 5255     5OqCv2Pw       25043  23264                            Udemy
# 5256     3TgEl5Xn       27077  25300                            Udemy
# 5257   prbgu9bqhd       33590  33488                            Udemy
# 5258   prpnv1ebe6       33589  33487                            Udemy
# 5259   prz666dzq4       29616  28785                            Udemy
#
#                                            product_name  course_level  \
# 0     Project Management Certified Associate: CAPM P...  Intermediate
# 1     ISO 22301Business Continuity Management (BCM &...      Beginner
# 2     Project Management - Theory of Constraints way...      Beginner
# 3        Life Insurance & Annuity Ultimate Buyers Guide      Beginner
# 4                         Digital Compliance Monitoring  Intermediate
# ...                                                 ...           ...
# 5255  Selenium Java : Beginner to Advanced [Live Pro...      Beginner
# 5256  SAP ABAP, OOPS, CROSSAPP, WEBDYNPRO, WORKFLOW,...      Beginner
# 5257  KPI and metrics for Management Consultants & M...      Advanced
# 5258  Critical Thinker Academy: Learn to Think Like ...  Intermediate
# 5259  ISC2 Certified in Cybersecurity (CC) Full Prac...      Beginner
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 0                 Hours                 0.1       0.0             0.0
# 1                 Hours                 0.1       0.0             0.0
# 2                 Hours                 0.1       0.0             0.0
# 3                 Hours                 0.1       0.0             0.0
# 4                 Hours                 0.1       0.0             0.0
# ...                 ...                 ...       ...             ...
# 5255            Minutes             11327.0   23850.0         23850.0
# 5256            Minutes             11547.0   23850.0         23850.0
# 5257              Hours               334.0   22842.0         22842.0
# 5258              Hours              1173.0   22842.0         22842.0
# 5259            Minutes                 NaN   23850.0         23850.0
#
#       inr_amount__c  skill_id  \
# 0               0.0        37
# 1               0.0        40
# 2               0.0        37
# 3               0.0        45
# 4               0.0        40
# ...             ...       ...
# 5255        23850.0       103
# 5256        23850.0       316
# 5257        22842.0        63
# 5258        22842.0       314
# 5259        23850.0       130
#
#                                                concepts  Duration_in_seconds  \
# 0                                                  4590                360.0
# 1                                           4586 , 5436                360.0
# 2                                                  4590                360.0
# 3                                                  4568                360.0
# 4                                                  4564                360.0
# ...                                                 ...                  ...
# 5255                                        6817 , 6849             679620.0
# 5256                                               6938             692820.0
# 5257                                               5506            1202400.0
# 5258  5025 , 7005 , 7006 , 7007 , 7008 , 7009 , 7010...            4222800.0
# 5259                                               6063                  NaN
#
#       Is_within_a_week  Integration  concept_count  no_concept  Udemy    Rank
# 0                 True        False              1       False   True  400.00
# 1                 True        False              2       False   True  399.99
# 2                 True        False              1       False   True  399.98
# 3                 True        False              1       False   True  399.97
# 4                 True        False              1       False   True  399.96
# ...                ...          ...            ...         ...    ...     ...
# 5255             False        False              2       False   True  347.45
# 5256             False        False              1       False   True  347.44
# 5257             False        False              1       False   True  347.43
# 5258             False        False             10       False   True  347.42
# 5259             False        False              1       False   True  347.41
#
# [5260 rows x 20 columns]

# %%
udemy_0_df = udemy_0_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
udemy_0_df['Rank'] = 340 - (udemy_0_df.index * 0.01)
udemy_0_df
# Out:
#    product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0    prckjmlvhq       29660  28123                            Udemy
# 1    pr04rriz87       29480  27943                            Udemy
# 2    pr9dhr23kk       29614  28077                            Udemy
# 3    pr3vmyyxgg       30260  28723                            Udemy
# 4    prbg329x5m       28263  26729                            Udemy
# 5    preelbycur       29646  28109                            Udemy
# 6    prwkzmf60z       30271  28734                            Udemy
# 7    prllet9osu       30939  29495                            Udemy
# 8    prr7lx775u       29532  27995                            Udemy
# 9    prxcjr25z4       30054  28517                            Udemy
# 10   pr4rce05qb       30210  28673                            Udemy
# 11   prrn4jj0va       28014  26480                            Udemy
# 12   prxp6bib17       28731  27197                            Udemy
# 13   prxd7fln6n       29050  27513                            Udemy
# 14   prxn9li6ss       31017  29573                            Udemy
# 15     8ObDt0Ty       23451  21672                            Udemy
# 16   pr48w18bp0       28040  26506                            Udemy
# 17   prgh28omad       30150  28613                            Udemy
# 18     7BpKm9Gj       23448  21669                            Udemy
# 19   prtq3w17ir       29930  28393                            Udemy
# 20     5TgAx9Cg       22983  21204                            Udemy
# 21   pr9d9b50m9       28381  26847                            Udemy
# 22     2FeBo7Oj       25745  23967                            Udemy
# 23   pr72kec05o       27984  26450                            Udemy
# 24   pridfixh08       29375  27838                            Udemy
# 25     5YrGr8Hy       22895  21116                            Udemy
# 26     1FkNf0Wo       22871  21092                            Udemy
# 27   prv7lg5yyb       29127  27590                            Udemy
#
#                                          product_name  course_level  \
# 0              Managing a Global Team with Confidence      Beginner
# 1                                Effective Leadership      Beginner
# 2         Developing Your Executive Leadership Skills  Intermediate
# 3          Chaos Engineering using Azure Chaos Studio      Beginner
# 4   Leadership: How to Influence, Inspire and Impa...      Beginner
# 5   Leadership - Rise of a Leader (Lead people wit...      Beginner
# 6   Leadership Style: Discover & Maximize Your Lea...      Beginner
# 7   Manage Change Through Collaboration and Team Work      Beginner
# 8             Leading & Managing People [Effectively]      Beginner
# 9   Body Language & Nonverbal Communication in Bus...      Beginner
# 10  Ethical AI Decision Making, Insights for Leade...      Beginner
# 11  Management - Leadership, Negotiating, Assertiv...      Beginner
# 12  Jira Crash Course | Jira Fundamentals for Agil...      Beginner
# 13                             Smart Tips: Leadership      Beginner
# 14          Collaboration with Emotional Intelligence  Intermediate
# 15  Master SWOT Analysis  and  Business Strategy f...      Beginner
# 16            Leadership: Practical Leadership Skills      Beginner
# 17  Web Performance In Practice: Master Core Web V...      Beginner
# 18  Master PMP Cost Management: Plan, Budget, Esti...      Beginner
# 19  Product Owner II for Agile Intermediate: Certi...      Beginner
# 20  Certified Key Performance Indicators Professio...      Beginner
# 21  Informed Risk Taking : Risk Management Process...      Beginner
# 22  AWS Technical Essentials  - Hands-On Training ...      Beginner
# 23     Lean Six Sigma Green Belt Online Course (2023)      Beginner
# 24                         Enterprise Risk Management      Advanced
# 25  Automated Cryptocurrency Portfolio Investing w...      Beginner
# 26  ACCA MA (F2) A Complete Course on Management A...      Beginner
# 27  Leadership & Management Skills: 2-in-1 Masterc...      Beginner
#
#    duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 0             Minutes                35.0   23850.0         23850.0
# 1             Minutes                49.0   23850.0         23850.0
# 2             Minutes                52.0   23850.0         23850.0
# 3             Minutes                74.0   23850.0         23850.0
# 4             Minutes                91.0   23850.0         23850.0
# 5             Minutes                91.0   23850.0         23850.0
# 6             Minutes               100.0   23850.0         23850.0
# 7             Minutes               102.0       0.0             0.0
# 8             Minutes               119.0   23850.0         23850.0
# 9             Minutes               125.0   23850.0         23850.0
# 10            Minutes               126.0   23850.0         23850.0
# 11            Minutes               128.0   23850.0         23850.0
# 12            Minutes               138.0   23850.0         23850.0
# 13            Minutes               172.0   23850.0         23850.0
# 14            Minutes               184.0       0.0             0.0
# 15            Minutes               185.0   23850.0         23850.0
# 16            Minutes               200.0   23850.0         23850.0
# 17            Minutes               204.0   23850.0         23850.0
# 18            Minutes               224.0   23850.0         23850.0
# 19            Minutes               379.0   23850.0         23850.0
# 20            Minutes               448.0   23850.0         23850.0
# 21            Minutes               532.0   23850.0         23850.0
# 22            Minutes               866.0   23850.0         23850.0
# 23            Minutes               967.0   23850.0         23850.0
# 24            Minutes              1055.0   23850.0         23850.0
# 25            Minutes              1931.0   23850.0         23850.0
# 26            Minutes              2014.0   23850.0         23850.0
# 27            Minutes              2655.0   23850.0         23850.0
#
#     inr_amount__c  skill_id concepts  Duration_in_seconds  Is_within_a_week  \
# 0         23850.0       255      NaN               2100.0              True
# 1         23850.0       255      NaN               2940.0              True
# 2         23850.0       255      NaN               3120.0              True
# 3         23850.0       261      NaN               4440.0              True
# 4         23850.0       255      NaN               5460.0              True
# 5         23850.0       255      NaN               5460.0              True
# 6         23850.0       255      NaN               6000.0              True
# 7             0.0       262      NaN               6120.0              True
# 8         23850.0       255      NaN               7140.0              True
# 9         23850.0        64      NaN               7500.0              True
# 10        23850.0       261      NaN               7560.0              True
# 11        23850.0       255      NaN               7680.0              True
# 12        23850.0        39      NaN               8280.0              True
# 13        23850.0       255      NaN              10320.0              True
# 14            0.0       262      NaN              11040.0              True
# 15        23850.0        49      NaN              11100.0              True
# 16        23850.0       255      NaN              12000.0              True
# 17        23850.0       106      NaN              12240.0              True
# 18        23850.0       261      NaN              13440.0              True
# 19        23850.0        36      NaN              22740.0              True
# 20        23850.0        49      NaN              26880.0              True
# 21        23850.0       406      NaN              31920.0              True
# 22        23850.0        44      NaN              51960.0              True
# 23        23850.0        39      NaN              58020.0              True
# 24        23850.0        21      NaN              63300.0              True
# 25        23850.0       261      NaN             115860.0              True
# 26        23850.0        49      NaN             120840.0              True
# 27        23850.0       255      NaN             159300.0              True
#
#     Integration  concept_count  no_concept  Udemy    Rank
# 0         False              0        True   True  340.00
# 1         False              0        True   True  339.99
# 2         False              0        True   True  339.98
# 3         False              0        True   True  339.97
# 4         False              0        True   True  339.96
# 5         False              0        True   True  339.95
# 6         False              0        True   True  339.94
# 7         False              0        True   True  339.93
# 8         False              0        True   True  339.92
# 9         False              0        True   True  339.91
# 10        False              0        True   True  339.90
# 11        False              0        True   True  339.89
# 12        False              0        True   True  339.88
# 13        False              0        True   True  339.87
# 14        False              0        True   True  339.86
# 15        False              0        True   True  339.85
# 16        False              0        True   True  339.84
# 17        False              0        True   True  339.83
# 18        False              0        True   True  339.82
# 19        False              0        True   True  339.81
# 20        False              0        True   True  339.80
# 21        False              0        True   True  339.79
# 22        False              0        True   True  339.78
# 23        False              0        True   True  339.77
# 24        False              0        True   True  339.76
# 25        False              0        True   True  339.75
# 26        False              0        True   True  339.74
# 27        False              0        True   True  339.73

# %% [markdown]
# Concanating all the dataframe

# %%
pieces = {"x": non_corporate_df,"x1":non_corporate_0_df, "y": abc_df,"y1": abc_0_df, "z": udemy_df,"z1": udemy_0_df}
result = pd.concat(pieces)
result.to_excel("C:\\Users\\taslim.siddiqui\\Downloads\\Recorating24.xlsx")
print(result)
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# x  0   01t8n000000JE6wAAG       10007  15551                      Skill Smith
#    1   01t8n000000JE6yAAG       10009  15708                      Skill Smith
#    2   01t8n000000JE6uAAG       10005  15553                      Skill Smith
#    3           prwea1wbu6       32056  30730                       Expertrons
#    4           prom1ezo1m       32060  30734                       Expertrons
# ...                   ...         ...    ...                              ...
# z1 23          pr72kec05o       27984  26450                            Udemy
#    24          pridfixh08       29375  27838                            Udemy
#    25            5YrGr8Hy       22895  21116                            Udemy
#    26            1FkNf0Wo       22871  21092                            Udemy
#    27          prv7lg5yyb       29127  27590                            Udemy
#
#                                             product_name course_level  \
# x  0                        Java Booster Program Offline     Advanced
#    1                      Angular Master Program Offline     Advanced
#    2   Full Stack Program (React JS and Node JS) Offline     Advanced
#    3                       Business Analysis using Excel     Beginner
#    4                                  Basics of LinkedIn     Beginner
# ...                                                  ...          ...
# z1 23     Lean Six Sigma Green Belt Online Course (2023)     Beginner
#    24                         Enterprise Risk Management     Advanced
#    25  Automated Cryptocurrency Portfolio Investing w...     Beginner
#    26  ACCA MA (F2) A Complete Course on Management A...     Beginner
#    27  Leadership & Management Skills: 2-in-1 Masterc...     Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# x  0             Minutes                 3.0      15.0       118000.00  ...
#    1             Minutes                 3.0       5.0       118000.00  ...
#    2             Minutes                 6.0      15.0         1295.48  ...
#    3             Minutes                18.0   20000.0        20000.00  ...
#    4             Minutes                25.0   20000.0        20000.00  ...
# ...                  ...                 ...       ...             ...  ...
# z1 23            Minutes               967.0   23850.0        23850.00  ...
#    24            Minutes              1055.0   23850.0        23850.00  ...
#    25            Minutes              1931.0   23850.0        23850.00  ...
#    26            Minutes              2014.0   23850.0        23850.00  ...
#    27            Minutes              2655.0   23850.0        23850.00  ...
#
#        skill_id  concepts Duration_in_seconds  Is_within_a_week  Integration  \
# x  0        213      6107               180.0              True        False
#    1        111      5747               180.0              True        False
#    2        213      6107               360.0              True        False
#    3        259      5002              1080.0              True        False
#    4        130      5812              1500.0              True        False
# ...         ...       ...                 ...               ...          ...
# z1 23        39       NaN             58020.0              True        False
#    24        21       NaN             63300.0              True        False
#    25       261       NaN            115860.0              True        False
#    26        49       NaN            120840.0              True        False
#    27       255       NaN            159300.0              True        False
#
#        concept_count  no_concept  Udemy    ABC    Rank
# x  0               1       False  False  False  600.00
#    1               1       False  False  False  599.99
#    2               1       False  False  False  599.98
#    3               1       False  False  False  599.97
#    4               1       False  False  False  599.96
# ...              ...         ...    ...    ...     ...
# z1 23              0        True   True    NaN  339.77
#    24              0        True   True    NaN  339.76
#    25              0        True   True    NaN  339.75
#    26              0        True   True    NaN  339.74
#    27              0        True   True    NaN  339.73
#
# [20945 rows x 21 columns]

# %% [markdown]
# testing

# %%
import pandas as pd

# Define the dataset
data = {
    "duration_seconds": [2000, 5890, 5739, 6746, 2000, 2000, 5890, 2000, 67383, 784892, 6474, 5890],
    "Integration": [True, True, False, True, True, True, True, True, False, True, False, False],
    "Price": [5943843, 7744, 4744, 84433, 74484, 4438, 46746, 73782, 74383, 74873, 764673, 64473]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort by the three columns in the desired order: duration_seconds, Integration (descending), Price
df = df.sort_values(
    by=["duration_seconds", "Integration", "Price"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
df['Rank'] = 600 - (df.index * 0.01)

# Display the resulting DataFrame
print(df)
# Out:
#     duration_seconds  Integration    Price    Rank
# 0               2000         True     4438  600.00
# 1               2000         True    73782  599.99
# 2               2000         True    74484  599.98
# 3               2000         True  5943843  599.97
# 4               5739        False     4744  599.96
# 5               5890         True     7744  599.95
# 6               5890         True    46746  599.94
# 7               5890        False    64473  599.93
# 8               6474        False   764673  599.92
# 9               6746         True    84433  599.91
# 10             67383        False    74383  599.90
# 11            784892         True    74873  599.89

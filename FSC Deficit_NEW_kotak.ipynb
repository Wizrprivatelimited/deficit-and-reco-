# %% [markdown]
# # FSC Deficiet

# %%
import pandas as pd

# %%
#Function,Prod Function ID,Skill,PRODUCTION Skill ID,Skill Description,Concept,Concept Description,PRODUCTION Concepts ID,Concat,product_id


#load FSC master excel
df1 = pd.read_excel(r"C:\Users\taslim.siddiqui\Downloads\KOTAK Course + Deficit Tracker_Data added (4).xlsx",sheet_name='Kotak FSC Master')
df1.head()
# Out:
#              Academy  Prod Function ID                                  Skill  \
# 0  Assurance - Audit                87  Audit Automation Tools and Techniques
# 1  Assurance - Audit                87  Audit Automation Tools and Techniques
# 2  Assurance - Audit                87  Audit Automation Tools and Techniques
# 3  Assurance - Audit                87  Audit Automation Tools and Techniques
# 4  Assurance - Audit                87  Audit Automation Tools and Techniques
#
#    PRODUCTION Skill ID                                  Skill Description  \
# 0                 1230  Master Audit Automation to streamline processe...
# 1                 1230  Master Audit Automation to streamline processe...
# 2                 1230  Master Audit Automation to streamline processe...
# 3                 1230  Master Audit Automation to streamline processe...
# 4                 1230  Master Audit Automation to streamline processe...
#
#                         Concept  \
# 0     Audit Management Software
# 1           Continuous Auditing
# 2    Automated Evidence Capture
# 3  Real-time Control Dashboards
# 4         Exception Auto-Triage
#
#                                  Concept Description  PRODUCTION Concepts ID  \
# 0  Experience with tools such as TeamMate, Metric...                    7014
# 1  Leveraging technology to perform ongoing, real...                    7015
# 2  Using automation scripts to collect audit evid...                   15339
# 3  Providing live visibility into automated contr...                   15340
# 4  Automatically categorizing exceptions based on...                   15341
#
#                                               Concat
# 0  Assurance - AuditAudit Automation Tools and Te...
# 1  Assurance - AuditAudit Automation Tools and Te...
# 2  Assurance - AuditAudit Automation Tools and Te...
# 3  Assurance - AuditAudit Automation Tools and Te...
# 4  Assurance - AuditAudit Automation Tools and Te...

# %%
#product_name,course_level,skill_id,concepts,product_id
#load data file
df2 = pd.read_excel(r"C:\Users\taslim.siddiqui\Downloads\KOTAK Course + Deficit Tracker_Data added (4).xlsx",sheet_name='HH+Other CPP Master')
df2
# Out:
#                                             Course Name  \
# 0                     Management Consulting Masterclass
# 1                     Management Consulting Masterclass
# 2                     Management Consulting Masterclass
# 3                     Management Consulting Masterclass
# 4                           IND AS and IFRS Masterclass
# ...                                                 ...
# 7694  Executive Program in Fintech, Banking, and App...
# 7695  Online Certificate Course in Enterprise Risk M...
# 7696         Corporate Leadership and People Management
# 7697  Executive Program in Fintech, Banking, and App...
# 7698  Executive Program in Fintech, Banking, and App...
#
#                                        Function  \
# 0                             Assurance - Audit
# 1                             Assurance - Audit
# 2                             Assurance - Audit
# 3                             Assurance - Audit
# 4                             Assurance - Audit
# ...                                         ...
# 7694  RM-Wholesale Business - Wholesale Banking
# 7695  RM-Wholesale Business - Wholesale Banking
# 7696  RM-Wholesale Business - Wholesale Banking
# 7697  RM-Wholesale Business - Wholesale Banking
# 7698  RM-Wholesale Business - Wholesale Banking
#
#                                         Skill  \
# 0         Stakeholder Relationship Management
# 1         Data Analytics & Insight Generation
# 2                       Business Intelligence
# 3                       Business Intelligence
# 4     Financial Reporting & Ind AS Compliance
# ...                                       ...
# 7694             Operational Discipline & MIS
# 7695         Negotiation & Commercial Selling
# 7696         Negotiation & Commercial Selling
# 7697         Negotiation & Commercial Selling
# 7698         Negotiation & Commercial Selling
#
#                                Concept course_level  \
# 0            Customer Lifecycle Review     Beginner
# 1           Analytics Tool Utilisation     Beginner
# 2          Business Analytics Strategy     Beginner
# 3     Data Analysis and Interpretation     Beginner
# 4        Lease Accounting (Ind AS 116)     Advanced
# ...                                ...          ...
# 7694    Continuous Process Improvement     Advanced
# 7695              Trade-Off Management     Advanced
# 7696               Win-Win Orientation     Advanced
# 7697              Commercial Awareness     Advanced
# 7698               Ethical Negotiation     Advanced
#
#                                             Course link  \
# 0     https://www.thinkingbridge.in/courses/Manageme...
# 1     https://www.thinkingbridge.in/courses/Manageme...
# 2     https://www.thinkingbridge.in/courses/Manageme...
# 3     https://www.thinkingbridge.in/courses/Manageme...
# 4     https://www.thinkingbridge.in/courses/IND-AS--...
# ...                                                 ...
# 7694  https://www.henryharvin.com/executive-program-...
# 7695  https://www.smartonlinecourse.co.in/courses/On...
# 7696  https://www.eduonix.com/corporate-leadership-a...
# 7697  https://www.henryharvin.com/executive-program-...
# 7698  https://www.henryharvin.com/executive-program-...
#
#                              CPP  \
# 0                Thinking Bridge
# 1                Thinking Bridge
# 2                Thinking Bridge
# 3                Thinking Bridge
# 4                Thinking Bridge
# ...                          ...
# 7694                Henry Harvin
# 7695         Smart Online Course
# 7696  Eduonix learning Solutions
# 7697                Henry Harvin
# 7698                Henry Harvin
#
#                                          Course Sylabus  product_id  \
# 0     Session 1 - 1.5 Hrs<br>Fundamentals of Managem...       37824
# 1     Session 1 - 1.5 Hrs<br>Fundamentals of Managem...       37824
# 2     Session 1 - 1.5 Hrs<br>Fundamentals of Managem...       37824
# 3     Session 1 - 1.5 Hrs<br>Fundamentals of Managem...       37824
# 4     Session 1 -<br>1.5 Hrs<br>IND AS & IFRS Master...       37822
# ...                                                 ...         ...
# 7694  Module 1: Overview of Risk Management in Banki...        6070
# 7695  Introduction to ERM:<br>What Makes a Risk "Ent...       36116
# 7696  Section 1 : Prepare your Environment<br>Welcom...       37853
# 7697  Module 1: Overview of Risk Management in Banki...        6070
# 7698  Module 1: Overview of Risk Management in Banki...        6070
#
#       Prod MP ID  ...  skill_id  concepts  Corporate id  \
# 0          38948  ...      1191     14777           [9]
# 1          38948  ...      1193     14796           [9]
# 2          38948  ...      1237      5652           [9]
# 3          38948  ...      1237      5730           [9]
# 4          38945  ...      1188     14740           [9]
# ...          ...  ...       ...       ...           ...
# 7694        1746  ...      1382     16035           [9]
# 7695       36981  ...      1384     16045           [9]
# 7696       38982  ...      1384     16047           [9]
# 7697        1746  ...      1384     16048           [9]
# 7698        1746  ...      1384     16049           [9]
#
#        Course Learning mode Duration  Duration_c    Price  \
# 0     Self-paced (Recorded)    20.00       Hours   2999.0
# 1     Self-paced (Recorded)    20.00       Hours   2999.0
# 2     Self-paced (Recorded)    20.00       Hours   2999.0
# 3     Self-paced (Recorded)    20.00       Hours   2999.0
# 4     Self-paced (Recorded)    20.00       Hours   2999.0
# ...                     ...      ...         ...      ...
# 7694  Self-paced (Recorded)   192.00       Hours  42275.0
# 7695  Self-paced (Recorded)     5.00       Hours   4200.0
# 7696  Self-paced (Recorded)     1.13       Hours   2348.2
# 7697  Self-paced (Recorded)   192.00       Hours  42275.0
# 7698  Self-paced (Recorded)   192.00       Hours  42275.0
#
#                                      Function 2                 Client ID  \
# 0                             Assurance - Audit  694662d4de84b15b52c5d89a
# 1                             Assurance - Audit  694662d4de84b15b52c5d89a
# 2                             Assurance - Audit  694662d4de84b15b52c5d89a
# 3                             Assurance - Audit  694662d4de84b15b52c5d89a
# 4                             Assurance - Audit  694670832521a451290ad559
# ...                                         ...                       ...
# 7694  RM-Wholesale Business - Wholesale Banking           FINTECH-BANKING
# 7695  RM-Wholesale Business - Wholesale Banking  694e8282f4334e63e303b84f
# 7696  RM-Wholesale Business - Wholesale Banking                     13047
# 7697  RM-Wholesale Business - Wholesale Banking           FINTECH-BANKING
# 7698  RM-Wholesale Business - Wholesale Banking           FINTECH-BANKING
#
#      Unnamed: 20
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 7694        5.01
# 7695        5.01
# 7696        5.01
# 7697        5.01
# 7698        5.01
#
# [7699 rows x 21 columns]

# %%
df1['PRODUCTION Concepts ID'].value_counts()
# Out:
# PRODUCTION Concepts ID
# 16043    6
# 15951    6
# 15960    6
# 15961    6
# 15962    6
#         ..
# 15527    1
# 15526    1
# 15525    1
# 15524    1
# 16147    1
# Name: count, Length: 1963, dtype: int64

# %% [markdown]
# If We want to remove some CPPs

# %%
# df2# data is the file which will only have CPP names

# # List of values to check
# values_to_check = ['Coursera','GVC','Gyanodaya Virtual Campus','CIEL','Percipio']

# # Check if any values in the DataFrame are in the list
# df2['CPP_ABC'] = df2['CPP Name'].isin(values_to_check)
# df2 = df2.query("CPP_ABC == False")
# df2

# %%
# Concept Column Row splitting code
df2['concepts'] = df2['concepts'].apply(
    lambda x: [int(i.strip()) for i in x.split(',')] if isinstance(x, str) else x
)

# Explode the 'concepts' column to create separate rows
df = df2.explode('concepts', ignore_index=True)
df['concepts'] = df['concepts'].fillna(0).astype(int)


df
# Out:
#                                             Course Name  \
# 0                     Management Consulting Masterclass
# 1                     Management Consulting Masterclass
# 2                     Management Consulting Masterclass
# 3                     Management Consulting Masterclass
# 4                           IND AS and IFRS Masterclass
# ...                                                 ...
# 7694  Executive Program in Fintech, Banking, and App...
# 7695  Online Certificate Course in Enterprise Risk M...
# 7696         Corporate Leadership and People Management
# 7697  Executive Program in Fintech, Banking, and App...
# 7698  Executive Program in Fintech, Banking, and App...
#
#                                        Function  \
# 0                             Assurance - Audit
# 1                             Assurance - Audit
# 2                             Assurance - Audit
# 3                             Assurance - Audit
# 4                             Assurance - Audit
# ...                                         ...
# 7694  RM-Wholesale Business - Wholesale Banking
# 7695  RM-Wholesale Business - Wholesale Banking
# 7696  RM-Wholesale Business - Wholesale Banking
# 7697  RM-Wholesale Business - Wholesale Banking
# 7698  RM-Wholesale Business - Wholesale Banking
#
#                                         Skill  \
# 0         Stakeholder Relationship Management
# 1         Data Analytics & Insight Generation
# 2                       Business Intelligence
# 3                       Business Intelligence
# 4     Financial Reporting & Ind AS Compliance
# ...                                       ...
# 7694             Operational Discipline & MIS
# 7695         Negotiation & Commercial Selling
# 7696         Negotiation & Commercial Selling
# 7697         Negotiation & Commercial Selling
# 7698         Negotiation & Commercial Selling
#
#                                Concept course_level  \
# 0            Customer Lifecycle Review     Beginner
# 1           Analytics Tool Utilisation     Beginner
# 2          Business Analytics Strategy     Beginner
# 3     Data Analysis and Interpretation     Beginner
# 4        Lease Accounting (Ind AS 116)     Advanced
# ...                                ...          ...
# 7694    Continuous Process Improvement     Advanced
# 7695              Trade-Off Management     Advanced
# 7696               Win-Win Orientation     Advanced
# 7697              Commercial Awareness     Advanced
# 7698               Ethical Negotiation     Advanced
#
#                                             Course link  \
# 0     https://www.thinkingbridge.in/courses/Manageme...
# 1     https://www.thinkingbridge.in/courses/Manageme...
# 2     https://www.thinkingbridge.in/courses/Manageme...
# 3     https://www.thinkingbridge.in/courses/Manageme...
# 4     https://www.thinkingbridge.in/courses/IND-AS--...
# ...                                                 ...
# 7694  https://www.henryharvin.com/executive-program-...
# 7695  https://www.smartonlinecourse.co.in/courses/On...
# 7696  https://www.eduonix.com/corporate-leadership-a...
# 7697  https://www.henryharvin.com/executive-program-...
# 7698  https://www.henryharvin.com/executive-program-...
#
#                              CPP  \
# 0                Thinking Bridge
# 1                Thinking Bridge
# 2                Thinking Bridge
# 3                Thinking Bridge
# 4                Thinking Bridge
# ...                          ...
# 7694                Henry Harvin
# 7695         Smart Online Course
# 7696  Eduonix learning Solutions
# 7697                Henry Harvin
# 7698                Henry Harvin
#
#                                          Course Sylabus  product_id  \
# 0     Session 1 - 1.5 Hrs<br>Fundamentals of Managem...       37824
# 1     Session 1 - 1.5 Hrs<br>Fundamentals of Managem...       37824
# 2     Session 1 - 1.5 Hrs<br>Fundamentals of Managem...       37824
# 3     Session 1 - 1.5 Hrs<br>Fundamentals of Managem...       37824
# 4     Session 1 -<br>1.5 Hrs<br>IND AS & IFRS Master...       37822
# ...                                                 ...         ...
# 7694  Module 1: Overview of Risk Management in Banki...        6070
# 7695  Introduction to ERM:<br>What Makes a Risk "Ent...       36116
# 7696  Section 1 : Prepare your Environment<br>Welcom...       37853
# 7697  Module 1: Overview of Risk Management in Banki...        6070
# 7698  Module 1: Overview of Risk Management in Banki...        6070
#
#       Prod MP ID  ...  skill_id  concepts  Corporate id  \
# 0          38948  ...      1191     14777           [9]
# 1          38948  ...      1193     14796           [9]
# 2          38948  ...      1237      5652           [9]
# 3          38948  ...      1237      5730           [9]
# 4          38945  ...      1188     14740           [9]
# ...          ...  ...       ...       ...           ...
# 7694        1746  ...      1382     16035           [9]
# 7695       36981  ...      1384     16045           [9]
# 7696       38982  ...      1384     16047           [9]
# 7697        1746  ...      1384     16048           [9]
# 7698        1746  ...      1384     16049           [9]
#
#        Course Learning mode Duration  Duration_c    Price  \
# 0     Self-paced (Recorded)    20.00       Hours   2999.0
# 1     Self-paced (Recorded)    20.00       Hours   2999.0
# 2     Self-paced (Recorded)    20.00       Hours   2999.0
# 3     Self-paced (Recorded)    20.00       Hours   2999.0
# 4     Self-paced (Recorded)    20.00       Hours   2999.0
# ...                     ...      ...         ...      ...
# 7694  Self-paced (Recorded)   192.00       Hours  42275.0
# 7695  Self-paced (Recorded)     5.00       Hours   4200.0
# 7696  Self-paced (Recorded)     1.13       Hours   2348.2
# 7697  Self-paced (Recorded)   192.00       Hours  42275.0
# 7698  Self-paced (Recorded)   192.00       Hours  42275.0
#
#                                      Function 2                 Client ID  \
# 0                             Assurance - Audit  694662d4de84b15b52c5d89a
# 1                             Assurance - Audit  694662d4de84b15b52c5d89a
# 2                             Assurance - Audit  694662d4de84b15b52c5d89a
# 3                             Assurance - Audit  694662d4de84b15b52c5d89a
# 4                             Assurance - Audit  694670832521a451290ad559
# ...                                         ...                       ...
# 7694  RM-Wholesale Business - Wholesale Banking           FINTECH-BANKING
# 7695  RM-Wholesale Business - Wholesale Banking  694e8282f4334e63e303b84f
# 7696  RM-Wholesale Business - Wholesale Banking                     13047
# 7697  RM-Wholesale Business - Wholesale Banking           FINTECH-BANKING
# 7698  RM-Wholesale Business - Wholesale Banking           FINTECH-BANKING
#
#      Unnamed: 20
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 7694        5.01
# 7695        5.01
# 7696        5.01
# 7697        5.01
# 7698        5.01
#
# [7699 rows x 21 columns]

# %%
# Concept Column Row splitting code
df2['concepts'] = df2['concepts'].apply(
    lambda x: [int(i.strip()) for i in x.split(',')] if isinstance(x, str) else x
)

# Explode the 'concepts' column to create separate rows
df = df2.explode('concepts', ignore_index=True)
df['concepts'] = df['concepts'].fillna(0).astype(int)


df
# Out:
#                                             Course Name  \
# 0                     Management Consulting Masterclass
# 1                     Management Consulting Masterclass
# 2                     Management Consulting Masterclass
# 3                     Management Consulting Masterclass
# 4                           IND AS and IFRS Masterclass
# ...                                                 ...
# 7694  Executive Program in Fintech, Banking, and App...
# 7695  Online Certificate Course in Enterprise Risk M...
# 7696         Corporate Leadership and People Management
# 7697  Executive Program in Fintech, Banking, and App...
# 7698  Executive Program in Fintech, Banking, and App...
#
#                                        Function  \
# 0                             Assurance - Audit
# 1                             Assurance - Audit
# 2                             Assurance - Audit
# 3                             Assurance - Audit
# 4                             Assurance - Audit
# ...                                         ...
# 7694  RM-Wholesale Business - Wholesale Banking
# 7695  RM-Wholesale Business - Wholesale Banking
# 7696  RM-Wholesale Business - Wholesale Banking
# 7697  RM-Wholesale Business - Wholesale Banking
# 7698  RM-Wholesale Business - Wholesale Banking
#
#                                         Skill  \
# 0         Stakeholder Relationship Management
# 1         Data Analytics & Insight Generation
# 2                       Business Intelligence
# 3                       Business Intelligence
# 4     Financial Reporting & Ind AS Compliance
# ...                                       ...
# 7694             Operational Discipline & MIS
# 7695         Negotiation & Commercial Selling
# 7696         Negotiation & Commercial Selling
# 7697         Negotiation & Commercial Selling
# 7698         Negotiation & Commercial Selling
#
#                                Concept course_level  \
# 0            Customer Lifecycle Review     Beginner
# 1           Analytics Tool Utilisation     Beginner
# 2          Business Analytics Strategy     Beginner
# 3     Data Analysis and Interpretation     Beginner
# 4        Lease Accounting (Ind AS 116)     Advanced
# ...                                ...          ...
# 7694    Continuous Process Improvement     Advanced
# 7695              Trade-Off Management     Advanced
# 7696               Win-Win Orientation     Advanced
# 7697              Commercial Awareness     Advanced
# 7698               Ethical Negotiation     Advanced
#
#                                             Course link  \
# 0     https://www.thinkingbridge.in/courses/Manageme...
# 1     https://www.thinkingbridge.in/courses/Manageme...
# 2     https://www.thinkingbridge.in/courses/Manageme...
# 3     https://www.thinkingbridge.in/courses/Manageme...
# 4     https://www.thinkingbridge.in/courses/IND-AS--...
# ...                                                 ...
# 7694  https://www.henryharvin.com/executive-program-...
# 7695  https://www.smartonlinecourse.co.in/courses/On...
# 7696  https://www.eduonix.com/corporate-leadership-a...
# 7697  https://www.henryharvin.com/executive-program-...
# 7698  https://www.henryharvin.com/executive-program-...
#
#                              CPP  \
# 0                Thinking Bridge
# 1                Thinking Bridge
# 2                Thinking Bridge
# 3                Thinking Bridge
# 4                Thinking Bridge
# ...                          ...
# 7694                Henry Harvin
# 7695         Smart Online Course
# 7696  Eduonix learning Solutions
# 7697                Henry Harvin
# 7698                Henry Harvin
#
#                                          Course Sylabus  product_id  \
# 0     Session 1 - 1.5 Hrs<br>Fundamentals of Managem...       37824
# 1     Session 1 - 1.5 Hrs<br>Fundamentals of Managem...       37824
# 2     Session 1 - 1.5 Hrs<br>Fundamentals of Managem...       37824
# 3     Session 1 - 1.5 Hrs<br>Fundamentals of Managem...       37824
# 4     Session 1 -<br>1.5 Hrs<br>IND AS & IFRS Master...       37822
# ...                                                 ...         ...
# 7694  Module 1: Overview of Risk Management in Banki...        6070
# 7695  Introduction to ERM:<br>What Makes a Risk "Ent...       36116
# 7696  Section 1 : Prepare your Environment<br>Welcom...       37853
# 7697  Module 1: Overview of Risk Management in Banki...        6070
# 7698  Module 1: Overview of Risk Management in Banki...        6070
#
#       Prod MP ID  ...  skill_id  concepts  Corporate id  \
# 0          38948  ...      1191     14777           [9]
# 1          38948  ...      1193     14796           [9]
# 2          38948  ...      1237      5652           [9]
# 3          38948  ...      1237      5730           [9]
# 4          38945  ...      1188     14740           [9]
# ...          ...  ...       ...       ...           ...
# 7694        1746  ...      1382     16035           [9]
# 7695       36981  ...      1384     16045           [9]
# 7696       38982  ...      1384     16047           [9]
# 7697        1746  ...      1384     16048           [9]
# 7698        1746  ...      1384     16049           [9]
#
#        Course Learning mode Duration  Duration_c    Price  \
# 0     Self-paced (Recorded)    20.00       Hours   2999.0
# 1     Self-paced (Recorded)    20.00       Hours   2999.0
# 2     Self-paced (Recorded)    20.00       Hours   2999.0
# 3     Self-paced (Recorded)    20.00       Hours   2999.0
# 4     Self-paced (Recorded)    20.00       Hours   2999.0
# ...                     ...      ...         ...      ...
# 7694  Self-paced (Recorded)   192.00       Hours  42275.0
# 7695  Self-paced (Recorded)     5.00       Hours   4200.0
# 7696  Self-paced (Recorded)     1.13       Hours   2348.2
# 7697  Self-paced (Recorded)   192.00       Hours  42275.0
# 7698  Self-paced (Recorded)   192.00       Hours  42275.0
#
#                                      Function 2                 Client ID  \
# 0                             Assurance - Audit  694662d4de84b15b52c5d89a
# 1                             Assurance - Audit  694662d4de84b15b52c5d89a
# 2                             Assurance - Audit  694662d4de84b15b52c5d89a
# 3                             Assurance - Audit  694662d4de84b15b52c5d89a
# 4                             Assurance - Audit  694670832521a451290ad559
# ...                                         ...                       ...
# 7694  RM-Wholesale Business - Wholesale Banking           FINTECH-BANKING
# 7695  RM-Wholesale Business - Wholesale Banking  694e8282f4334e63e303b84f
# 7696  RM-Wholesale Business - Wholesale Banking                     13047
# 7697  RM-Wholesale Business - Wholesale Banking           FINTECH-BANKING
# 7698  RM-Wholesale Business - Wholesale Banking           FINTECH-BANKING
#
#      Unnamed: 20
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 7694        5.01
# 7695        5.01
# 7696        5.01
# 7697        5.01
# 7698        5.01
#
# [7699 rows x 21 columns]

# %%
# Renaming Flexible to Beginner in Course level column
df['course_level'] = df['course_level'].replace('Flexible', 'Beginner')

# %%
df['course_level'].unique()
# Out:
# array(['Beginner', 'Advanced', 'Intermediate'], dtype=object)

# %%
# Concat of Skill Concept
#df['FSC_concat'] = df['skill_id'].astype(str)+'|'+df['concepts'].astype(str)
#df['FSC_concat'] = df['concepts'].astype(str)
df['FSC_concat'] =  df['Function'].astype(str) + '|'+  df['skill_id'].astype(str)+'|'+df['concepts'].astype(str)
df['FSC_concat']
# Out:
# 0                            Assurance - Audit|1191|14777
# 1                            Assurance - Audit|1193|14796
# 2                             Assurance - Audit|1237|5652
# 3                             Assurance - Audit|1237|5730
# 4                            Assurance - Audit|1188|14740
#                               ...
# 7694    RM-Wholesale Business - Wholesale Banking|1382...
# 7695    RM-Wholesale Business - Wholesale Banking|1384...
# 7696    RM-Wholesale Business - Wholesale Banking|1384...
# 7697    RM-Wholesale Business - Wholesale Banking|1384...
# 7698    RM-Wholesale Business - Wholesale Banking|1384...
# Name: FSC_concat, Length: 7699, dtype: object

# %%
uniquedf = df.drop_duplicates(subset=['FSC_concat'])
uniquedf=uniquedf['FSC_concat']
uniquedf
# Out:
# 0                    Assurance - Audit|1191|14777
# 1                    Assurance - Audit|1193|14796
# 2                     Assurance - Audit|1237|5652
# 3                     Assurance - Audit|1237|5730
# 4                    Assurance - Audit|1188|14740
#                           ...
# 7237        RM-Consumer Bank - Product|1441|16443
# 7271    RM-Consumer Bank - Proposition|1455|16544
# 7273    RM-Consumer Bank - Proposition|1456|16552
# 7281    RM-Consumer Bank - Proposition|1458|16567
# 7398            RM-Consumer Bank - 811|1419|16290
# Name: FSC_concat, Length: 2477, dtype: object

# %%
# Making new dataframe of Advanced course level only.
Advanced = df[df['course_level'] == 'Advanced']
Advanced
# Out:
#                                             Course Name  \
# 4                           IND AS and IFRS Masterclass
# 5                           IND AS and IFRS Masterclass
# 6                           IND AS and IFRS Masterclass
# 7                           IND AS and IFRS Masterclass
# 8                           IND AS and IFRS Masterclass
# ...                                                 ...
# 7694  Executive Program in Fintech, Banking, and App...
# 7695  Online Certificate Course in Enterprise Risk M...
# 7696         Corporate Leadership and People Management
# 7697  Executive Program in Fintech, Banking, and App...
# 7698  Executive Program in Fintech, Banking, and App...
#
#                                        Function  \
# 4                             Assurance - Audit
# 5                             Assurance - Audit
# 6                             Assurance - Audit
# 7                             Assurance - Audit
# 8                             Assurance - Audit
# ...                                         ...
# 7694  RM-Wholesale Business - Wholesale Banking
# 7695  RM-Wholesale Business - Wholesale Banking
# 7696  RM-Wholesale Business - Wholesale Banking
# 7697  RM-Wholesale Business - Wholesale Banking
# 7698  RM-Wholesale Business - Wholesale Banking
#
#                                         Skill                         Concept  \
# 4     Financial Reporting & Ind AS Compliance   Lease Accounting (Ind AS 116)
# 5     Financial Reporting & Ind AS Compliance          Acquisition Accounting
# 6     Financial Reporting & Ind AS Compliance      Joint Operation Accounting
# 7     Financial Reporting & Ind AS Compliance               Ind AS 8 Policies
# 8     Financial Reporting & Ind AS Compliance             Cash-Settled Awards
# ...                                       ...                             ...
# 7694             Operational Discipline & MIS  Continuous Process Improvement
# 7695         Negotiation & Commercial Selling            Trade-Off Management
# 7696         Negotiation & Commercial Selling             Win-Win Orientation
# 7697         Negotiation & Commercial Selling            Commercial Awareness
# 7698         Negotiation & Commercial Selling             Ethical Negotiation
#
#      course_level                                        Course link  \
# 4        Advanced  https://www.thinkingbridge.in/courses/IND-AS--...
# 5        Advanced  https://www.thinkingbridge.in/courses/IND-AS--...
# 6        Advanced  https://www.thinkingbridge.in/courses/IND-AS--...
# 7        Advanced  https://www.thinkingbridge.in/courses/IND-AS--...
# 8        Advanced  https://www.thinkingbridge.in/courses/IND-AS--...
# ...           ...                                                ...
# 7694     Advanced  https://www.henryharvin.com/executive-program-...
# 7695     Advanced  https://www.smartonlinecourse.co.in/courses/On...
# 7696     Advanced  https://www.eduonix.com/corporate-leadership-a...
# 7697     Advanced  https://www.henryharvin.com/executive-program-...
# 7698     Advanced  https://www.henryharvin.com/executive-program-...
#
#                              CPP  \
# 4                Thinking Bridge
# 5                Thinking Bridge
# 6                Thinking Bridge
# 7                Thinking Bridge
# 8                Thinking Bridge
# ...                          ...
# 7694                Henry Harvin
# 7695         Smart Online Course
# 7696  Eduonix learning Solutions
# 7697                Henry Harvin
# 7698                Henry Harvin
#
#                                          Course Sylabus  product_id  \
# 4     Session 1 -<br>1.5 Hrs<br>IND AS & IFRS Master...       37822
# 5     Session 1 -<br>1.5 Hrs<br>IND AS & IFRS Master...       37822
# 6     Session 1 -<br>1.5 Hrs<br>IND AS & IFRS Master...       37822
# 7     Session 1 -<br>1.5 Hrs<br>IND AS & IFRS Master...       37822
# 8     Session 1 -<br>1.5 Hrs<br>IND AS & IFRS Master...       37822
# ...                                                 ...         ...
# 7694  Module 1: Overview of Risk Management in Banki...        6070
# 7695  Introduction to ERM:<br>What Makes a Risk "Ent...       36116
# 7696  Section 1 : Prepare your Environment<br>Welcom...       37853
# 7697  Module 1: Overview of Risk Management in Banki...        6070
# 7698  Module 1: Overview of Risk Management in Banki...        6070
#
#       Prod MP ID  ...  concepts  Corporate id   Course Learning mode Duration  \
# 4          38945  ...     14740           [9]  Self-paced (Recorded)    20.00
# 5          38945  ...     14741           [9]  Self-paced (Recorded)    20.00
# 6          38945  ...     14742           [9]  Self-paced (Recorded)    20.00
# 7          38945  ...     14743           [9]  Self-paced (Recorded)    20.00
# 8          38945  ...     14745           [9]  Self-paced (Recorded)    20.00
# ...          ...  ...       ...           ...                    ...      ...
# 7694        1746  ...     16035           [9]  Self-paced (Recorded)   192.00
# 7695       36981  ...     16045           [9]  Self-paced (Recorded)     5.00
# 7696       38982  ...     16047           [9]  Self-paced (Recorded)     1.13
# 7697        1746  ...     16048           [9]  Self-paced (Recorded)   192.00
# 7698        1746  ...     16049           [9]  Self-paced (Recorded)   192.00
#
#      Duration_c    Price                                 Function 2  \
# 4         Hours   2999.0                          Assurance - Audit
# 5         Hours   2999.0                          Assurance - Audit
# 6         Hours   2999.0                          Assurance - Audit
# 7         Hours   2999.0                          Assurance - Audit
# 8         Hours   2999.0                          Assurance - Audit
# ...         ...      ...                                        ...
# 7694      Hours  42275.0  RM-Wholesale Business - Wholesale Banking
# 7695      Hours   4200.0  RM-Wholesale Business - Wholesale Banking
# 7696      Hours   2348.2  RM-Wholesale Business - Wholesale Banking
# 7697      Hours  42275.0  RM-Wholesale Business - Wholesale Banking
# 7698      Hours  42275.0  RM-Wholesale Business - Wholesale Banking
#
#                      Client ID Unnamed: 20  \
# 4     694670832521a451290ad559         NaN
# 5     694670832521a451290ad559         NaN
# 6     694670832521a451290ad559         NaN
# 7     694670832521a451290ad559         NaN
# 8     694670832521a451290ad559         NaN
# ...                        ...         ...
# 7694           FINTECH-BANKING        5.01
# 7695  694e8282f4334e63e303b84f        5.01
# 7696                     13047        5.01
# 7697           FINTECH-BANKING        5.01
# 7698           FINTECH-BANKING        5.01
#
#                                              FSC_concat
# 4                          Assurance - Audit|1188|14740
# 5                          Assurance - Audit|1188|14741
# 6                          Assurance - Audit|1188|14742
# 7                          Assurance - Audit|1188|14743
# 8                          Assurance - Audit|1188|14745
# ...                                                 ...
# 7694  RM-Wholesale Business - Wholesale Banking|1382...
# 7695  RM-Wholesale Business - Wholesale Banking|1384...
# 7696  RM-Wholesale Business - Wholesale Banking|1384...
# 7697  RM-Wholesale Business - Wholesale Banking|1384...
# 7698  RM-Wholesale Business - Wholesale Banking|1384...
#
# [2287 rows x 22 columns]

# %%
# Counting the number of courses in Advanced course level against the FSC_concat column.
result_Advanced =  Advanced.groupby("FSC_concat")["product_id"].nunique().reset_index()
result_Advanced.columns = ["FSC_concat", "Function_count_Advanced"]
result_Advanced.head()
# Out:
#                      FSC_concat  Function_count_Advanced
# 0  Assurance - Audit|1188|14739                        1
# 1  Assurance - Audit|1188|14740                        2
# 2  Assurance - Audit|1188|14741                        1
# 3  Assurance - Audit|1188|14742                        1
# 4  Assurance - Audit|1188|14743                        2

# %%
Beginner = df[df['course_level'] == 'Beginner']
Beginner
# Out:
#                                            Course Name  \
# 0                    Management Consulting Masterclass
# 1                    Management Consulting Masterclass
# 2                    Management Consulting Masterclass
# 3                    Management Consulting Masterclass
# 19                                   Big 4 Masterclass
# ...                                                ...
# 7150  Post Graduate Program in Supply Chain Management
# 7151  Post Graduate Program in Supply Chain Management
# 7152                                        FRM Course
# 7153                                Banking Law Course
# 7154                                        FRM Course
#
#                                        Function  \
# 0                             Assurance - Audit
# 1                             Assurance - Audit
# 2                             Assurance - Audit
# 3                             Assurance - Audit
# 19                            Assurance - Audit
# ...                                         ...
# 7150  RM-Wholesale Business - Wholesale Banking
# 7151  RM-Wholesale Business - Wholesale Banking
# 7152  RM-Wholesale Business - Wholesale Banking
# 7153  RM-Wholesale Business - Wholesale Banking
# 7154  RM-Wholesale Business - Wholesale Banking
#
#                                     Skill                           Concept  \
# 0     Stakeholder Relationship Management         Customer Lifecycle Review
# 1     Data Analytics & Insight Generation        Analytics Tool Utilisation
# 2                   Business Intelligence       Business Analytics Strategy
# 3                   Business Intelligence  Data Analysis and Interpretation
# 19           Risk-Based Audit Methodology         Data-Driven Audit Methods
# ...                                   ...                               ...
# 7150       Supply Chain Finance Solutions                  Vendor Financing
# 7151       Supply Chain Finance Solutions                   Buyer Financing
# 7152        Collateral Audit Coordination            Valuation Coordination
# 7153        Collateral Audit Coordination                  Audit Scheduling
# 7154       Client Relationship Management       Relationship Risk Awareness
#
#      course_level                                        Course link  \
# 0        Beginner  https://www.thinkingbridge.in/courses/Manageme...
# 1        Beginner  https://www.thinkingbridge.in/courses/Manageme...
# 2        Beginner  https://www.thinkingbridge.in/courses/Manageme...
# 3        Beginner  https://www.thinkingbridge.in/courses/Manageme...
# 19       Beginner  https://www.thinkingbridge.in/courses/Big-4-Ma...
# ...           ...                                                ...
# 7150     Beginner  https://www.henryharvin.com/post-graduate-prog...
# 7151     Beginner  https://www.henryharvin.com/post-graduate-prog...
# 7152     Beginner                 https://henryharvin.com/frm-course
# 7153     Beginner     https://www.henryharvin.com/banking-law-course
# 7154     Beginner                 https://henryharvin.com/frm-course
#
#                   CPP                                     Course Sylabus  \
# 0     Thinking Bridge  Session 1 - 1.5 Hrs<br>Fundamentals of Managem...
# 1     Thinking Bridge  Session 1 - 1.5 Hrs<br>Fundamentals of Managem...
# 2     Thinking Bridge  Session 1 - 1.5 Hrs<br>Fundamentals of Managem...
# 3     Thinking Bridge  Session 1 - 1.5 Hrs<br>Fundamentals of Managem...
# 19    Thinking Bridge  Session 1 - 0.5 Hrs<br>Introductory Session - ...
# ...               ...                                                ...
# 7150     Henry Harvin  Module 1: Modelling & Analytics Tools<br>-Basi...
# 7151     Henry Harvin  Module 1: Modelling & Analytics Tools<br>-Basi...
# 7152     Henry Harvin  Module 1: Quantitative Analysis<br>- Discrete ...
# 7153     Henry Harvin  Banking Law Course Curriculum<br>Module 1: Ban...
# 7154     Henry Harvin  Module 1: Quantitative Analysis<br>- Discrete ...
#
#       product_id  Prod MP ID  ...  concepts  Corporate id  \
# 0          37824       38948  ...     14777           [9]
# 1          37824       38948  ...     14796           [9]
# 2          37824       38948  ...      5652           [9]
# 3          37824       38948  ...      5730           [9]
# 19         37834       38950  ...     14752           [9]
# ...          ...         ...  ...       ...           ...
# 7150        6272        1943  ...     16128           [9]
# 7151        6272        1943  ...     16129           [9]
# 7152       35112       36039  ...     16142           [9]
# 7153        6041        1649  ...     16143           [9]
# 7154       35112       36039  ...     15965           [9]
#
#        Course Learning mode Duration Duration_c     Price  \
# 0     Self-paced (Recorded)     20.0      Hours    2999.0
# 1     Self-paced (Recorded)     20.0      Hours    2999.0
# 2     Self-paced (Recorded)     20.0      Hours    2999.0
# 3     Self-paced (Recorded)     20.0      Hours    2999.0
# 19    Self-paced (Recorded)     25.0      Hours   10000.0
# ...                     ...      ...        ...       ...
# 7150  Self-paced (Recorded)    140.0      Hours  189500.0
# 7151  Self-paced (Recorded)    140.0      Hours  189500.0
# 7152  Self-paced (Recorded)    192.0      Hours   59500.0
# 7153  Self-paced (Recorded)     12.0      Hours   10000.0
# 7154  Self-paced (Recorded)    192.0      Hours   59500.0
#
#                                      Function 2                 Client ID  \
# 0                             Assurance - Audit  694662d4de84b15b52c5d89a
# 1                             Assurance - Audit  694662d4de84b15b52c5d89a
# 2                             Assurance - Audit  694662d4de84b15b52c5d89a
# 3                             Assurance - Audit  694662d4de84b15b52c5d89a
# 19                            Assurance - Audit  688cd0427eccb75ab122cc55
# ...                                         ...                       ...
# 7150  RM-Wholesale Business - Wholesale Banking           pg-supply-chain
# 7151  RM-Wholesale Business - Wholesale Banking           pg-supply-chain
# 7152  RM-Wholesale Business - Wholesale Banking                       FRM
# 7153  RM-Wholesale Business - Wholesale Banking               Banking Law
# 7154  RM-Wholesale Business - Wholesale Banking                       FRM
#
#      Unnamed: 20                                         FSC_concat
# 0            NaN                       Assurance - Audit|1191|14777
# 1            NaN                       Assurance - Audit|1193|14796
# 2            NaN                        Assurance - Audit|1237|5652
# 3            NaN                        Assurance - Audit|1237|5730
# 19           NaN                       Assurance - Audit|1189|14752
# ...          ...                                                ...
# 7150        3.01  RM-Wholesale Business - Wholesale Banking|1396...
# 7151        3.01  RM-Wholesale Business - Wholesale Banking|1396...
# 7152        3.01  RM-Wholesale Business - Wholesale Banking|1398...
# 7153        3.01  RM-Wholesale Business - Wholesale Banking|1398...
# 7154        3.01  RM-Wholesale Business - Wholesale Banking|1372...
#
# [2980 rows x 22 columns]

# %%
result_Beginner =  Beginner.groupby("FSC_concat")["product_id"].nunique().reset_index()
result_Beginner.columns = ["FSC_concat", "Function_count_beginner"]
result_Beginner.head()
# Out:
#                      FSC_concat  Function_count_beginner
# 0  Assurance - Audit|1188|14739                        1
# 1  Assurance - Audit|1188|14740                        1
# 2  Assurance - Audit|1188|14741                        1
# 3  Assurance - Audit|1188|14742                        1
# 4  Assurance - Audit|1188|14743                        1

# %%
Intermediate = df[df['course_level'] == 'Intermediate']
Intermediate.head()
# Out:
#                                          Course Name           Function  \
# 30  Financial Planning & Analysis (FP&A) Masterclass  Assurance - Audit
# 31  Financial Planning & Analysis (FP&A) Masterclass  Assurance - Audit
# 32  Financial Planning & Analysis (FP&A) Masterclass  Assurance - Audit
# 33  Financial Planning & Analysis (FP&A) Masterclass  Assurance - Audit
# 34  Financial Planning & Analysis (FP&A) Masterclass  Assurance - Audit
#
#                                   Skill                     Concept  \
# 30  Data Analytics & Insight Generation     Data Narrative Building
# 31  Data Analytics & Insight Generation     Data Quality Validation
# 32  Data Analytics & Insight Generation  Analytics Tool Utilisation
# 33   Audit Findings & Results Reporting         Executive Reporting
# 34   Audit Findings & Results Reporting  Cross-Functional Reporting
#
#     course_level                                        Course link  \
# 30  Intermediate  https://www.thinkingbridge.in/courses/Financia...
# 31  Intermediate  https://www.thinkingbridge.in/courses/Financia...
# 32  Intermediate  https://www.thinkingbridge.in/courses/Financia...
# 33  Intermediate  https://www.thinkingbridge.in/courses/Financia...
# 34  Intermediate  https://www.thinkingbridge.in/courses/Financia...
#
#                 CPP                                     Course Sylabus  \
# 30  Thinking Bridge  Session 1 - 1.5 Hrs<br>Introduction to FP&A & ...
# 31  Thinking Bridge  Session 1 - 1.5 Hrs<br>Introduction to FP&A & ...
# 32  Thinking Bridge  Session 1 - 1.5 Hrs<br>Introduction to FP&A & ...
# 33  Thinking Bridge  Session 1 - 1.5 Hrs<br>Introduction to FP&A & ...
# 34  Thinking Bridge  Session 1 - 1.5 Hrs<br>Introduction to FP&A & ...
#
#     product_id  Prod MP ID  ...  concepts  Corporate id  \
# 30       37833       38955  ...     14789           [9]
# 31       37833       38955  ...     14790           [9]
# 32       37833       38955  ...     14796           [9]
# 33       37833       38955  ...     14950           [9]
# 34       37833       38955  ...     14956           [9]
#
#      Course Learning mode Duration Duration_c   Price         Function 2  \
# 30  Self-paced (Recorded)     20.0      Hours  2999.0  Assurance - Audit
# 31  Self-paced (Recorded)     20.0      Hours  2999.0  Assurance - Audit
# 32  Self-paced (Recorded)     20.0      Hours  2999.0  Assurance - Audit
# 33  Self-paced (Recorded)     20.0      Hours  2999.0  Assurance - Audit
# 34  Self-paced (Recorded)     20.0      Hours  2999.0  Assurance - Audit
#
#                    Client ID Unnamed: 20                    FSC_concat
# 30  69466e60de84b15b52c5dd34         NaN  Assurance - Audit|1193|14789
# 31  69466e60de84b15b52c5dd34         NaN  Assurance - Audit|1193|14790
# 32  69466e60de84b15b52c5dd34         NaN  Assurance - Audit|1193|14796
# 33  69466e60de84b15b52c5dd34         NaN  Assurance - Audit|1209|14950
# 34  69466e60de84b15b52c5dd34         NaN  Assurance - Audit|1209|14956
#
# [5 rows x 22 columns]

# %%
result_Intermediate =  Intermediate.groupby("FSC_concat")["product_id"].nunique().reset_index()
result_Intermediate.columns = ["FSC_concat", "Function_count_intermediate"]
result_Intermediate.head()
# Out:
#                      FSC_concat  Function_count_intermediate
# 0  Assurance - Audit|1188|14739                            1
# 1  Assurance - Audit|1188|14740                            1
# 2  Assurance - Audit|1188|14741                            2
# 3  Assurance - Audit|1188|14742                            1
# 4  Assurance - Audit|1188|14743                            1

# %%
unique_values_df = df.drop_duplicates(subset=['FSC_concat'])
unique_values_df = unique_values_df[['FSC_concat']]
unique_values_df.head()
# Out:
#                      FSC_concat
# 0  Assurance - Audit|1191|14777
# 1  Assurance - Audit|1193|14796
# 2   Assurance - Audit|1237|5652
# 3   Assurance - Audit|1237|5730
# 4  Assurance - Audit|1188|14740

# %%
merged_df = pd.merge(unique_values_df, result_Beginner, on="FSC_concat", how="left")  # Merge df1 and df2
merged_df = pd.merge(merged_df, result_Intermediate, on="FSC_concat", how="left")  # Merge with df3
merged_df = pd.merge(merged_df, result_Advanced, on="FSC_concat", how="left")
merged_df.head()
# Out:
#                      FSC_concat  Function_count_beginner  \
# 0  Assurance - Audit|1191|14777                      1.0
# 1  Assurance - Audit|1193|14796                      2.0
# 2   Assurance - Audit|1237|5652                      2.0
# 3   Assurance - Audit|1237|5730                      2.0
# 4  Assurance - Audit|1188|14740                      1.0
#
#    Function_count_intermediate  Function_count_Advanced
# 0                          1.0                      1.0
# 1                          4.0                      3.0
# 2                          2.0                      1.0
# 3                          2.0                      3.0
# 4                          1.0                      2.0

# %%
# If you're working with a single column but want to keep it as a DataFrame:
merged_df['Function_count_beginner'] = merged_df['Function_count_beginner'].fillna(0).astype(int)
merged_df['Function_count_intermediate'] = merged_df['Function_count_intermediate'].fillna(0).astype(int)
merged_df['Function_count_Advanced'] = merged_df['Function_count_Advanced'].fillna(0).astype(int)
merged_df.head()
# Out:
#                      FSC_concat  Function_count_beginner  \
# 0  Assurance - Audit|1191|14777                        1
# 1  Assurance - Audit|1193|14796                        2
# 2   Assurance - Audit|1237|5652                        2
# 3   Assurance - Audit|1237|5730                        2
# 4  Assurance - Audit|1188|14740                        1
#
#    Function_count_intermediate  Function_count_Advanced
# 0                            1                        1
# 1                            4                        3
# 2                            2                        1
# 3                            2                        3
# 4                            1                        2

# %%
#df1['Skill ID'].unique()
#df1['FSC_concat']= df1['PRODUCTION Skill ID'].fillna(0).astype(int).astype(str)+"|"+df1['PRODUCTION Concepts ID'].fillna(0).astype(int).astype(str)
#df1.head()

# %%
#df1['FSC_concat'] = (
    #pd.to_numeric(df1['PRODUCTION Skill ID'], errors='coerce').fillna(0).astype(int).astype(str)
    #+ "|" + pd.to_numeric(df1['PRODUCTION Concepts ID'], errors='coerce').fillna(0).astype(int).astype(str))
#df1.head()


df1['FSC_concat'] = df1['Academy'].fillna(0).astype(str) + "|" + df1['PRODUCTION Skill ID'].fillna(0).astype(int).astype(str) + "|" + (df1['PRODUCTION Concepts ID']) .fillna(0).astype(int).astype(str)
df1.head()
# Out:
#              Academy  Prod Function ID                                  Skill  \
# 0  Assurance - Audit                87  Audit Automation Tools and Techniques
# 1  Assurance - Audit                87  Audit Automation Tools and Techniques
# 2  Assurance - Audit                87  Audit Automation Tools and Techniques
# 3  Assurance - Audit                87  Audit Automation Tools and Techniques
# 4  Assurance - Audit                87  Audit Automation Tools and Techniques
#
#    PRODUCTION Skill ID                                  Skill Description  \
# 0                 1230  Master Audit Automation to streamline processe...
# 1                 1230  Master Audit Automation to streamline processe...
# 2                 1230  Master Audit Automation to streamline processe...
# 3                 1230  Master Audit Automation to streamline processe...
# 4                 1230  Master Audit Automation to streamline processe...
#
#                         Concept  \
# 0     Audit Management Software
# 1           Continuous Auditing
# 2    Automated Evidence Capture
# 3  Real-time Control Dashboards
# 4         Exception Auto-Triage
#
#                                  Concept Description  PRODUCTION Concepts ID  \
# 0  Experience with tools such as TeamMate, Metric...                    7014
# 1  Leveraging technology to perform ongoing, real...                    7015
# 2  Using automation scripts to collect audit evid...                   15339
# 3  Providing live visibility into automated contr...                   15340
# 4  Automatically categorizing exceptions based on...                   15341
#
#                                               Concat  \
# 0  Assurance - AuditAudit Automation Tools and Te...
# 1  Assurance - AuditAudit Automation Tools and Te...
# 2  Assurance - AuditAudit Automation Tools and Te...
# 3  Assurance - AuditAudit Automation Tools and Te...
# 4  Assurance - AuditAudit Automation Tools and Te...
#
#                      FSC_concat
# 0   Assurance - Audit|1230|7014
# 1   Assurance - Audit|1230|7015
# 2  Assurance - Audit|1230|15339
# 3  Assurance - Audit|1230|15340
# 4  Assurance - Audit|1230|15341

# %%
automated_df = pd.merge(df1,merged_df, on ='FSC_concat', how = 'left' )
automated_df['Function_count_beginner'] = automated_df['Function_count_beginner'].fillna(0).astype(int)
automated_df['Function_count_intermediate'] = automated_df['Function_count_intermediate'].fillna(0).astype(int)
automated_df['Function_count_Advanced'] = automated_df['Function_count_Advanced'].fillna(0).astype(int)
automated_df.head()
# Out:
#              Academy  Prod Function ID                                  Skill  \
# 0  Assurance - Audit                87  Audit Automation Tools and Techniques
# 1  Assurance - Audit                87  Audit Automation Tools and Techniques
# 2  Assurance - Audit                87  Audit Automation Tools and Techniques
# 3  Assurance - Audit                87  Audit Automation Tools and Techniques
# 4  Assurance - Audit                87  Audit Automation Tools and Techniques
#
#    PRODUCTION Skill ID                                  Skill Description  \
# 0                 1230  Master Audit Automation to streamline processe...
# 1                 1230  Master Audit Automation to streamline processe...
# 2                 1230  Master Audit Automation to streamline processe...
# 3                 1230  Master Audit Automation to streamline processe...
# 4                 1230  Master Audit Automation to streamline processe...
#
#                         Concept  \
# 0     Audit Management Software
# 1           Continuous Auditing
# 2    Automated Evidence Capture
# 3  Real-time Control Dashboards
# 4         Exception Auto-Triage
#
#                                  Concept Description  PRODUCTION Concepts ID  \
# 0  Experience with tools such as TeamMate, Metric...                    7014
# 1  Leveraging technology to perform ongoing, real...                    7015
# 2  Using automation scripts to collect audit evid...                   15339
# 3  Providing live visibility into automated contr...                   15340
# 4  Automatically categorizing exceptions based on...                   15341
#
#                                               Concat  \
# 0  Assurance - AuditAudit Automation Tools and Te...
# 1  Assurance - AuditAudit Automation Tools and Te...
# 2  Assurance - AuditAudit Automation Tools and Te...
# 3  Assurance - AuditAudit Automation Tools and Te...
# 4  Assurance - AuditAudit Automation Tools and Te...
#
#                      FSC_concat  Function_count_beginner  \
# 0   Assurance - Audit|1230|7014                        1
# 1   Assurance - Audit|1230|7015                        1
# 2  Assurance - Audit|1230|15339                        1
# 3  Assurance - Audit|1230|15340                        1
# 4  Assurance - Audit|1230|15341                        1
#
#    Function_count_intermediate  Function_count_Advanced
# 0                            1                        1
# 1                            1                        2
# 2                            1                        1
# 3                            1                        2
# 4                            1                        2

# %%
automated_df.to_excel("C:\\Users\\taslim.siddiqui\\Downloads//automate_FSC_deficit_Kotak_08-01-2026.xlsx")

# %%
import pandas as pd
 
path =r"C:\Users\taslim.siddiqui\Downloads\KOTAK Course + Deficit Tracker_Data added (4).xlsx"
df = pd.read_excel(path, sheet_name='HH+Other CPP Master')
 
# cpp_value = "HH+Other"   # <-- change if needed
# df_f = df[df["CPP"].astype(str).str.strip().eq(cpp_value)]
 
# --- PIVOT: Function x Proficiency, distinct count of concepts ---
pivot = pd.pivot_table(
    df,
    index=['Function'],
    columns=['course_level'],
    values="concepts"
,          # use "Concept" if you want distinct by concept name
    aggfunc=pd.Series.nunique,    # distinct count
    fill_value=0
)
 
pivot_out = pivot.reset_index()
 
print(pivot_out.head())
pivot_out.to_excel(r"C:\Users\taslim.siddiqui\Downloads\pivot_1.xlsx")
# Out:
# course_level                            Function  Advanced  Beginner  \
# 0                              Assurance - Audit       466       447
# 1                                             HR       447       441
# 2                                            Ops       299       302
# 3                Professional Behavior & Mindset        34        35
# 4             RM-Commercial Bank - Agri Business       150       165
#
# course_level  Intermediate
# 0                      471
# 1                      406
# 2                      288
# 3                       35
# 4                      173

# %%
print("df1 dup keys:", df1['FSC_concat'].duplicated().sum())
print("merged_df dup keys:", merged_df['FSC_concat'].duplicated().sum())
print("Any 0-keys in df1:", df1['FSC_concat'].str.startswith("0|").sum(), df1['FSC_concat'].str.contains("|0|", regex=False).sum())
df1.to_excel(r"C:\Users\taslim.siddiqui\Downloads\FSC_concat.xlsx")
# Out:
# df1 dup keys: 0
# merged_df dup keys: 0
# Any 0-keys in df1: 0 0

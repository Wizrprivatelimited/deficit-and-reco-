# %% [markdown]
# **Time Converter

# %%
import pandas as pd

# %%
import pandas as pd
#load excel
df = pd.read_csv("C:\\Users\\taslim.siddiqui\\Downloads\\production_recoRatingDataRecords (2).csv")
#df=pd.read_excel("//Users//romitbenkar//Desktop//Office//07-11-2024//other_output.xlsx")

# Replace 'apple' with 'orange' and 'banana' with 'grape' in column 'B'
df['duration_medium__c'] = df['duration_medium__c'].replace({'Day': 'Days', 'Month': 'Months','Year':'Years'})

# Define conversion factors to seconds for each mode
conversion_factors = {
    'years': 365 * 24 * 60 * 60,        # approximate (ignores leap years)
    'months': 30.44 * 24 * 60 * 60,     # average month
    'weeks': 7 * 24 * 60 * 60,
    'days': 24 * 60 * 60,
    'hours': 60 * 60,
    'minutes': 60
}

df['duration_medium__c']=df['duration_medium__c'].astype(str)


# Function to convert duration based on the mode
def convert_to_seconds(row):
    duration = row['course_duration__c']
    mode = row['duration_medium__c'].strip().lower()  # normalize to lowercase
    return duration * conversion_factors.get(mode, 1)  # Default to 1 if mode is not found

# Apply the conversion function to each row
df['Duration_in_seconds'] = df.apply(convert_to_seconds, axis=1)

# Add a column that checks if the duration in seconds is less than or equal to a week
df['Is_within_a_week'] = df['Duration_in_seconds'] <= 7 * 24 * 60 * 60

# Save the result back to Excel
#df.to_excel('//Users//romitbenkar//Desktop//Office//19-11-24//timeconvertoutput.xlsx', index=False)
df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      01t8n000000GrJPAA0        4641  17890             Amity Future Academy
# 1      01t8n000000GrJQAA0        4642  16262             Amity Future Academy
# 2      01t8n000000GrJRAA0        4643  16885             Amity Future Academy
# 3      01t8n000000GrJSAA0        4644  17637             Amity Future Academy
# 4      01t8n000000GrJTAA0        4645  15978             Amity Future Academy
# ...                   ...         ...    ...                              ...
# 21369          przzd0g0p1       28069  26535                            Udemy
# 21370          przzj4igrr       14130  14308                         Coursera
# 21371          przzltt2yl       34946  35729                              GVC
# 21372          przzvn6z59       14710  11674                         Coursera
# 21373          przzxluxi8       20241  12028                         Coursera
#
#                                             product_name  course_level  \
# 0      PG Program in Digital Marketing Strategies (PG...      Advanced
# 1              PG Program in Product Management (PGP-PM)      Advanced
# 2                    Post Graduate Diploma in Management      Advanced
# 3                    Post Graduate Diploma in Management      Advanced
# 4      Post Graduate Program in Big Data Architecture...      Advanced
# ...                                                  ...           ...
# 21369  Email Marketing: Subscriber List Growth With C...      Beginner
# 21370                      Resourcing a Project Schedule      Beginner
# 21371                      Programming Languages, Part B  Intermediate
# 21372  Exam Prep CKA: Certified Kubernetes Administrator  Intermediate
# 21373                               Generative AI Primer      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 0                 Months               12.00       NaN        170000.0
# 1                 Months               12.00       NaN        215000.0
# 2                 Months                6.00       NaN        120000.0
# 3                 Months                6.00       NaN        120000.0
# 4                 Months                6.00       NaN        100000.0
# ...                  ...                 ...       ...             ...
# 21369            Minutes              215.00   23850.0         23850.0
# 21370              Hours                0.30       1.0             0.0
# 21371              Hours               18.00       NaN             1.0
# 21372              Hours               18.93       1.0             0.0
# 21373              Hours                1.48       1.0             0.0
#
#        inr_amount__c  skill_id            concepts  Duration_in_seconds  \
# 0           170000.0       663                9830           31560192.0
# 1           215000.0        76                6978           31560192.0
# 2           120000.0       643  9585 , 9593 , 9594           15780096.0
# 3           120000.0       343                7066           15780096.0
# 4           100000.0        64         4928 , 4936           15780096.0
# ...              ...       ...                 ...                  ...
# 21369        23850.0       107                6615              12900.0
# 21370            0.0        37                4590               1080.0
# 21371            1.0       164                6893              64800.0
# 21372            0.0       107                 NaN              68148.0
# 21373            0.0       645                9607               5328.0
#
#        Is_within_a_week
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 21369              True
# 21370              True
# 21371              True
# 21372              True
# 21373              True
#
# [21374 rows x 15 columns]

# %% [markdown]
# Integration

# %%
values_to_check = ['Guvi Geeks','Edujournal','Sharpener','Business Toys Skills School']

# Check if any values in the DataFrame are in the list
df['Integration'] = df['course_provider_platform_name__c'].isin(values_to_check)
df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      01t8n000000GrJPAA0        4641  17890             Amity Future Academy
# 1      01t8n000000GrJQAA0        4642  16262             Amity Future Academy
# 2      01t8n000000GrJRAA0        4643  16885             Amity Future Academy
# 3      01t8n000000GrJSAA0        4644  17637             Amity Future Academy
# 4      01t8n000000GrJTAA0        4645  15978             Amity Future Academy
# ...                   ...         ...    ...                              ...
# 21369          przzd0g0p1       28069  26535                            Udemy
# 21370          przzj4igrr       14130  14308                         Coursera
# 21371          przzltt2yl       34946  35729                              GVC
# 21372          przzvn6z59       14710  11674                         Coursera
# 21373          przzxluxi8       20241  12028                         Coursera
#
#                                             product_name  course_level  \
# 0      PG Program in Digital Marketing Strategies (PG...      Advanced
# 1              PG Program in Product Management (PGP-PM)      Advanced
# 2                    Post Graduate Diploma in Management      Advanced
# 3                    Post Graduate Diploma in Management      Advanced
# 4      Post Graduate Program in Big Data Architecture...      Advanced
# ...                                                  ...           ...
# 21369  Email Marketing: Subscriber List Growth With C...      Beginner
# 21370                      Resourcing a Project Schedule      Beginner
# 21371                      Programming Languages, Part B  Intermediate
# 21372  Exam Prep CKA: Certified Kubernetes Administrator  Intermediate
# 21373                               Generative AI Primer      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 0                 Months               12.00       NaN        170000.0
# 1                 Months               12.00       NaN        215000.0
# 2                 Months                6.00       NaN        120000.0
# 3                 Months                6.00       NaN        120000.0
# 4                 Months                6.00       NaN        100000.0
# ...                  ...                 ...       ...             ...
# 21369            Minutes              215.00   23850.0         23850.0
# 21370              Hours                0.30       1.0             0.0
# 21371              Hours               18.00       NaN             1.0
# 21372              Hours               18.93       1.0             0.0
# 21373              Hours                1.48       1.0             0.0
#
#        inr_amount__c  skill_id            concepts  Duration_in_seconds  \
# 0           170000.0       663                9830           31560192.0
# 1           215000.0        76                6978           31560192.0
# 2           120000.0       643  9585 , 9593 , 9594           15780096.0
# 3           120000.0       343                7066           15780096.0
# 4           100000.0        64         4928 , 4936           15780096.0
# ...              ...       ...                 ...                  ...
# 21369        23850.0       107                6615              12900.0
# 21370            0.0        37                4590               1080.0
# 21371            1.0       164                6893              64800.0
# 21372            0.0       107                 NaN              68148.0
# 21373            0.0       645                9607               5328.0
#
#        Is_within_a_week  Integration
# 0                 False        False
# 1                 False        False
# 2                 False        False
# 3                 False        False
# 4                 False        False
# ...                 ...          ...
# 21369              True        False
# 21370              True        False
# 21371              True        False
# 21372              True        False
# 21373              True        False
#
# [21374 rows x 16 columns]

# %% [markdown]
# Concept Count

# %%
def count_commas(val):
    if pd.isna(val):
        return 0
    elif ',' in val:
        return val.count(',') + 1
    else:
        return 1
df['concept_count']=df['concepts'].apply(count_commas)
df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      01t8n000000GrJPAA0        4641  17890             Amity Future Academy
# 1      01t8n000000GrJQAA0        4642  16262             Amity Future Academy
# 2      01t8n000000GrJRAA0        4643  16885             Amity Future Academy
# 3      01t8n000000GrJSAA0        4644  17637             Amity Future Academy
# 4      01t8n000000GrJTAA0        4645  15978             Amity Future Academy
# ...                   ...         ...    ...                              ...
# 21369          przzd0g0p1       28069  26535                            Udemy
# 21370          przzj4igrr       14130  14308                         Coursera
# 21371          przzltt2yl       34946  35729                              GVC
# 21372          przzvn6z59       14710  11674                         Coursera
# 21373          przzxluxi8       20241  12028                         Coursera
#
#                                             product_name  course_level  \
# 0      PG Program in Digital Marketing Strategies (PG...      Advanced
# 1              PG Program in Product Management (PGP-PM)      Advanced
# 2                    Post Graduate Diploma in Management      Advanced
# 3                    Post Graduate Diploma in Management      Advanced
# 4      Post Graduate Program in Big Data Architecture...      Advanced
# ...                                                  ...           ...
# 21369  Email Marketing: Subscriber List Growth With C...      Beginner
# 21370                      Resourcing a Project Schedule      Beginner
# 21371                      Programming Languages, Part B  Intermediate
# 21372  Exam Prep CKA: Certified Kubernetes Administrator  Intermediate
# 21373                               Generative AI Primer      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 0                 Months               12.00       NaN        170000.0
# 1                 Months               12.00       NaN        215000.0
# 2                 Months                6.00       NaN        120000.0
# 3                 Months                6.00       NaN        120000.0
# 4                 Months                6.00       NaN        100000.0
# ...                  ...                 ...       ...             ...
# 21369            Minutes              215.00   23850.0         23850.0
# 21370              Hours                0.30       1.0             0.0
# 21371              Hours               18.00       NaN             1.0
# 21372              Hours               18.93       1.0             0.0
# 21373              Hours                1.48       1.0             0.0
#
#        inr_amount__c  skill_id            concepts  Duration_in_seconds  \
# 0           170000.0       663                9830           31560192.0
# 1           215000.0        76                6978           31560192.0
# 2           120000.0       643  9585 , 9593 , 9594           15780096.0
# 3           120000.0       343                7066           15780096.0
# 4           100000.0        64         4928 , 4936           15780096.0
# ...              ...       ...                 ...                  ...
# 21369        23850.0       107                6615              12900.0
# 21370            0.0        37                4590               1080.0
# 21371            1.0       164                6893              64800.0
# 21372            0.0       107                 NaN              68148.0
# 21373            0.0       645                9607               5328.0
#
#        Is_within_a_week  Integration  concept_count
# 0                 False        False              1
# 1                 False        False              1
# 2                 False        False              3
# 3                 False        False              1
# 4                 False        False              2
# ...                 ...          ...            ...
# 21369              True        False              1
# 21370              True        False              1
# 21371              True        False              1
# 21372              True        False              0
# 21373              True        False              1
#
# [21374 rows x 17 columns]

# %% [markdown]
# No concept column

# %%
deficit_0 =(df['concept_count']== 0 ).sum()
deficit_0
# Out:
# 2431

# %%
df['no_concept'] = df['concepts'].isna()

# %% [markdown]
# ## Only priority CPP

# %%
values_to_check_priority_cpp = ['Henry Harvin Education','Henry Harvin','Eduonix']

# Check if any values in the DataFrame are in the list
df['priority_cpp'] = df['course_provider_platform_name__c'].isin(values_to_check_priority_cpp)
priority_cpp_df = df.query("priority_cpp == True and no_concept == False")
priority_cpp_df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 92     01t8n000000GrYnAAK        5587  15679                          Eduonix
# 159    01t8n000000GrfBAAS        5991  17553                     Henry Harvin
# 163    01t8n000000GrfGAAS        5996  15983                     Henry Harvin
# 164    01t8n000000GrfHAAS        5997  16790                     Henry Harvin
# 165    01t8n000000GrfIAAS        5998  17412                     Henry Harvin
# ...                   ...         ...    ...                              ...
# 21261          przseu9ihh       32571  32384                     Henry Harvin
# 21265          przst9nk8u       32231  32044                     Henry Harvin
# 21269          przsx3so8g       32315  32128                     Henry Harvin
# 21337          przxanp6v0       21027  18953                          Eduonix
# 21346          przxtoqmej       21015  18941                          Eduonix
#
#                                             product_name course_level  \
# 92                 AI-ML For Absolute Beginners E-Degree     Beginner
# 159                                    7 QC Tools Course     Beginner
# 163                                 ACCA Course Training     Advanced
# 164                                ACCA Dip. IFRS Course     Advanced
# 165                       Accounting and Taxation Course     Advanced
# ...                                                  ...          ...
# 21261  Lean Six Sigma Combo (Green Belt + PMP) Course...     Beginner
# 21265  CompTIA Cloud+ CV0-003 Training Course (Instru...     Beginner
# 21269  Content Writing Course with Gold Membership (I...     Beginner
# 21337        ChatGPT & Generative AI Lifetime Membership     Beginner
# 21346              MERN Stack Developer E-Degree Program     Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 92                 Hours                35.0   39500.0          7900.0
# 159                Hours                 8.0    9500.0          5000.0
# 163                Hours               900.0       NaN         93000.0
# 164                Hours                75.0       NaN         29500.0
# 165                Hours               172.0       NaN         34500.0
# ...                  ...                 ...       ...             ...
# 21261              Hours                64.0   32500.0         32500.0
# 21265              Hours                40.0   22500.0         22500.0
# 21269              Hours                40.0   17500.0         17500.0
# 21337              Hours                75.0   22000.0         14950.0
# 21346              Hours                20.0    5300.0          5300.0
#
#        inr_amount__c  skill_id                   concepts  \
# 92            7900.0        65                4673 , 5224
# 159           5000.0       645                       9607
# 163          93000.0       630                9475 , 9476
# 164          29500.0       630                       9476
# 165          34500.0       648  9634 , 9636 , 9638 , 9644
# ...              ...       ...                        ...
# 21261        32500.0       261                       5024
# 21265        22500.0        58                       5723
# 21269        17500.0       129                       4539
# 21337        14950.0       645                       9607
# 21346         5300.0        57                       6446
#
#        Duration_in_seconds  Is_within_a_week  Integration  concept_count  \
# 92                126000.0              True        False              2
# 159                28800.0              True        False              1
# 163              3240000.0             False        False              2
# 164               270000.0              True        False              1
# 165               619200.0             False        False              4
# ...                    ...               ...          ...            ...
# 21261             230400.0              True        False              1
# 21265             144000.0              True        False              1
# 21269             144000.0              True        False              1
# 21337             270000.0              True        False              1
# 21346              72000.0              True        False              1
#
#        no_concept  priority_cpp
# 92          False          True
# 159         False          True
# 163         False          True
# 164         False          True
# 165         False          True
# ...           ...           ...
# 21261       False          True
# 21265       False          True
# 21269       False          True
# 21337       False          True
# 21346       False          True
#
# [1941 rows x 19 columns]

# %%
# Check if any values in the DataFrame are in the list
df['priority_cpp'] = df['course_provider_platform_name__c'].isin(values_to_check_priority_cpp)
priority_cpp_0_df = df.query("priority_cpp == True and no_concept == True")
priority_cpp_0_df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 93     01t8n000000GrYpAAK        5589  16949                          Eduonix
# 141    01t8n000000Grd6AAC        5862  17470                     Henry Harvin
# 158    01t8n000000GrfAAAS        5990  17589                     Henry Harvin
# 160    01t8n000000GrfCAAS        5992  16788                     Henry Harvin
# 161    01t8n000000GrfEAAS        5994  17401                     Henry Harvin
# ...                   ...         ...    ...                              ...
# 18037          prt8u1g23p       32871  32719                     Henry Harvin
# 18239          prtlz4fi6q       32875  32723                     Henry Harvin
# 18777          pruqhr0m95       21038  18964                          Eduonix
# 19001          prv7ba4hn6       33647  34145                     Henry Harvin
# 19233          prvp5xxwba       33597  33496                     Henry Harvin
#
#                                             product_name  course_level  \
# 93               Live Data Science Certification Program      Advanced
# 141                Post Graduate Diploma in Human Rights      Advanced
# 158                     5S Certification Training Course      Beginner
# 160                              8051 and Arduino Course      Beginner
# 161                                   8D Analysis Course      Beginner
# ...                                                  ...           ...
# 18037  Certificate Course in Investment Law (Instruct...      Beginner
# 18239  Business Analysis Course Training (Instructor-...      Beginner
# 18777                         Learn Oracle Process Cloud      Beginner
# 19001  Executive Certification Course in Human Resour...  Intermediate
# 19233                           MBA in Digital Marketing      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 93                Months                6.00   79999.0         79999.0
# 141               Months                9.00       NaN         25500.0
# 158                Hours                8.00       NaN          5000.0
# 160                Hours               40.00       NaN         34500.0
# 161                Hours                8.00    9500.0          9500.0
# ...                  ...                 ...       ...             ...
# 18037              Hours               35.00   22500.0         22500.0
# 18239              Hours               24.00   15000.0         15000.0
# 18777              Hours                5.47    5000.0          5000.0
# 19001              Hours              288.00  118000.0        118000.0
# 19233              Hours              192.00  298000.0        298000.0
#
#        inr_amount__c  skill_id concepts  Duration_in_seconds  \
# 93           79999.0        69      NaN           15780096.0
# 141          25500.0        64      NaN           23670144.0
# 158           5000.0        37      NaN              28800.0
# 160          34500.0       213      NaN             144000.0
# 161           9500.0        37      NaN              28800.0
# ...              ...       ...      ...                  ...
# 18037        22500.0       389      NaN             126000.0
# 18239        15000.0        39      NaN              86400.0
# 18777         5000.0       108      NaN              19692.0
# 19001       118000.0        27      NaN            1036800.0
# 19233       298000.0       107      NaN             691200.0
#
#        Is_within_a_week  Integration  concept_count  no_concept  priority_cpp
# 93                False        False              0        True          True
# 141               False        False              0        True          True
# 158                True        False              0        True          True
# 160                True        False              0        True          True
# 161                True        False              0        True          True
# ...                 ...          ...            ...         ...           ...
# 18037              True        False              0        True          True
# 18239              True        False              0        True          True
# 18777              True        False              0        True          True
# 19001             False        False              0        True          True
# 19233             False        False              0        True          True
#
# [113 rows x 19 columns]

# %% [markdown]
# Only Udemy data

# %%
# Sample DataFrame
df# data is the file which will only have CPP names

# List of values to check
values_to_check_udemy = ['Udemy']

# Check if any values in the DataFrame are in the list
df['Udemy'] = df['course_provider_platform_name__c'].isin(values_to_check_udemy)
udemy_df = df.query("Udemy == True and no_concept == False")
udemy_df
#df.to_excel("//Users//romitbenkar//Desktop//Office//19-11-2024//Udemy_output.xlsx")
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 1419      0AbIh9To       24901  23122                            Udemy
# 1420      0AbXa8Ut       24645  22866                            Udemy
# 1421      0AnKw5Rl       24128  22349                            Udemy
# 1422      0ArCd7Lv       27407  25631                            Udemy
# 1423      0ArKm5Sb       24969  23190                            Udemy
# ...            ...         ...    ...                              ...
# 21349   przy1fgag3       28644  27110                            Udemy
# 21354   przyc3rjqv       31300  29856                            Udemy
# 21355   przyhu62lv       29152  27615                            Udemy
# 21365   przyxra2de       29045  27508                            Udemy
# 21369   przzd0g0p1       28069  26535                            Udemy
#
#                                             product_name  course_level  \
# 1419   (Jetpack, Architecture and More)Advanced Andro...      Beginner
# 1420           Object-oriented Programming in JavaScript  Intermediate
# 1421   Vue - The Complete Guide (incl. Router  and  C...      Beginner
# 1422   Bootstrap 5 From Scratch | Build 5 Modern Webs...      Beginner
# 1423   Complete Deep Learning In R With Keras and Others      Beginner
# ...                                                  ...           ...
# 21349  Microsoft Teams: Teams Essentials for the work...      Beginner
# 21354  Master Certified Fraud Examiner (CFE) Essentia...      Beginner
# 21355           Negotiating Your Salary and Compensation      Beginner
# 21365                     Advanced Cryptography Concepts      Beginner
# 21369  Email Marketing: Subscriber List Growth With C...      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 1419             Minutes              2250.0   23850.0         23850.0
# 1420             Minutes               234.0   23850.0         23850.0
# 1421             Minutes              1912.0   23850.0         23850.0
# 1422             Minutes               798.0   23850.0         23850.0
# 1423             Minutes               475.0   23850.0         23850.0
# ...                  ...                 ...       ...             ...
# 21349            Minutes               135.0   23850.0         23850.0
# 21354            Minutes               121.0       0.0         23850.0
# 21355            Minutes               133.0   23850.0         23850.0
# 21365            Minutes               260.0   23850.0         23850.0
# 21369            Minutes               215.0   23850.0         23850.0
#
#        inr_amount__c  skill_id     concepts  Duration_in_seconds  \
# 1419         23850.0       293         6876             135000.0
# 1420         23850.0       103         6849              14040.0
# 1421         23850.0       103         6849             114720.0
# 1422         23850.0       103  6817 , 6849              47880.0
# 1423         23850.0       293         6778              28500.0
# ...              ...       ...          ...                  ...
# 21349        23850.0        44         4561               8100.0
# 21354        23850.0        24         5635               7260.0
# 21355        23850.0       643         9588               7980.0
# 21365        23850.0       291         4648              15600.0
# 21369        23850.0       107         6615              12900.0
#
#        Is_within_a_week  Integration  concept_count  no_concept  priority_cpp  \
# 1419               True        False              1       False         False
# 1420               True        False              1       False         False
# 1421               True        False              1       False         False
# 1422               True        False              2       False         False
# 1423               True        False              1       False         False
# ...                 ...          ...            ...         ...           ...
# 21349              True        False              1       False         False
# 21354              True        False              1       False         False
# 21355              True        False              1       False         False
# 21365              True        False              1       False         False
# 21369              True        False              1       False         False
#
#        Udemy
# 1419    True
# 1420    True
# 1421    True
# 1422    True
# 1423    True
# ...      ...
# 21349   True
# 21354   True
# 21355   True
# 21365   True
# 21369   True
#
# [5265 rows x 20 columns]

# %%
# Check if any values in the DataFrame are in the list
df['Udemy'] = df['course_provider_platform_name__c'].isin(values_to_check_udemy)
udemy_0_df = df.query("Udemy == True and no_concept == True")
udemy_0_df
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 1741      1FkNf0Wo       22871  21092                            Udemy
# 1993      2FeBo7Oj       25745  23967                            Udemy
# 2877      5TgAx9Cg       22983  21204                            Udemy
# 2930      5YrGr8Hy       22895  21116                            Udemy
# 3226      7BpKm9Gj       23448  21669                            Udemy
# 3607      8ObDt0Ty       23451  21672                            Udemy
# 6006    pr48w18bp0       28040  26506                            Udemy
# 6245    pr4rce05qb       30210  28673                            Udemy
# 7395    pr72kec05o       27984  26450                            Udemy
# 9438    prbg329x5m       28263  26729                            Udemy
# 10022   prckjmlvhq       29660  28123                            Udemy
# 10896   preelbycur       29646  28109                            Udemy
# 11822   prgh28omad       30150  28613                            Udemy
# 12048   prgxo3e70m       29720  28183                            Udemy
# 14302   prllet9osu       30939  29495                            Udemy
# 17035   prr7lx775u       29532  27995                            Udemy
# 17273   prrn4jj0va       28014  26480                            Udemy
# 18314   prtq3w17ir       29930  28393                            Udemy
# 18383   prtvhr73po       28604  27070                            Udemy
# 19005   prv7lg5yyb       29127  27590                            Udemy
# 20199   prxn9li6ss       31017  29573                            Udemy
# 20961   prz4qvhvi9       30188  28651                            Udemy
# 21009   prz8qyxwm0       28009  26475                            Udemy
#
#                                             product_name  course_level  \
# 1741   ACCA MA (F2) A Complete Course on Management A...      Beginner
# 1993   AWS Technical Essentials  - Hands-On Training ...      Beginner
# 2877   Certified Key Performance Indicators Professio...      Beginner
# 2930   Automated Cryptocurrency Portfolio Investing w...      Beginner
# 3226   Master PMP Cost Management: Plan, Budget, Esti...      Beginner
# 3607   Master SWOT Analysis  and  Business Strategy f...      Beginner
# 6006             Leadership: Practical Leadership Skills      Beginner
# 6245   Ethical AI Decision Making, Insights for Leade...      Beginner
# 7395      Lean Six Sigma Green Belt Online Course (2023)      Beginner
# 9438   Leadership: How to Influence, Inspire and Impa...      Beginner
# 10022             Managing a Global Team with Confidence      Beginner
# 10896  Leadership - Rise of a Leader (Lead people wit...      Beginner
# 11822  Web Performance In Practice: Master Core Web V...      Beginner
# 12048  Leadership Skills: Learn Vigilant Leadership &...      Beginner
# 14302  Manage Change Through Collaboration and Team Work      Beginner
# 17035            Leading & Managing People [Effectively]      Beginner
# 17273  Management - Leadership, Negotiating, Assertiv...      Beginner
# 18314  Product Owner II for Agile Intermediate: Certi...      Beginner
# 18383                       Visionary Servant Leadership      Beginner
# 19005  Leadership & Management Skills: 2-in-1 Masterc...      Beginner
# 20199          Collaboration with Emotional Intelligence  Intermediate
# 20961  Professional Diploma in Advertising and Public...      Beginner
# 21009  How to Lead with Ease & Be a Successful CEO, L...      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  \
# 1741             Minutes              2014.0   23850.0         23850.0
# 1993             Minutes               866.0   23850.0         23850.0
# 2877             Minutes               448.0   23850.0         23850.0
# 2930             Minutes              1931.0   23850.0         23850.0
# 3226             Minutes               224.0   23850.0         23850.0
# 3607             Minutes               185.0   23850.0         23850.0
# 6006             Minutes               200.0   23850.0         23850.0
# 6245             Minutes               126.0   23850.0         23850.0
# 7395             Minutes               967.0   23850.0         23850.0
# 9438             Minutes                91.0   23850.0         23850.0
# 10022            Minutes                35.0   23850.0         23850.0
# 10896            Minutes                91.0   23850.0         23850.0
# 11822            Minutes               204.0   23850.0         23850.0
# 12048            Minutes                89.0   23850.0         23850.0
# 14302            Minutes               102.0       0.0         23850.0
# 17035            Minutes               119.0   23850.0         23850.0
# 17273            Minutes               128.0   23850.0         23850.0
# 18314            Minutes               379.0   23850.0         23850.0
# 18383            Minutes                84.0   23850.0         23850.0
# 19005            Minutes              2655.0   23850.0         23850.0
# 20199            Minutes               184.0       0.0         23850.0
# 20961            Minutes               251.0   23850.0         23850.0
# 21009            Minutes               186.0   23850.0         23850.0
#
#        inr_amount__c  skill_id concepts  Duration_in_seconds  \
# 1741         23850.0       261      NaN             120840.0
# 1993         23850.0        44      NaN              51960.0
# 2877         23850.0        49      NaN              26880.0
# 2930         23850.0        49      NaN             115860.0
# 3226         23850.0        49      NaN              13440.0
# 3607         23850.0        49      NaN              11100.0
# 6006         23850.0       255      NaN              12000.0
# 6245         23850.0       261      NaN               7560.0
# 7395         23850.0        39      NaN              58020.0
# 9438         23850.0       255      NaN               5460.0
# 10022        23850.0       255      NaN               2100.0
# 10896        23850.0       255      NaN               5460.0
# 11822        23850.0       106      NaN              12240.0
# 12048        23850.0       255      NaN               5340.0
# 14302        23850.0       262      NaN               6120.0
# 17035        23850.0       255      NaN               7140.0
# 17273        23850.0       255      NaN               7680.0
# 18314        23850.0        36      NaN              22740.0
# 18383        23850.0       255      NaN               5040.0
# 19005        23850.0       255      NaN             159300.0
# 20199        23850.0       262      NaN              11040.0
# 20961        23850.0       262      NaN              15060.0
# 21009        23850.0       255      NaN              11160.0
#
#        Is_within_a_week  Integration  concept_count  no_concept  priority_cpp  \
# 1741               True        False              0        True         False
# 1993               True        False              0        True         False
# 2877               True        False              0        True         False
# 2930               True        False              0        True         False
# 3226               True        False              0        True         False
# 3607               True        False              0        True         False
# 6006               True        False              0        True         False
# 6245               True        False              0        True         False
# 7395               True        False              0        True         False
# 9438               True        False              0        True         False
# 10022              True        False              0        True         False
# 10896              True        False              0        True         False
# 11822              True        False              0        True         False
# 12048              True        False              0        True         False
# 14302              True        False              0        True         False
# 17035              True        False              0        True         False
# 17273              True        False              0        True         False
# 18314              True        False              0        True         False
# 18383              True        False              0        True         False
# 19005              True        False              0        True         False
# 20199              True        False              0        True         False
# 20961              True        False              0        True         False
# 21009              True        False              0        True         False
#
#        Udemy
# 1741    True
# 1993    True
# 2877    True
# 2930    True
# 3226    True
# 3607    True
# 6006    True
# 6245    True
# 7395    True
# 9438    True
# 10022   True
# 10896   True
# 11822   True
# 12048   True
# 14302   True
# 17035   True
# 17273   True
# 18314   True
# 18383   True
# 19005   True
# 20199   True
# 20961   True
# 21009   True

# %% [markdown]
# Only ABC data   Priority_ coursera

# %%
values_to_check_abc_coursera = ['Coursera']

# Check if values in 'course_provider_platform_name__c' column are in the list, and create a boolean column 'ABC'
df['ABC_coursera'] = df['course_provider_platform_name__c'].isin(values_to_check_abc_coursera)

abc_coursera_df = df.query("ABC_coursera == True and no_concept == False")
abc_coursera_df
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 3988    pr0072y7ai       17054  13847                         Coursera
# 3989    pr00ll9a88       14368  15208                         Coursera
# 3990    pr00nc2nuj       19718  12119                         Coursera
# 4002    pr01mrgb8a       16779  13115                         Coursera
# 4005    pr01x7z7az       16372  15180                         Coursera
# ...            ...         ...    ...                              ...
# 21362   przyv633ju       15093  14071                         Coursera
# 21366   przz7qgy8j       20005  14847                         Coursera
# 21367   przz9s4oct       16916  10069                         Coursera
# 21370   przzj4igrr       14130  14308                         Coursera
# 21373   przzxluxi8       20241  12028                         Coursera
#
#                                             product_name  course_level  \
# 3988   Personal Productivity, Time Management and Pri...      Beginner
# 3989   Use SurveyMonkey to Create a Survey and Analyz...      Beginner
# 3990                 Getting Started with Facebook Pixel      Beginner
# 4002                       LangChain Chat with Your Data      Beginner
# 4005   Use C++ to build a Crypto Trading Platform: Fi...  Intermediate
# ...                                                  ...           ...
# 21362                            Programming Languages Ⅱ  Intermediate
# 21366                Technical Managerial Written Skills      Beginner
# 21367          Building Your Freelancing Career Capstone  Intermediate
# 21370                      Resourcing a Project Schedule      Beginner
# 21373                               Generative AI Primer      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 3988               Hours                6.32       1.0             0.0  ...
# 3989               Hours                0.40       1.0             0.0  ...
# 3990               Hours                 NaN       1.0             0.0  ...
# 4002               Hours                1.50       1.0             0.0  ...
# 4005               Hours                7.30       1.0             0.0  ...
# ...                  ...                 ...       ...             ...  ...
# 21362              Hours               10.55       1.0             0.0  ...
# 21366              Hours               18.87       1.0             0.0  ...
# 21367              Hours               11.93       1.0             0.0  ...
# 21370              Hours                0.30       1.0             0.0  ...
# 21373              Hours                1.48       1.0             0.0  ...
#
#        skill_id     concepts Duration_in_seconds  Is_within_a_week  \
# 3988         39         5939             22752.0              True
# 3989        123         5497              1440.0              True
# 3990        121         4726                 NaN             False
# 4002        213  5888 , 6107              5400.0              True
# 4005        291         4648             26280.0              True
# ...         ...          ...                 ...               ...
# 21362       213         6107             37980.0              True
# 21366       645         9609             67932.0              True
# 21367        37         5396             42948.0              True
# 21370        37         4590              1080.0              True
# 21373       645         9607              5328.0              True
#
#        Integration  concept_count  no_concept  priority_cpp  Udemy  \
# 3988         False              1       False         False  False
# 3989         False              1       False         False  False
# 3990         False              1       False         False  False
# 4002         False              2       False         False  False
# 4005         False              1       False         False  False
# ...            ...            ...         ...           ...    ...
# 21362        False              1       False         False  False
# 21366        False              1       False         False  False
# 21367        False              1       False         False  False
# 21370        False              1       False         False  False
# 21373        False              1       False         False  False
#
#        ABC_coursera
# 3988           True
# 3989           True
# 3990           True
# 4002           True
# 4005           True
# ...             ...
# 21362          True
# 21366          True
# 21367          True
# 21370          True
# 21373          True
#
# [5444 rows x 21 columns]

# %%
# Check if values in 'course_provider_platform_name__c' column are in the list, and create a boolean column 'ABC'
df['ABC_coursera'] = df['course_provider_platform_name__c'].isin(values_to_check_abc_coursera)

abc_coursera_0_df = df.query("ABC_coursera == True and no_concept == True")
abc_coursera_0_df
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 4048    pr05es3nvi       18844  12909                         Coursera
# 4063    pr06e8hqrz       14035  14086                         Coursera
# 4098    pr08pu8d3g       19039  14138                         Coursera
# 4102    pr08wgxixo       17716  19575                         Coursera
# 4106    pr091o1o6t       19628  11836                         Coursera
# ...            ...         ...    ...                              ...
# 21306   przvd8bx2g       19471  10883                         Coursera
# 21333   przx3a7dpa       16113   9655                         Coursera
# 21347   przxwst6s4       16924  13794                         Coursera
# 21364   przyx8v5ue       14285  10322                         Coursera
# 21372   przzvn6z59       14710  11674                         Coursera
#
#                                             product_name  course_level  \
# 4048                     Introduction to NoSQL Databases      Beginner
# 4063   Project Management: Control using the Earned V...      Beginner
# 4098                  PyCaret: Anatomy of Classification  Intermediate
# 4102                       The Principles of Real Estate      Beginner
# 4106                    FinTech Foundations and Overview      Beginner
# ...                                                  ...           ...
# 21306                 Creating Custom Callbacks in Keras  Intermediate
# 21333  Autoscaling TensorFlow Model Deployments with ...  Intermediate
# 21347  Our Share: Employee Ownership as a Wealth Shar...      Beginner
# 21364  Cluster Analysis, Association Mining, and Mode...  Intermediate
# 21372  Exam Prep CKA: Certified Kubernetes Administrator  Intermediate
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 4048               Hours                 NaN       1.0             0.0  ...
# 4063               Hours                1.87       1.0             0.0  ...
# 4098               Hours                0.20       1.0             0.0  ...
# 4102               Hours               24.13       1.0             0.0  ...
# 4106               Hours                7.20       1.0             0.0  ...
# ...                  ...                 ...       ...             ...  ...
# 21306              Hours                0.10       1.0             0.0  ...
# 21333              Hours                1.50       1.0             0.0  ...
# 21347              Hours               15.08       1.0             0.0  ...
# 21364              Hours                3.95       1.0             0.0  ...
# 21372              Hours               18.93       1.0             0.0  ...
#
#        skill_id  concepts Duration_in_seconds  Is_within_a_week  Integration  \
# 4048         57       NaN                 NaN             False        False
# 4063        213       NaN              6732.0              True        False
# 4098         65       NaN               720.0              True        False
# 4102        213       NaN             86868.0              True        False
# 4106        262       NaN             25920.0              True        False
# ...         ...       ...                 ...               ...          ...
# 21306        69       NaN               360.0              True        False
# 21333        69       NaN              5400.0              True        False
# 21347       267       NaN             54288.0              True        False
# 21364        68       NaN             14220.0              True        False
# 21372       107       NaN             68148.0              True        False
#
#        concept_count  no_concept  priority_cpp  Udemy  ABC_coursera
# 4048               0        True         False  False          True
# 4063               0        True         False  False          True
# 4098               0        True         False  False          True
# 4102               0        True         False  False          True
# 4106               0        True         False  False          True
# ...              ...         ...           ...    ...           ...
# 21306              0        True         False  False          True
# 21333              0        True         False  False          True
# 21347              0        True         False  False          True
# 21364              0        True         False  False          True
# 21372              0        True         False  False          True
#
# [1063 rows x 21 columns]

# %%
# List of values to check
values_to_check_abc = ['GVC','Gyanodaya Virtual Campus','CIEL']

# Check if values in 'course_provider_platform_name__c' column are in the list, and create a boolean column 'ABC'
df['ABC'] = df['course_provider_platform_name__c'].isin(values_to_check_abc)

# Save the updated DataFrame to a new Excel file
#df.to_excel("//Users//romitbenkar//Desktop//Office//07-11-2024//ABCoutput.xlsx", index=False)
abc_df = df.query("ABC == True and no_concept == False")
abc_df
#df.to_excel("//Users//romitbenkar//Desktop//Office//19-11-2024//Udemy_output.xlsx")
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 3987    pr000be54a       22145  20095                              GVC
# 3995    pr015bytb9       12844   8295                              GVC
# 3998    pr01iiouag       34882  35609                              GVC
# 3999    pr01kkxugj       12964   8414                              GVC
# 4000    pr01kw4oyr       22165  20115                              GVC
# ...            ...         ...    ...                              ...
# 21329   przwty7x3c       13212   8662                              GVC
# 21353   przy8u5muw       12681   8132                              GVC
# 21360   przyr0egej       13596   9046                              GVC
# 21361   przyu0in9m       22779  20873                              GVC
# 21371   przzltt2yl       34946  35729                              GVC
#
#                                             product_name  course_level  \
# 3987   Advanced Visualizations & Dashboards: Visualiz...  Intermediate
# 3995   CompTIA A+ Core 1: Wireless Networking & Services  Intermediate
# 3998                 Cryptography and Information Theory  Intermediate
# 3999   Integrate Power Apps portals with web-based te...      Beginner
# 4000   CompTIA A+ Core 1: Mobile Device Accessories &...      Beginner
# ...                                                  ...           ...
# 21329  Webex Meetings Web: Organizing & Hosting Meetings      Beginner
# 21353  PMBOK® Guide Sixth Edition: Project Management...  Intermediate
# 21360  Applying Research Methods for Trend & Impact A...      Advanced
# 21361            Microsoft Azure Services and Lifecycles      Beginner
# 21371                      Programming Languages, Part B  Intermediate
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 3987               Hours                0.34       1.0             0.0  ...
# 3995               Hours                2.25       1.0             0.0  ...
# 3998               Hours                4.60       NaN             1.0  ...
# 3999               Hours                0.19       1.0             0.0  ...
# 4000               Hours                1.22       1.0             0.0  ...
# ...                  ...                 ...       ...             ...  ...
# 21329              Hours                1.07       1.0             0.0  ...
# 21353              Hours                0.45       1.0             0.0  ...
# 21360              Hours                0.35       1.0             0.0  ...
# 21361              Hours                 NaN       1.0             0.0  ...
# 21371              Hours               18.00       NaN             1.0  ...
#
#        concepts  Duration_in_seconds Is_within_a_week  Integration  \
# 3987       4641               1224.0             True        False
# 3995       6575               8100.0             True        False
# 3998       4648              16560.0             True        False
# 3999       5207                684.0             True        False
# 4000       6229               4392.0             True        False
# ...         ...                  ...              ...          ...
# 21329      6226               3852.0             True        False
# 21353      4590               1620.0             True        False
# 21360      5263               1260.0             True        False
# 21361      5947                  NaN            False        False
# 21371      6893              64800.0             True        False
#
#        concept_count  no_concept  priority_cpp  Udemy  ABC_coursera   ABC
# 3987               1       False         False  False         False  True
# 3995               1       False         False  False         False  True
# 3998               1       False         False  False         False  True
# 3999               1       False         False  False         False  True
# 4000               1       False         False  False         False  True
# ...              ...         ...           ...    ...           ...   ...
# 21329              1       False         False  False         False  True
# 21353              1       False         False  False         False  True
# 21360              1       False         False  False         False  True
# 21361              1       False         False  False         False  True
# 21371              1       False         False  False         False  True
#
# [2498 rows x 22 columns]

# %%
# Save the updated DataFrame to a new Excel file
#df.to_excel("//Users//romitbenkar//Desktop//Office//07-11-2024//ABCoutput.xlsx", index=False)
abc_0_df = df.query("ABC == True and no_concept == True")
abc_0_df
#df.to_excel("//Users//romitbenkar//Desktop//Office//19-11-2024//Udemy_output.xlsx")
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 4433    pr0wj9k13n       13718   9167                              GVC
# 4564    pr17mclr8v       13296   8746                              GVC
# 4602    pr1avov4dr       22840  20934                              GVC
# 4842    pr1tp2vzx8       12759   8210                              GVC
# 5268    pr2o2gu7to       22776  20870                              GVC
# ...            ...         ...    ...                              ...
# 20326   prxw8lype3       20908  18816                              GVC
# 20344   prxxilay2h       21520  19565                              GVC
# 20923   prz1t3b38w       12954   8404                              GVC
# 20928   prz2d9wato       13588   9038                              GVC
# 21224   przp8o0vrj       20929  18837                              GVC
#
#                                             product_name  course_level  \
# 4433                     Implement DirectAccess [Guided]      Beginner
# 4564   CompTIA Server+: Ports, Protocols, & Cable Man...  Intermediate
# 4602             Advanced Styling with Responsive Design      Beginner
# 4842   Windows 8.1: Installing & Using Windows Univer...  Intermediate
# 5268   Data Engineering with MS Azure Synapse Apache ...      Beginner
# ...                                                  ...           ...
# 20326  Optimize Your Operations for Today - and Tomorrow      Beginner
# 20344   Project Scheduling:  Estimate Activity Durations      Beginner
# 20923  AWS SysOps Associate 2021: EC2 Instance Manage...  Intermediate
# 20928                      Slack 2020: Configuring Slack  Intermediate
# 21224       Scrum Foundation: Scrum Development Concepts      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 4433               Hours               0.750       1.0             0.0  ...
# 4564               Hours               0.530       1.0             0.0  ...
# 4602               Hours                 NaN       1.0             0.0  ...
# 4842               Hours               1.280       1.0             0.0  ...
# 5268               Hours                 NaN       1.0             0.0  ...
# ...                  ...                 ...       ...             ...  ...
# 20326              Hours               0.580       1.0             0.0  ...
# 20344              Hours                 NaN       1.0             0.0  ...
# 20923              Hours               1.535       1.0             0.0  ...
# 20928              Hours                 NaN       1.0             0.0  ...
# 21224              Hours               1.100       1.0             0.0  ...
#
#        concepts  Duration_in_seconds Is_within_a_week  Integration  \
# 4433        NaN               2700.0             True        False
# 4564        NaN               1908.0             True        False
# 4602        NaN                  NaN            False        False
# 4842        NaN               4608.0             True        False
# 5268        NaN                  NaN            False        False
# ...         ...                  ...              ...          ...
# 20326       NaN               2088.0             True        False
# 20344       NaN                  NaN            False        False
# 20923       NaN               5526.0             True        False
# 20928       NaN                  NaN            False        False
# 21224       NaN               3960.0             True        False
#
#        concept_count  no_concept  priority_cpp  Udemy  ABC_coursera   ABC
# 4433               0        True         False  False         False  True
# 4564               0        True         False  False         False  True
# 4602               0        True         False  False         False  True
# 4842               0        True         False  False         False  True
# 5268               0        True         False  False         False  True
# ...              ...         ...           ...    ...           ...   ...
# 20326              0        True         False  False         False  True
# 20344              0        True         False  False         False  True
# 20923              0        True         False  False         False  True
# 20928              0        True         False  False         False  True
# 21224              0        True         False  False         False  True
#
# [81 rows x 22 columns]

# %% [markdown]
# non_corporate_df(No ABC and Udemy) Wizr course

# %%
non_corporate_df = df.query("ABC == False and ABC_coursera == False and Udemy == False and priority_cpp == False  and no_concept == False").sort_values(by='Duration_in_seconds')
non_corporate_df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 1311   01t8n000000JE6yAAG       10009  15708                      Skill Smith
# 1316   01t8n000000JE73AAG       10014  15544                      Skill Smith
# 1308   01t8n000000JE6uAAG       10005  15553                      Skill Smith
# 1309   01t8n000000JE6vAAG       10006  15552                      Skill Smith
# 12594          pri5rci4yv       35552  36373              PharmaState Academy
# ...                   ...         ...    ...                              ...
# 1010   01t8n000000GwvPAAS        9054  16448   Lovely Professional University
# 472    01t8n000000GrsuAAC        6842  15579                    Masters Union
# 11560          prfwoo5mcq       27775  25999                        IMI Delhi
# 539    01t8n000000GrxEAAS        7140  17371                           upGrad
# 85     01t8n000000GrYbAAK        5575  16657                        Edudelphi
#
#                                             product_name  course_level  \
# 1311                      Angular Master Program Offline      Advanced
# 1316                  Master React Native Program Online      Advanced
# 1308   Full Stack Program (React JS and Node JS) Offline      Advanced
# 1309    Full Stack Program (React JS and Node JS) Online      Advanced
# 12594  Personal Protective Equipment (PPEs) - Safety ...      Beginner
# ...                                                  ...           ...
# 1010                                  BBA, LL.B. (Hons.)  Intermediate
# 472                              Undergraduate Programme      Beginner
# 11560       Post Graduate Diploma in Management (Online)      Advanced
# 539                  MBA Leading Business Transformation      Advanced
# 85              Certified Fraud Examiner Course in India      Advanced
#
#       duration_medium__c  course_duration__c   price__c  loan_amount__c  ...  \
# 1311             Minutes                 3.0        5.0       118000.00  ...
# 1316             Minutes                 3.0        9.0          777.29  ...
# 1308             Minutes                 6.0       15.0         1295.48  ...
# 1309             Minutes                 6.0       15.0         1295.48  ...
# 12594            Minutes                 7.0        NaN          399.00  ...
# ...                  ...                 ...        ...             ...  ...
# 1010               Years                 5.0  1200000.0      1200000.00  ...
# 472                Years                 6.0        NaN      2925000.00  ...
# 11560              Years                24.0   295000.0       295000.00  ...
# 539               Months               585.0   365000.0      1344753.00  ...
# 85                   nan                 NaN        NaN          450.00  ...
#
#                                concepts  Duration_in_seconds Is_within_a_week  \
# 1311                               5747         1.800000e+02             True
# 1316                               5747         1.800000e+02             True
# 1308                               5747         3.600000e+02             True
# 1309                               6107         3.600000e+02             True
# 12594  7965 , 7966 , 7967 , 7970 , 7971         4.200000e+02             True
# ...                                 ...                  ...              ...
# 1010                               5061         1.576800e+08            False
# 472                                9802         1.892160e+08            False
# 11560                              9656         7.568640e+08            False
# 539                                5877         1.538559e+09            False
# 85                                 5503                  NaN            False
#
#        Integration  concept_count  no_concept  priority_cpp  Udemy  \
# 1311         False              1       False         False  False
# 1316         False              1       False         False  False
# 1308         False              1       False         False  False
# 1309         False              1       False         False  False
# 12594        False              5       False         False  False
# ...            ...            ...         ...           ...    ...
# 1010         False              1       False         False  False
# 472          False              1       False         False  False
# 11560        False              1       False         False  False
# 539          False              1       False         False  False
# 85           False              1       False         False  False
#
#        ABC_coursera    ABC
# 1311          False  False
# 1316          False  False
# 1308          False  False
# 1309          False  False
# 12594         False  False
# ...             ...    ...
# 1010          False  False
# 472           False  False
# 11560         False  False
# 539           False  False
# 85            False  False
#
# [3795 rows x 22 columns]

# %%
non_corporate_0_df = df.query("ABC == False and Udemy == False and ABC_coursera == False and priority_cpp == False and no_concept == True").sort_values(by='Duration_in_seconds')
non_corporate_0_df
# Out:
#              product_sfid  product_id   mpid course_provider_platform_name__c  \
# 12210          prha028n6z       10900  17663                       Skillfloor
# 14154          prlag2pjhr       27842  26220                          Edureka
# 1084   01t8n000000Gx1RAAS        9428  15717                            Unext
# 1310   01t8n000000JE6wAAG       10007  15551                      Skill Smith
# 1315   01t8n000000JE72AAG       10013  16508                      Skill Smith
# ...                   ...         ...    ...                              ...
# 1347   01t8n000000KtT5AAK       10214  15523                         Yenepoya
# 5861           pr3yro2h81       11180  15999                   Physics Wallah
# 1413   01tTZ000000gwFWYAY       10541   5922      The Design Village Easebuzz
# 1409   01tTZ000000gwEvYAI       10504   5894      The Design Village Easebuzz
# 150    01t8n000000GreMAAS        5940  14641              Fireblaze AI School
#
#                                             product_name  course_level  \
# 12210              Certified Data Scientist Professional      Beginner
# 14154  Linux Administration Certification Training Co...      Beginner
# 1084            Integrated Program In Business Analytics      Advanced
# 1310                        Java Booster Program Offline      Advanced
# 1315                 Master React Native Program Offline      Advanced
# ...                                                  ...           ...
# 1347   Bachelor of Computer Application | Cloud Compu...  Intermediate
# 5861   UG Course in Computer Science & Artificial Int...      Advanced
# 1413                                      Product Design      Beginner
# 1409                             Interaction & Ux Design      Beginner
# 150                                 SQL for Data Science      Advanced
#
#       duration_medium__c  course_duration__c   price__c  loan_amount__c  ...  \
# 12210             Month                  3.0    40000.0        60000.00  ...
# 14154               Week                 7.5    23594.0        17995.00  ...
# 1084              Month                 10.0   305836.0       305836.00  ...
# 1310             Minutes                 3.0       15.0       118000.00  ...
# 1315             Minutes                 3.0        9.0          777.29  ...
# ...                  ...                 ...        ...             ...  ...
# 1347               Years                 4.0   120000.0       120000.00  ...
# 5861               Years                 4.0  1519000.0      1519000.00  ...
# 1413               Years                 4.0  2200000.0      2200000.00  ...
# 1409               Years                 4.0  2200000.0      2200000.00  ...
# 150                  nan                 NaN        NaN         2499.00  ...
#
#        concepts  Duration_in_seconds Is_within_a_week  Integration  \
# 12210       NaN                  3.0             True        False
# 14154       NaN                  7.5             True        False
# 1084        NaN                 10.0             True        False
# 1310        NaN                180.0             True        False
# 1315        NaN                180.0             True        False
# ...         ...                  ...              ...          ...
# 1347        NaN          126144000.0            False        False
# 5861        NaN          126144000.0            False        False
# 1413        NaN          126144000.0            False        False
# 1409        NaN          126144000.0            False        False
# 150         NaN                  NaN            False        False
#
#        concept_count  no_concept  priority_cpp  Udemy  ABC_coursera    ABC
# 12210              0        True         False  False         False  False
# 14154              0        True         False  False         False  False
# 1084               0        True         False  False         False  False
# 1310               0        True         False  False         False  False
# 1315               0        True         False  False         False  False
# ...              ...         ...           ...    ...           ...    ...
# 1347               0        True         False  False         False  False
# 5861               0        True         False  False         False  False
# 1413               0        True         False  False         False  False
# 1409               0        True         False  False         False  False
# 150                0        True         False  False         False  False
#
# [1151 rows x 22 columns]

# %%
non_corporate_priority_cpp_df = df.query("ABC == False and ABC_coursera == False and Udemy == False and Integration==False and priority_cpp == True").sort_values(by='Duration_in_seconds')
non_corporate_priority_cpp_df
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# 4515    pr140tds7q       21046  18972                          Eduonix
# 17376   prrv19u96h       21052  18978                          Eduonix
# 19594   prwelgdjic       21043  18969                          Eduonix
# 5083    pr2aa9dt8x       21053  18979                          Eduonix
# 4313    pr0or3bd6t       21049  18975                          Eduonix
# ...            ...         ...    ...                              ...
# 6674    pr5nenya2u       32958  32806                     Henry Harvin
# 6378    pr4zjtodwa       33700  33605           Henry Harvin Education
# 19673   prwka30dss       32957  32805                     Henry Harvin
# 8389    pr96zqow82       32296  32109                     Henry Harvin
# 16865   prqu6t1ijt       35459  36150                     Henry Harvin
#
#                                             product_name  course_level  \
# 4515                    Business Analytics for Beginners      Beginner
# 17376  Web Accessibility for an Inclusive online pres...      Beginner
# 19594  Start Simple Coding with HTML , CSS and JavaSc...      Beginner
# 5083                                     UIUX with Figma      Beginner
# 4313   Microsoft Bot Framework v4 - Real Life Example...      Beginner
# ...                                                  ...           ...
# 6674   Advanced Human Resource Management Course (Sel...      Advanced
# 6378   Industry Expert Program in Finance and Account...  Intermediate
# 19673  Advanced Human Resource Management Course (Liv...      Advanced
# 8389   Advanced Human Resource Management Course (Ins...      Beginner
# 16865                  Masters (MS) in Digital Marketing      Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 4515             Minutes               15.00   22488.0         22488.0  ...
# 17376              Hours                1.00    1500.0          5500.0  ...
# 19594              Hours                1.05   10000.0         10000.0  ...
# 5083               Hours                1.13    1500.0          5599.0  ...
# 4313             Minutes               68.00   12500.0         12500.0  ...
# ...                  ...                 ...       ...             ...  ...
# 6674               Years                4.00  349500.0        349500.0  ...
# 6378               Years                4.00  498000.0        498000.0  ...
# 19673              Years                4.00  349500.0        349500.0  ...
# 8389               Years                4.00  349500.0        349500.0  ...
# 16865             Months              288.00       NaN         22500.0  ...
#
#                         concepts  Duration_in_seconds Is_within_a_week  \
# 4515                        4980                900.0             True
# 17376                        NaN               3600.0             True
# 19594                5102 , 5747               3780.0             True
# 5083                         NaN               4068.0             True
# 4313                        5947               4080.0             True
# ...                          ...                  ...              ...
# 6674                        5586          126144000.0            False
# 6378                        7056          126144000.0            False
# 19673                5586 , 5770          126144000.0            False
# 8389   4799 , 6262 , 6318 , 6461          126144000.0            False
# 16865                       5102          757444608.0            False
#
#        Integration  concept_count  no_concept  priority_cpp  Udemy  \
# 4515         False              1       False          True  False
# 17376        False              0        True          True  False
# 19594        False              2       False          True  False
# 5083         False              0        True          True  False
# 4313         False              1       False          True  False
# ...            ...            ...         ...           ...    ...
# 6674         False              1       False          True  False
# 6378         False              1       False          True  False
# 19673        False              2       False          True  False
# 8389         False              4       False          True  False
# 16865        False              1       False          True  False
#
#        ABC_coursera    ABC
# 4515          False  False
# 17376         False  False
# 19594         False  False
# 5083          False  False
# 4313          False  False
# ...             ...    ...
# 6674          False  False
# 6378          False  False
# 19673         False  False
# 8389          False  False
# 16865         False  False
#
# [2054 rows x 22 columns]

# %% [markdown]
# Ranking non_corporate

# %%
non_corporate_df = non_corporate_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
non_corporate_df['Rank'] = 600 - (non_corporate_df.index * 0.01)
non_corporate_df
# Out:
#             product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0     01t8n000000JE73AAG       10014  15544                      Skill Smith
# 1     01t8n000000JE6yAAG       10009  15708                      Skill Smith
# 2     01t8n000000JE6uAAG       10005  15553                      Skill Smith
# 3     01t8n000000JE6vAAG       10006  15552                      Skill Smith
# 4             pri5rci4yv       35552  36373              PharmaState Academy
# ...                  ...         ...    ...                              ...
# 3790  01t8n000000GwvPAAS        9054  16448   Lovely Professional University
# 3791  01t8n000000GrsuAAC        6842  15579                    Masters Union
# 3792          prfwoo5mcq       27775  25999                        IMI Delhi
# 3793  01t8n000000GrxEAAS        7140  17371                           upGrad
# 3794  01t8n000000GrYbAAK        5575  16657                        Edudelphi
#
#                                            product_name  course_level  \
# 0                    Master React Native Program Online      Advanced
# 1                        Angular Master Program Offline      Advanced
# 2     Full Stack Program (React JS and Node JS) Offline      Advanced
# 3      Full Stack Program (React JS and Node JS) Online      Advanced
# 4     Personal Protective Equipment (PPEs) - Safety ...      Beginner
# ...                                                 ...           ...
# 3790                                 BBA, LL.B. (Hons.)  Intermediate
# 3791                            Undergraduate Programme      Beginner
# 3792       Post Graduate Diploma in Management (Online)      Advanced
# 3793                MBA Leading Business Transformation      Advanced
# 3794           Certified Fraud Examiner Course in India      Advanced
#
#      duration_medium__c  course_duration__c   price__c  loan_amount__c  ...  \
# 0               Minutes                 3.0        9.0          777.29  ...
# 1               Minutes                 3.0        5.0       118000.00  ...
# 2               Minutes                 6.0       15.0         1295.48  ...
# 3               Minutes                 6.0       15.0         1295.48  ...
# 4               Minutes                 7.0        NaN          399.00  ...
# ...                 ...                 ...        ...             ...  ...
# 3790              Years                 5.0  1200000.0      1200000.00  ...
# 3791              Years                 6.0        NaN      2925000.00  ...
# 3792              Years                24.0   295000.0       295000.00  ...
# 3793             Months               585.0   365000.0      1344753.00  ...
# 3794                nan                 NaN        NaN          450.00  ...
#
#       Duration_in_seconds  Is_within_a_week Integration  concept_count  \
# 0            1.800000e+02              True       False              1
# 1            1.800000e+02              True       False              1
# 2            3.600000e+02              True       False              1
# 3            3.600000e+02              True       False              1
# 4            4.200000e+02              True       False              5
# ...                   ...               ...         ...            ...
# 3790         1.576800e+08             False       False              1
# 3791         1.892160e+08             False       False              1
# 3792         7.568640e+08             False       False              1
# 3793         1.538559e+09             False       False              1
# 3794                  NaN             False       False              1
#
#       no_concept  priority_cpp  Udemy  ABC_coursera    ABC    Rank
# 0          False         False  False         False  False  600.00
# 1          False         False  False         False  False  599.99
# 2          False         False  False         False  False  599.98
# 3          False         False  False         False  False  599.97
# 4          False         False  False         False  False  599.96
# ...          ...           ...    ...           ...    ...     ...
# 3790       False         False  False         False  False  562.10
# 3791       False         False  False         False  False  562.09
# 3792       False         False  False         False  False  562.08
# 3793       False         False  False         False  False  562.07
# 3794       False         False  False         False  False  562.06
#
# [3795 rows x 23 columns]

# %%
non_corporate_0_df = non_corporate_0_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
non_corporate_0_df['Rank'] = 550 - (non_corporate_0_df.index * 0.01)
non_corporate_0_df
# Out:
#             product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0             prha028n6z       10900  17663                       Skillfloor
# 1             prlag2pjhr       27842  26220                          Edureka
# 2     01t8n000000Gx1RAAS        9428  15717                            Unext
# 3     01t8n000000JE72AAG       10013  16508                      Skill Smith
# 4     01t8n000000JE6wAAG       10007  15551                      Skill Smith
# ...                  ...         ...    ...                              ...
# 1146  01tTZ000000gx2DYAQ       10560   5937      The Design Village Easebuzz
# 1147  01tTZ000000gwFWYAY       10541   5922      The Design Village Easebuzz
# 1148  01tTZ000000gwEvYAI       10504   5894      The Design Village Easebuzz
# 1149  01t8n000000GrstAAC        6841  16928                    Masters Union
# 1150  01t8n000000GreMAAS        5940  14641              Fireblaze AI School
#
#                                            product_name  course_level  \
# 0                 Certified Data Scientist Professional      Beginner
# 1     Linux Administration Certification Training Co...      Beginner
# 2              Integrated Program In Business Analytics      Advanced
# 3                   Master React Native Program Offline      Advanced
# 4                          Java Booster Program Offline      Advanced
# ...                                                 ...           ...
# 1146                 Transportation And Mobility Design      Beginner
# 1147                                     Product Design      Beginner
# 1148                            Interaction & Ux Design      Beginner
# 1149       UG Programme in Tech and Business Management  Intermediate
# 1150                               SQL for Data Science      Advanced
#
#      duration_medium__c  course_duration__c   price__c  loan_amount__c  ...  \
# 0                Month                  3.0    40000.0        60000.00  ...
# 1                  Week                 7.5    23594.0        17995.00  ...
# 2                Month                 10.0   305836.0       305836.00  ...
# 3               Minutes                 3.0        9.0          777.29  ...
# 4               Minutes                 3.0       15.0       118000.00  ...
# ...                 ...                 ...        ...             ...  ...
# 1146              Years                 4.0  2200000.0      2200000.00  ...
# 1147              Years                 4.0  2200000.0      2200000.00  ...
# 1148              Years                 4.0  2200000.0      2200000.00  ...
# 1149              Years                 4.0        NaN      4368000.00  ...
# 1150                nan                 NaN        NaN         2499.00  ...
#
#       Duration_in_seconds  Is_within_a_week Integration  concept_count  \
# 0                     3.0              True       False              0
# 1                     7.5              True       False              0
# 2                    10.0              True       False              0
# 3                   180.0              True       False              0
# 4                   180.0              True       False              0
# ...                   ...               ...         ...            ...
# 1146          126144000.0             False       False              0
# 1147          126144000.0             False       False              0
# 1148          126144000.0             False       False              0
# 1149          126144000.0             False       False              0
# 1150                  NaN             False       False              0
#
#       no_concept  priority_cpp  Udemy  ABC_coursera    ABC    Rank
# 0           True         False  False         False  False  550.00
# 1           True         False  False         False  False  549.99
# 2           True         False  False         False  False  549.98
# 3           True         False  False         False  False  549.97
# 4           True         False  False         False  False  549.96
# ...          ...           ...    ...           ...    ...     ...
# 1146        True         False  False         False  False  538.54
# 1147        True         False  False         False  False  538.53
# 1148        True         False  False         False  False  538.52
# 1149        True         False  False         False  False  538.51
# 1150        True         False  False         False  False  538.50
#
# [1151 rows x 23 columns]

# %%
non_corporate_priority_cpp_df= non_corporate_priority_cpp_df.sort_values(
    by=["Duration_in_seconds", "inr_amount__c"],
    ascending=[True,True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
non_corporate_priority_cpp_df['Rank'] = 700 - (non_corporate_priority_cpp_df.index * 0.01)
non_corporate_priority_cpp_df
# Out:
#      product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      pr140tds7q       21046  18972                          Eduonix
# 1      prrv19u96h       21052  18978                          Eduonix
# 2      prwelgdjic       21043  18969                          Eduonix
# 3      pr2aa9dt8x       21053  18979                          Eduonix
# 4      pr0or3bd6t       21049  18975                          Eduonix
# ...           ...         ...    ...                              ...
# 2049   prwka30dss       32957  32805                     Henry Harvin
# 2050   pr96zqow82       32296  32109                     Henry Harvin
# 2051   prevunsc7b       32809  32627                     Henry Harvin
# 2052   pr4zjtodwa       33700  33605           Henry Harvin Education
# 2053   prqu6t1ijt       35459  36150                     Henry Harvin
#
#                                            product_name  course_level  \
# 0                      Business Analytics for Beginners      Beginner
# 1     Web Accessibility for an Inclusive online pres...      Beginner
# 2     Start Simple Coding with HTML , CSS and JavaSc...      Beginner
# 3                                       UIUX with Figma      Beginner
# 4     Microsoft Bot Framework v4 - Real Life Example...      Beginner
# ...                                                 ...           ...
# 2049  Advanced Human Resource Management Course (Liv...      Advanced
# 2050  Advanced Human Resource Management Course (Ins...      Beginner
# 2051  Industry Expert Program in Finance and Account...      Beginner
# 2052  Industry Expert Program in Finance and Account...  Intermediate
# 2053                  Masters (MS) in Digital Marketing      Beginner
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0               Minutes               15.00   22488.0         22488.0  ...
# 1                 Hours                1.00    1500.0          5500.0  ...
# 2                 Hours                1.05   10000.0         10000.0  ...
# 3                 Hours                1.13    1500.0          5599.0  ...
# 4               Minutes               68.00   12500.0         12500.0  ...
# ...                 ...                 ...       ...             ...  ...
# 2049              Years                4.00  349500.0        349500.0  ...
# 2050              Years                4.00  349500.0        349500.0  ...
# 2051              Years                4.00  498000.0        498000.0  ...
# 2052              Years                4.00  498000.0        498000.0  ...
# 2053             Months              288.00       NaN         22500.0  ...
#
#       Duration_in_seconds  Is_within_a_week Integration  concept_count  \
# 0                   900.0              True       False              1
# 1                  3600.0              True       False              0
# 2                  3780.0              True       False              2
# 3                  4068.0              True       False              0
# 4                  4080.0              True       False              1
# ...                   ...               ...         ...            ...
# 2049          126144000.0             False       False              2
# 2050          126144000.0             False       False              4
# 2051          126144000.0             False       False              3
# 2052          126144000.0             False       False              1
# 2053          757444608.0             False       False              1
#
#       no_concept  priority_cpp  Udemy  ABC_coursera    ABC    Rank
# 0          False          True  False         False  False  700.00
# 1           True          True  False         False  False  699.99
# 2          False          True  False         False  False  699.98
# 3           True          True  False         False  False  699.97
# 4          False          True  False         False  False  699.96
# ...          ...           ...    ...           ...    ...     ...
# 2049       False          True  False         False  False  679.51
# 2050       False          True  False         False  False  679.50
# 2051       False          True  False         False  False  679.49
# 2052       False          True  False         False  False  679.48
# 2053       False          True  False         False  False  679.47
#
# [2054 rows x 23 columns]

# %% [markdown]
# Ranking ABC

# %%
abc_coursera_0_df = abc_coursera_0_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
abc_coursera_0_df['Rank'] = 510 - (abc_coursera_0_df.index * 0.01)
abc_coursera_0_df
# Out:
#      product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      prai5zubue       14804  14664                         Coursera
# 1      priofhwu49       14375  10553                         Coursera
# 2      prj50a1zil       16862  11768                         Coursera
# 3      prpp90zk8u       18219  14252                         Coursera
# 4      prrtje596c       15301  14737                         Coursera
# ...           ...         ...    ...                              ...
# 1058   prnkxi2dfy       15752  20942                         Coursera
# 1059   prtq8fe2jo       22555  20634                         Coursera
# 1060   prw7ivef80       15593  20515                         Coursera
# 1061   prwbrwx3rr       22534  20612                         Coursera
# 1062   prx3ri6kt5       17517  20952                         Coursera
#
#                                            product_name  course_level  \
# 0     Static Website Hosting and Cross-Region Replic...      Beginner
# 1     Create a Boggle Word Solver using recursion in...  Intermediate
# 2                          Fast Typer Game using Pygame      Beginner
# 3     Recreate the First Ever Easter Egg from Advent...      Beginner
# 4                                 Style Images with CSS  Intermediate
# ...                                                 ...           ...
# 1058  Maximizing Marketing Success with Generative A...      Beginner
# 1059  Concepts, Strategies, and Analytics in Perform...      Beginner
# 1060  Hotel Digital Marketing and Social Media Strategy      Beginner
# 1061                     Google Advanced Data Analytics      Beginner
# 1062                                    jQuery Tutorial      Beginner
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0                 Hours                 0.1       1.0             0.0  ...
# 1                 Hours                 0.1       1.0             0.0  ...
# 2                 Hours                 0.1       1.0             0.0  ...
# 3                 Hours                 0.1       1.0             0.0  ...
# 4                 Hours                 0.1       1.0             0.0  ...
# ...                 ...                 ...       ...             ...  ...
# 1058              Hours                 NaN       1.0             0.0  ...
# 1059              Hours                 NaN       1.0             0.0  ...
# 1060              Hours                 NaN       1.0             0.0  ...
# 1061              Hours                 NaN       1.0             0.0  ...
# 1062              Hours                 NaN       1.0             0.0  ...
#
#       concepts  Duration_in_seconds Is_within_a_week  Integration  \
# 0          NaN                360.0             True        False
# 1          NaN                360.0             True        False
# 2          NaN                360.0             True        False
# 3          NaN                360.0             True        False
# 4          NaN                360.0             True        False
# ...        ...                  ...              ...          ...
# 1058       NaN                  NaN            False        False
# 1059       NaN                  NaN            False        False
# 1060       NaN                  NaN            False        False
# 1061       NaN                  NaN            False        False
# 1062       NaN                  NaN            False        False
#
#       concept_count  no_concept  priority_cpp  Udemy  ABC_coursera    Rank
# 0                 0        True         False  False          True  510.00
# 1                 0        True         False  False          True  509.99
# 2                 0        True         False  False          True  509.98
# 3                 0        True         False  False          True  509.97
# 4                 0        True         False  False          True  509.96
# ...             ...         ...           ...    ...           ...     ...
# 1058              0        True         False  False          True  499.42
# 1059              0        True         False  False          True  499.41
# 1060              0        True         False  False          True  499.40
# 1061              0        True         False  False          True  499.39
# 1062              0        True         False  False          True  499.38
#
# [1063 rows x 22 columns]

# %%
abc_coursera_df = abc_coursera_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
abc_coursera_df['Rank'] = 525 - (abc_coursera_df.index * 0.01)
abc_coursera_df
# Out:
#      product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      pr191gx295       19528   9449                         Coursera
# 1      pr1mfracxt       20031  12536                         Coursera
# 2      prabvbpkbt       15387  11282                         Coursera
# 3      prmlysrlzl       19486  13933                         Coursera
# 4      prny34l21j       20046  10012                         Coursera
# ...           ...         ...    ...                              ...
# 5439   przhd3q074       22533  20611                         Coursera
# 5440   przixvhfo5       22618  20702                         Coursera
# 5441   przqenabsa       22672  20761                         Coursera
# 5442   przy2ytv16       21460  19450                         Coursera
# 5443   pro59osu24       22748  20841                         Coursera
#
#                                            product_name  course_level  \
# 0                    Analyze Text Data with Yellowbrick  Intermediate
# 1                Improving Math Engagement with Prodigy      Beginner
# 2     Design and Develop an Obstacles Game using Pyg...  Intermediate
# 3     Predict Gas Guzzlers using a Neural Net Model ...  Intermediate
# 4           Building Classroom Community Using Flipgrid      Beginner
# ...                                                 ...           ...
# 5439               Learn Mandarin Chinese: Intermediate      Beginner
# 5440                        Privacy and Standardisation      Beginner
# 5441                Teach English: Intermediate Grammar      Beginner
# 5442  Database Design and Operational Business Intel...      Beginner
# 5443                          Academic English: Writing      Beginner
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0                 Hours                 0.1       1.0             0.0  ...
# 1                 Hours                 0.1       1.0             0.0  ...
# 2                 Hours                 0.1       1.0             0.0  ...
# 3                 Hours                 0.1       1.0             0.0  ...
# 4                 Hours                 0.1       1.0             0.0  ...
# ...                 ...                 ...       ...             ...  ...
# 5439              Hours                 NaN       1.0             0.0  ...
# 5440              Hours                 NaN       1.0             0.0  ...
# 5441              Hours                 NaN       1.0             0.0  ...
# 5442              Hours                 NaN       1.0             0.0  ...
# 5443              Hours                 NaN       1.0             0.0  ...
#
#                 concepts  Duration_in_seconds Is_within_a_week  Integration  \
# 0                   4887                360.0             True        False
# 1                   6061                360.0             True        False
# 2                   5612                360.0             True        False
# 3     4607 , 4905 , 6669                360.0             True        False
# 4                   5002                360.0             True        False
# ...                  ...                  ...              ...          ...
# 5439         6061 , 6213                  NaN            False        False
# 5440                4934                  NaN            False        False
# 5441                9606                  NaN            False        False
# 5442                4705                  NaN            False        False
# 5443                6213                  NaN            False        False
#
#       concept_count  no_concept  priority_cpp  Udemy  ABC_coursera    Rank
# 0                 1       False         False  False          True  525.00
# 1                 1       False         False  False          True  524.99
# 2                 1       False         False  False          True  524.98
# 3                 3       False         False  False          True  524.97
# 4                 1       False         False  False          True  524.96
# ...             ...         ...           ...    ...           ...     ...
# 5439              2       False         False  False          True  470.61
# 5440              1       False         False  False          True  470.60
# 5441              1       False         False  False          True  470.59
# 5442              1       False         False  False          True  470.58
# 5443              1       False         False  False          True  470.57
#
# [5444 rows x 22 columns]

# %%
abc_df = abc_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
abc_df['Rank'] = 425 - (abc_df.index * 0.01)
abc_df
# Out:
#      product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      pr6ggb6crn       13720   9169                              GVC
# 1      prz439vl3r       12700   8151                              GVC
# 2      prwjj6sgg7       13783  19765                              GVC
# 3      pr0ramdk0c       13667   9117                              GVC
# 4      prnl3tqozi       13112   8562                              GVC
# ...           ...         ...    ...                              ...
# 2493   przpiipjwv       22448  20398                              GVC
# 2494   przsnkj6o1       22075  20025                              GVC
# 2495   przurvq0im       22264  20214                              GVC
# 2496   przvahytsh       22157  20107                              GVC
# 2497   przyu0in9m       22779  20873                              GVC
#
#                                            product_name  course_level  \
# 0               Sharing Multiple Screens Simultaneously      Beginner
# 1                     Scheduling a Meeting with Outlook      Beginner
# 2     Recognizing and Addressing Micro-behaviors in ...      Beginner
# 3                                     Closed Captioning      Beginner
# 4                                   Sharing Your Screen      Beginner
# ...                                                 ...           ...
# 2493  Outlook on the Web: Using & Managing the Calendar      Beginner
# 2494  Configure Windows Defender on a Windows System...      Beginner
# 2495                 CompTIA Linux+: SELinux & AppArmor  Intermediate
# 2496      Outlook 2016 (Mac): Sending & Receiving Email      Beginner
# 2497            Microsoft Azure Services and Lifecycles      Beginner
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0                 Hours                0.01       1.0             0.0  ...
# 1                 Hours                0.01       1.0             0.0  ...
# 2                 Hours                0.01       1.0             0.0  ...
# 3                 Hours                0.02       1.0             0.0  ...
# 4                 Hours                0.02       1.0             0.0  ...
# ...                 ...                 ...       ...             ...  ...
# 2493              Hours                 NaN       1.0             0.0  ...
# 2494              Hours                 NaN       1.0             0.0  ...
# 2495              Hours                 NaN       1.0             0.0  ...
# 2496              Hours                 NaN       1.0             0.0  ...
# 2497              Hours                 NaN       1.0             0.0  ...
#
#       Duration_in_seconds  Is_within_a_week Integration  concept_count  \
# 0                    36.0              True       False              1
# 1                    36.0              True       False              1
# 2                    36.0              True       False              1
# 3                    72.0              True       False              1
# 4                    72.0              True       False              1
# ...                   ...               ...         ...            ...
# 2493                  NaN             False       False              1
# 2494                  NaN             False       False              1
# 2495                  NaN             False       False              1
# 2496                  NaN             False       False              1
# 2497                  NaN             False       False              1
#
#       no_concept  priority_cpp  Udemy  ABC_coursera   ABC    Rank
# 0          False         False  False         False  True  425.00
# 1          False         False  False         False  True  424.99
# 2          False         False  False         False  True  424.98
# 3          False         False  False         False  True  424.97
# 4          False         False  False         False  True  424.96
# ...          ...           ...    ...           ...   ...     ...
# 2493       False         False  False         False  True  400.07
# 2494       False         False  False         False  True  400.06
# 2495       False         False  False         False  True  400.05
# 2496       False         False  False         False  True  400.04
# 2497       False         False  False         False  True  400.03
#
# [2498 rows x 23 columns]

# %%
abc_0_df = abc_0_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
abc_0_df['Rank'] = 350 - (abc_0_df.index * 0.01)
abc_0_df
# Out:
#    product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0    prkbticw4m       13061   8511                              GVC
# 1    prcr33dsjs       13008   8458                              GVC
# 2    pr8l3huhxx       13084   8534                              GVC
# 3    prk4u6jgyu       12654   8105                              GVC
# 4    pr54fqvljc       12740   8191                              GVC
# ..          ...         ...    ...                              ...
# 76   prkyuckt6g       22822  20916                              GVC
# 77   prlzsqg3kg       22764  20858                              GVC
# 78   proo82aici       22823  20917                              GVC
# 79   prp279k851       21916  19866                              GVC
# 80   prxxilay2h       21520  19565                              GVC
#
#                                          product_name  course_level  \
# 0                       Is Your Internet FAST Enough?      Beginner
# 1                    What is Data and Digital Content      Beginner
# 2                 Prospecting: Panning for Sales Gold      Beginner
# 3                Introduction to Power Virtual Agents      Beginner
# 4   AWS SysOps Associate: AWS Directory Services &...  Intermediate
# ..                                                ...           ...
# 76         Business intelligence and data warehousing      Beginner
# 77                          Python Data Visualization      Beginner
# 78                            Introduction to MongoDB      Beginner
# 79                                      Collaboration      Beginner
# 80   Project Scheduling:  Estimate Activity Durations      Beginner
#
#    duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0               Hours                0.11       1.0             0.0  ...
# 1               Hours                0.17       1.0             0.0  ...
# 2               Hours                0.20       1.0             0.0  ...
# 3               Hours                0.22       1.0             0.0  ...
# 4               Hours                0.30       1.0             0.0  ...
# ..                ...                 ...       ...             ...  ...
# 76              Hours                 NaN       1.0             0.0  ...
# 77              Hours                 NaN       1.0             0.0  ...
# 78              Hours                 NaN       1.0             0.0  ...
# 79              Hours                 NaN       1.0             0.0  ...
# 80              Hours                 NaN       1.0             0.0  ...
#
#     Duration_in_seconds  Is_within_a_week Integration  concept_count  \
# 0                 396.0              True       False              0
# 1                 612.0              True       False              0
# 2                 720.0              True       False              0
# 3                 792.0              True       False              0
# 4                1080.0              True       False              0
# ..                  ...               ...         ...            ...
# 76                  NaN             False       False              0
# 77                  NaN             False       False              0
# 78                  NaN             False       False              0
# 79                  NaN             False       False              0
# 80                  NaN             False       False              0
#
#     no_concept  priority_cpp  Udemy  ABC_coursera   ABC    Rank
# 0         True         False  False         False  True  350.00
# 1         True         False  False         False  True  349.99
# 2         True         False  False         False  True  349.98
# 3         True         False  False         False  True  349.97
# 4         True         False  False         False  True  349.96
# ..         ...           ...    ...           ...   ...     ...
# 76        True         False  False         False  True  349.24
# 77        True         False  False         False  True  349.23
# 78        True         False  False         False  True  349.22
# 79        True         False  False         False  True  349.21
# 80        True         False  False         False  True  349.20
#
# [81 rows x 23 columns]

# %% [markdown]
# Ranking Udemy_courses

# %%
udemy_df = udemy_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
udemy_df['Rank'] = 300 - (udemy_df.index * 0.01)
udemy_df
# Out:
#      product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0      pr0y1ipl5c       31002  29558                            Udemy
# 1      pr3362upkq       31204  29760                            Udemy
# 2      prcdxzvedk       31166  29722                            Udemy
# 3      prgw6evcc9       31137  29693                            Udemy
# 4      prhzt6h99t       31340  29896                            Udemy
# ...           ...         ...    ...                              ...
# 5260     5OqCv2Pw       25043  23264                            Udemy
# 5261     3TgEl5Xn       27077  25300                            Udemy
# 5262   prbgu9bqhd       33590  33488                            Udemy
# 5263   prpnv1ebe6       33589  33487                            Udemy
# 5264   prz666dzq4       29616  28785                            Udemy
#
#                                            product_name  course_level  \
# 0     Project Management Certified Associate: CAPM P...  Intermediate
# 1     SAFE 6.0 Scrum Master - Certified SAFE 6 Scrum...      Beginner
# 2     ISO 22301Business Continuity Management (BCM &...      Beginner
# 3     Project Management - Theory of Constraints way...      Beginner
# 4        Life Insurance & Annuity Ultimate Buyers Guide      Beginner
# ...                                                 ...           ...
# 5260  Selenium Java : Beginner to Advanced [Live Pro...      Beginner
# 5261  SAP ABAP, OOPS, CROSSAPP, WEBDYNPRO, WORKFLOW,...      Beginner
# 5262  KPI and metrics for Management Consultants & M...      Advanced
# 5263  Critical Thinker Academy: Learn to Think Like ...  Intermediate
# 5264  ISC2 Certified in Cybersecurity (CC) Full Prac...      Beginner
#
#      duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0                 Hours                 0.1       0.0         23850.0  ...
# 1                 Hours                 0.1       0.0         23850.0  ...
# 2                 Hours                 0.1       0.0         23850.0  ...
# 3                 Hours                 0.1       0.0         23850.0  ...
# 4                 Hours                 0.1       0.0         23850.0  ...
# ...                 ...                 ...       ...             ...  ...
# 5260            Minutes             11327.0   23850.0         23850.0  ...
# 5261            Minutes             11547.0   23850.0         23850.0  ...
# 5262              Hours               334.0   22842.0         23850.0  ...
# 5263              Hours              1173.0   22842.0         23850.0  ...
# 5264            Minutes                 NaN   23850.0         23850.0  ...
#
#       skill_id                                           concepts  \
# 0           37                                               4590
# 1          263                                               5724
# 2           40                                        4586 , 5436
# 3           37                                               4590
# 4           45                                               4568
# ...        ...                                                ...
# 5260       103                                        6817 , 6849
# 5261       316                                               6938
# 5262        63                                               5506
# 5263       314  5025 , 7005 , 7006 , 7007 , 7008 , 7009 , 7010...
# 5264       130                                               6063
#
#      Duration_in_seconds  Is_within_a_week  Integration  concept_count  \
# 0                  360.0              True        False              1
# 1                  360.0              True        False              1
# 2                  360.0              True        False              2
# 3                  360.0              True        False              1
# 4                  360.0              True        False              1
# ...                  ...               ...          ...            ...
# 5260            679620.0             False        False              2
# 5261            692820.0             False        False              1
# 5262           1202400.0             False        False              1
# 5263           4222800.0             False        False             10
# 5264                 NaN             False        False              1
#
#       no_concept  priority_cpp  Udemy    Rank
# 0          False         False   True  300.00
# 1          False         False   True  299.99
# 2          False         False   True  299.98
# 3          False         False   True  299.97
# 4          False         False   True  299.96
# ...          ...           ...    ...     ...
# 5260       False         False   True  247.40
# 5261       False         False   True  247.39
# 5262       False         False   True  247.38
# 5263       False         False   True  247.37
# 5264       False         False   True  247.36
#
# [5265 rows x 21 columns]

# %%
udemy_0_df = udemy_0_df.sort_values(
    by=["Duration_in_seconds", "Integration", "inr_amount__c"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
udemy_0_df['Rank'] = 200 - (udemy_0_df.index * 0.01)
udemy_0_df
# Out:
#    product_sfid  product_id   mpid course_provider_platform_name__c  \
# 0    prckjmlvhq       29660  28123                            Udemy
# 1    prtvhr73po       28604  27070                            Udemy
# 2    prgxo3e70m       29720  28183                            Udemy
# 3    prbg329x5m       28263  26729                            Udemy
# 4    preelbycur       29646  28109                            Udemy
# 5    prllet9osu       30939  29495                            Udemy
# 6    prr7lx775u       29532  27995                            Udemy
# 7    pr4rce05qb       30210  28673                            Udemy
# 8    prrn4jj0va       28014  26480                            Udemy
# 9    prxn9li6ss       31017  29573                            Udemy
# 10     8ObDt0Ty       23451  21672                            Udemy
# 11   prz8qyxwm0       28009  26475                            Udemy
# 12   pr48w18bp0       28040  26506                            Udemy
# 13   prgh28omad       30150  28613                            Udemy
# 14     7BpKm9Gj       23448  21669                            Udemy
# 15   prz4qvhvi9       30188  28651                            Udemy
# 16   prtq3w17ir       29930  28393                            Udemy
# 17     5TgAx9Cg       22983  21204                            Udemy
# 18     2FeBo7Oj       25745  23967                            Udemy
# 19   pr72kec05o       27984  26450                            Udemy
# 20     5YrGr8Hy       22895  21116                            Udemy
# 21     1FkNf0Wo       22871  21092                            Udemy
# 22   prv7lg5yyb       29127  27590                            Udemy
#
#                                          product_name  course_level  \
# 0              Managing a Global Team with Confidence      Beginner
# 1                        Visionary Servant Leadership      Beginner
# 2   Leadership Skills: Learn Vigilant Leadership &...      Beginner
# 3   Leadership: How to Influence, Inspire and Impa...      Beginner
# 4   Leadership - Rise of a Leader (Lead people wit...      Beginner
# 5   Manage Change Through Collaboration and Team Work      Beginner
# 6             Leading & Managing People [Effectively]      Beginner
# 7   Ethical AI Decision Making, Insights for Leade...      Beginner
# 8   Management - Leadership, Negotiating, Assertiv...      Beginner
# 9           Collaboration with Emotional Intelligence  Intermediate
# 10  Master SWOT Analysis  and  Business Strategy f...      Beginner
# 11  How to Lead with Ease & Be a Successful CEO, L...      Beginner
# 12            Leadership: Practical Leadership Skills      Beginner
# 13  Web Performance In Practice: Master Core Web V...      Beginner
# 14  Master PMP Cost Management: Plan, Budget, Esti...      Beginner
# 15  Professional Diploma in Advertising and Public...      Beginner
# 16  Product Owner II for Agile Intermediate: Certi...      Beginner
# 17  Certified Key Performance Indicators Professio...      Beginner
# 18  AWS Technical Essentials  - Hands-On Training ...      Beginner
# 19     Lean Six Sigma Green Belt Online Course (2023)      Beginner
# 20  Automated Cryptocurrency Portfolio Investing w...      Beginner
# 21  ACCA MA (F2) A Complete Course on Management A...      Beginner
# 22  Leadership & Management Skills: 2-in-1 Masterc...      Beginner
#
#    duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# 0             Minutes                35.0   23850.0         23850.0  ...
# 1             Minutes                84.0   23850.0         23850.0  ...
# 2             Minutes                89.0   23850.0         23850.0  ...
# 3             Minutes                91.0   23850.0         23850.0  ...
# 4             Minutes                91.0   23850.0         23850.0  ...
# 5             Minutes               102.0       0.0         23850.0  ...
# 6             Minutes               119.0   23850.0         23850.0  ...
# 7             Minutes               126.0   23850.0         23850.0  ...
# 8             Minutes               128.0   23850.0         23850.0  ...
# 9             Minutes               184.0       0.0         23850.0  ...
# 10            Minutes               185.0   23850.0         23850.0  ...
# 11            Minutes               186.0   23850.0         23850.0  ...
# 12            Minutes               200.0   23850.0         23850.0  ...
# 13            Minutes               204.0   23850.0         23850.0  ...
# 14            Minutes               224.0   23850.0         23850.0  ...
# 15            Minutes               251.0   23850.0         23850.0  ...
# 16            Minutes               379.0   23850.0         23850.0  ...
# 17            Minutes               448.0   23850.0         23850.0  ...
# 18            Minutes               866.0   23850.0         23850.0  ...
# 19            Minutes               967.0   23850.0         23850.0  ...
# 20            Minutes              1931.0   23850.0         23850.0  ...
# 21            Minutes              2014.0   23850.0         23850.0  ...
# 22            Minutes              2655.0   23850.0         23850.0  ...
#
#     skill_id  concepts Duration_in_seconds  Is_within_a_week  Integration  \
# 0        255       NaN              2100.0              True        False
# 1        255       NaN              5040.0              True        False
# 2        255       NaN              5340.0              True        False
# 3        255       NaN              5460.0              True        False
# 4        255       NaN              5460.0              True        False
# 5        262       NaN              6120.0              True        False
# 6        255       NaN              7140.0              True        False
# 7        261       NaN              7560.0              True        False
# 8        255       NaN              7680.0              True        False
# 9        262       NaN             11040.0              True        False
# 10        49       NaN             11100.0              True        False
# 11       255       NaN             11160.0              True        False
# 12       255       NaN             12000.0              True        False
# 13       106       NaN             12240.0              True        False
# 14        49       NaN             13440.0              True        False
# 15       262       NaN             15060.0              True        False
# 16        36       NaN             22740.0              True        False
# 17        49       NaN             26880.0              True        False
# 18        44       NaN             51960.0              True        False
# 19        39       NaN             58020.0              True        False
# 20        49       NaN            115860.0              True        False
# 21       261       NaN            120840.0              True        False
# 22       255       NaN            159300.0              True        False
#
#     concept_count  no_concept  priority_cpp  Udemy    Rank
# 0               0        True         False   True  200.00
# 1               0        True         False   True  199.99
# 2               0        True         False   True  199.98
# 3               0        True         False   True  199.97
# 4               0        True         False   True  199.96
# 5               0        True         False   True  199.95
# 6               0        True         False   True  199.94
# 7               0        True         False   True  199.93
# 8               0        True         False   True  199.92
# 9               0        True         False   True  199.91
# 10              0        True         False   True  199.90
# 11              0        True         False   True  199.89
# 12              0        True         False   True  199.88
# 13              0        True         False   True  199.87
# 14              0        True         False   True  199.86
# 15              0        True         False   True  199.85
# 16              0        True         False   True  199.84
# 17              0        True         False   True  199.83
# 18              0        True         False   True  199.82
# 19              0        True         False   True  199.81
# 20              0        True         False   True  199.80
# 21              0        True         False   True  199.79
# 22              0        True         False   True  199.78
#
# [23 rows x 21 columns]

# %% [markdown]
# Concanating all the dataframe

# %%
pieces = {"x1":non_corporate_priority_cpp_df,"x2": non_corporate_df,"x3":non_corporate_0_df, "y":abc_coursera_df,"y1":abc_coursera_0_df,"y2": abc_df,"y3": abc_0_df, "z": udemy_df,"z1": udemy_0_df}
result = pd.concat(pieces)
result.to_excel("C:\\Users\\taslim.siddiqui\\Downloads\\Recorating_25-07-2025.xlsx")
print(result)
# Out:
#       product_sfid  product_id   mpid course_provider_platform_name__c  \
# x1 0    pr140tds7q       21046  18972                          Eduonix
#    1    prrv19u96h       21052  18978                          Eduonix
#    2    prwelgdjic       21043  18969                          Eduonix
#    3    pr2aa9dt8x       21053  18979                          Eduonix
#    4    pr0or3bd6t       21049  18975                          Eduonix
# ...            ...         ...    ...                              ...
# z1 18     2FeBo7Oj       25745  23967                            Udemy
#    19   pr72kec05o       27984  26450                            Udemy
#    20     5YrGr8Hy       22895  21116                            Udemy
#    21     1FkNf0Wo       22871  21092                            Udemy
#    22   prv7lg5yyb       29127  27590                            Udemy
#
#                                             product_name course_level  \
# x1 0                    Business Analytics for Beginners     Beginner
#    1   Web Accessibility for an Inclusive online pres...     Beginner
#    2   Start Simple Coding with HTML , CSS and JavaSc...     Beginner
#    3                                     UIUX with Figma     Beginner
#    4   Microsoft Bot Framework v4 - Real Life Example...     Beginner
# ...                                                  ...          ...
# z1 18  AWS Technical Essentials  - Hands-On Training ...     Beginner
#    19     Lean Six Sigma Green Belt Online Course (2023)     Beginner
#    20  Automated Cryptocurrency Portfolio Investing w...     Beginner
#    21  ACCA MA (F2) A Complete Course on Management A...     Beginner
#    22  Leadership & Management Skills: 2-in-1 Masterc...     Beginner
#
#       duration_medium__c  course_duration__c  price__c  loan_amount__c  ...  \
# x1 0             Minutes               15.00   22488.0         22488.0  ...
#    1               Hours                1.00    1500.0          5500.0  ...
#    2               Hours                1.05   10000.0         10000.0  ...
#    3               Hours                1.13    1500.0          5599.0  ...
#    4             Minutes               68.00   12500.0         12500.0  ...
# ...                  ...                 ...       ...             ...  ...
# z1 18            Minutes              866.00   23850.0         23850.0  ...
#    19            Minutes              967.00   23850.0         23850.0  ...
#    20            Minutes             1931.00   23850.0         23850.0  ...
#    21            Minutes             2014.00   23850.0         23850.0  ...
#    22            Minutes             2655.00   23850.0         23850.0  ...
#
#        Duration_in_seconds  Is_within_a_week Integration  concept_count  \
# x1 0                 900.0              True       False              1
#    1                3600.0              True       False              0
#    2                3780.0              True       False              2
#    3                4068.0              True       False              0
#    4                4080.0              True       False              1
# ...                    ...               ...         ...            ...
# z1 18              51960.0              True       False              0
#    19              58020.0              True       False              0
#    20             115860.0              True       False              0
#    21             120840.0              True       False              0
#    22             159300.0              True       False              0
#
#        no_concept  priority_cpp  Udemy  ABC_coursera    ABC    Rank
# x1 0        False          True  False         False  False  700.00
#    1         True          True  False         False  False  699.99
#    2        False          True  False         False  False  699.98
#    3         True          True  False         False  False  699.97
#    4        False          True  False         False  False  699.96
# ...           ...           ...    ...           ...    ...     ...
# z1 18        True         False   True           NaN    NaN  199.82
#    19        True         False   True           NaN    NaN  199.81
#    20        True         False   True           NaN    NaN  199.80
#    21        True         False   True           NaN    NaN  199.79
#    22        True         False   True           NaN    NaN  199.78
#
# [21374 rows x 23 columns]

# %% [markdown]
# testing

# %%
result_reset = result.reset_index()
result_reset['final_rank'] = 600 - (result_reset.index * 0.01)
#result_reset.to_excel("/Users/romitbenkar/Downloads/Recorating_21-03-2025.xlsx")

# %%
import pandas as pd

# Define the dataset
data = {
    "duration_seconds": [2000, 5890, 5739, 6746, 2000, 2000, 5890, 2000, 67383, 784892, 6474, 5890],
    "Integration": [True, True, False, True, True, True, True, True, False, True, False, False],
    "Price": [5943843, 7744, 4744, 84433, 74484, 4438, 46746, 73782, 74383, 74873, 764673, 64473]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort by the three columns in the desired order: duration_seconds, Integration (descending), Price
df = df.sort_values(
    by=["duration_seconds", "Integration", "Price"],
    ascending=[True, False, True]
).reset_index(drop=True)

# Assign sequence rankings based on sorted order
df['Rank'] = 600 - (df.index * 0.01)

# Display the resulting DataFrame
print(df)
# Out:
#     duration_seconds  Integration    Price    Rank
# 0               2000         True     4438  600.00
# 1               2000         True    73782  599.99
# 2               2000         True    74484  599.98
# 3               2000         True  5943843  599.97
# 4               5739        False     4744  599.96
# 5               5890         True     7744  599.95
# 6               5890         True    46746  599.94
# 7               5890        False    64473  599.93
# 8               6474        False   764673  599.92
# 9               6746         True    84433  599.91
# 10             67383        False    74383  599.90
# 11            784892         True    74873  599.89
